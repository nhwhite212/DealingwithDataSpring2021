# %% [markdown]
# ### Twitter example using Panos Ipeirotis authentication
# Here is an example of using Oauth1 with twitter. It was developed by Pano I. and uses his twitter account.

# %% [markdown]
# ## Example: Twitter API in Python, with OAuth1 authentication

# %% [markdown]
# <img src="https://github.com/nhwhite212/DealingwithDataSpring2021/blob/master/3-WebAPIs_crawling/images/Python_Twitter.jpg?raw=1" width="300px">
#
# The guide below shows the steps of registering an application that you can integrate with **Twitter**. Registering the application is the first step in developing an application that is integrated into its users' social graph.

# %% [markdown]
# ## Register a new application
#
# All **Twitter** users are potentially **Twitter** application developers. Simply visit https://apps.twitter.com/ and sign in with your **Twitter** credentials.
#
# Click the "Create a new application" button near the top. A new page with the **_Create an application_** form requires basic information about your application.
#
# <img src="https://github.com/nhwhite212/DealingwithDataSpring2021/blob/master/3-WebAPIs_crawling/images/create_an_application_1.jpg?raw=1">
#
# - In the **_Name_** field name your application in 32 characters or fewer.
# - In the **_Description_** field describe your application in 10 to 200 characters.
# - In the **_Website_** field, you can give a pointer to your website. (It does not really matter, as we will not be using that functionality yet).
# - The **_Callback URL_** leave it empty for now.
#
# The **Developer Agreement** section outlines rules you must agree to follow if you build an application that uses **Twitter’s** API. If you agree to the rules, check "Yes, I agree".
#
# <img src="https://github.com/nhwhite212/DealingwithDataSpring2021/blob/master/3-WebAPIs_crawling/images/create_an_application_2.jpg?raw=1">
#
# After Captcha challenge click "Create your **Twitter** application" to complete the form and go to the application settings page.
#
# In the opened window you’ll then be presented with lots of information. The main fields to note are **_Consumer key_** and **_Consumer secret_**. These values are your application’s credentials for **Twitter**. You need them to do almost anything with **Twitter**, including going through the OAuth authorization flow and working with **Twitter’s** REST API. But we’re not quite done yet. We now need to authorise the **Twitter** app for your **Twitter** account. To do this you should select "Key and Access Tokens" menu button and create your access token. This **access token** will allow your **Twitter** application to read **Twitter** information. You’ll be able to get data of your tweets, mentions, lists and more.
#
# <img src="https://github.com/nhwhite212/DealingwithDataSpring2021/blob/master/3-WebAPIs_crawling/images/create_an_application_3.jpg?raw=1">
#
# As a result you will see the window with consumer and token keys for your application
#
# <img src="https://github.com/nhwhite212/DealingwithDataSpring2021/blob/master/3-WebAPIs_crawling/images/create_an_application_4.jpg?raw=1">
#
# Above the four fields are highlighted. You will need these long horrible strings of characters for your **Twitter** app. It goes without saying that you should keep these secret. If anyone was to get these keys, they could effectively access your **Twitter** account.
#
# However, if you want to do more advanced stuff like sending tweets or deleting, you’ll need to change your access type in the "Permission" menu window. Change the access type to "Read and Write" to be able to read **Twitter** data and send tweets and select "Read, Write and access direct messages" if you want to also have access to your direct messages.

# %% [markdown]
# ---
# ## Getting access to Twitter APIs using main Python tools
# ---

# %% [markdown]
# Many web services including **Twitter** require authentication, and there are many different types.
#
# Python library `requests` provides a pythonic way to make complex HTTP requests, and handles difficult tasks like authentication.
#
# A common form of authentication for several web APIs is OAuth. The `requests-oauthlib` library allows `requests`'s users to easily make OAuth authenticated requests.

# %%
# !pip3 install -U requests_oauthlib
# Out:
# Requirement already up-to-date: requests_oauthlib in /usr/local/lib/python3.6/dist-packages (1.2.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib) (2.22.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.0.0->requests_oauthlib) (2.6)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/lib/python3/dist-packages (from requests>=2.0.0->requests_oauthlib) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib) (2019.6.16)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib) (1.25.3)

# %%
import requests
from requests_oauthlib import OAuth1

import json

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
consumer_key = 'ZFSlBaBhgAnoI5Cb5YJ8Q2iSL'
consumer_secret = 'QBFuxdiXsGypn1fEL3Nu8BQtYiFXC97RIsaCf6xv7Rq7E4Dcyg'
access_token = '16976496-hhbdqyfoVqgYbFmVz076IwWxa4vM58my0v1nJNlW0'
access_secret = '3aTWUUdNMTVWDBjxCOApzRdSiiySFM4yaZcGJ1YYaub75'

# You will authenticate yourself using OAuth1 object
auth = OAuth1(consumer_key, consumer_secret, access_token, access_secret)
print(auth)
# Out:
# <requests_oauthlib.oauth1_auth.OAuth1 object at 0x7faa47dc5690>

# %%
# If the authentication was successful, you should see the name of the account print(out)
url_0 = 'https://api.twitter.com/1.1/account/verify_credentials.json'
res = requests.get(url_0, auth=auth)

print("My name is", res.json()["name"])
# Out:
# My name is Panos Ipeirotis

# %%
res.json()
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Sun Oct 26 04:16:42 +0000 2008',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': 'Scientist at @Compass. Professor at @NYUStern.\n\n#ai #datascience #crowdsourcing \n\nI have opinions.',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'ipeirotis.org',
#      'expanded_url': 'http://ipeirotis.org',
#      'indices': [0, 23],
#      'url': 'https://t.co/BvP8qHhk1r'}]}},
#  'favourites_count': 271,
#  'follow_request_sent': False,
#  'followers_count': 4491,
#  'following': False,
#  'friends_count': 311,
#  'geo_enabled': True,
#  'has_extended_profile': True,
#  'id': 16976496,
#  'id_str': '16976496',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 252,
#  'location': 'New York, NY',
#  'name': 'Panos Ipeirotis',
#  'needs_phone_verification': False,
#  'notifications': False,
#  'profile_background_color': '131516',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_tile': True,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16976496/1398193510',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  'profile_link_color': 'FF691F',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'EFEFEF',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'ipeirotis',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 24 17:38:51 +0000 2021',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1374777746950348809',
#      'indices': [116, 139],
#      'url': 'https://t.co/FC24Ja5QBL'}],
#    'user_mentions': [{'id': 34953531,
#      'id_str': '34953531',
#      'indices': [0, 9],
#      'name': 'Ippokratis Pandis',
#      'screen_name': 'Hippotas'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 1374777746950348809,
#   'id_str': '1374777746950348809',
#   'in_reply_to_screen_name': 'Hippotas',
#   'in_reply_to_status_id': 1374770363020627970,
#   'in_reply_to_status_id_str': '1374770363020627970',
#   'in_reply_to_user_id': 34953531,
#   'in_reply_to_user_id_str': '34953531',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': '@Hippotas It is just a failure of a single kubernetes. Ask the kubernetes of the other ships to load balance using… https://t.co/FC24Ja5QBL',
#   'truncated': True},
#  'statuses_count': 3588,
#  'suspended': False,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/BvP8qHhk1r',
#  'utc_offset': None,
#  'verified': False}

# %% [markdown]
# ### Example 1: Read Tweets from Your Homepage
#
# The list of all available **Twitter** API you can find here https://dev.twitter.com/rest/public. Let's use `home_timeline` that returns a collection of the most recent tweets and retweets posted by the authenticating user and the users they follow.

# %%
url_1 = 'https://api.twitter.com/1.1/statuses/home_timeline.json'
res = requests.get(url_1, auth=auth, params={"count": 20})

# The res object encapsulates the "response" of the server. Notice the status code that is displayed. 
# Code 200 means that things went fine
# Code 403 means that the server understood the request, but is refusing to fulfill it
# Code 404 means that the URL was not found
# Codes 5xx mean that something went wrong

print(res, "Status code:", res.status_code)
# Let's see how looks the url
print(res.url)
print("Content type:", res.headers['content-type'], '\n')

tweets = res.json()
if res.status_code == 200:
    for tweet in tweets:
        print("* ", tweet['text'])
        print("----------------------------------")
else:   # You have no tweets
    pass
# Out:
# <Response [200]> Status code: 200
# https://api.twitter.com/1.1/statuses/home_timeline.json?count=20
# Content type: application/json;charset=utf-8
#
# *  Its great and in nice small chunks that are easy to use independently. https://t.co/eEDaYrYVjc
# ----------------------------------
# *  RT @alan7cheng: i own a copy of dan's book, The ABCs of How We Learn, and i highly recommend it to anyone who wants to better understand ho…
# ----------------------------------
# *  @johnjhorton There is?
# ----------------------------------
# *  RT @dynamodb: Want to replicate data from DynamoDB to Amazon Elasticsearch Service, Amazon S3 or Amazon Redshift? Check out AWS Glue Elasti…
# ----------------------------------
# *  You can use Amazon Redshift Spectrum in the GovCloud, Cape Town, Milan and Osaka regions. #redshift #spectrum… https://t.co/51xO2jgnti
# ----------------------------------
# *  Dan of @StanfordEd says the traditional lecture style of Summarize + Lecture doesn't work well. Explanations and co… https://t.co/EoAsRALjRi
# ----------------------------------
# *  Update: apparently spouse’s zoom work call was also interrupted to break the news about the McDonald’s app.
# ----------------------------------
# *  RT @KarlreMarks: My ambitious plan to free the boat is to push a huge cotton swab up the canal https://t.co/ZnY4ehu8fx
# ----------------------------------
# *  All my servers have an 8 GB empty file on disk https://t.co/BzDwRyD1Z2 (https://t.co/vBVuzFb9zS)
# ----------------------------------
# *  Some people are so desperate to broadcast they are “good,” that they are willing to do evil things to stage their “… https://t.co/xEwAm9xH6h
# ----------------------------------
# *  Dan of @StanfordEd notes in one study how important it is to have students use their knowledge to predict so they c… https://t.co/ZDDrkkUeFs
# ----------------------------------
# *  RT @20002ist: @KimBhasin @LavishTantrums https://t.co/94ORmTPWz4
# ----------------------------------
# *  I was surprised gun deaths/injuries did not decline in 2020 - when so much of the country was in lockdown.
#
# In fact… https://t.co/ws2V3EQFag
# ----------------------------------
# *  Son interrupted online class today while I was lecturing. I asked if it was an emergency - he said “yes”; I hopped… https://t.co/DInd8nGoKr
# ----------------------------------
# *  Machine Learning Analytics: Understanding Data with Stories #MachineLearning @AkkioHQ https://t.co/IpYTxzG1Zr https://t.co/MAAfinLH2W
# ----------------------------------
# *  RT @PyTorch: v1.8.1 released with a few improvements and bug fixes. Highlights:
# - Autocast for PyTorch XLA
# - torch. submodule import more a…
# ----------------------------------
# *  Join @Formlabs – currently hiring for over 100 open roles in Berlin, Budapest, Boston, Ohio, North Carolina, Japan,… https://t.co/GGLJ0EPU1D
# ----------------------------------
# *  And build *robust* (convex) payoffs to be immune from statistical errors. https://t.co/qViBQLrVdt
# ----------------------------------
# *  #recall_memory Πηγή: Thanasis Triantafillou και το κατεβάζετε δωρεάν από εδώ: https://t.co/GnHFozLbrG
# ----------------------------------
# *  Και λόγω της ημέρας ψάχναμε το ελληνικό βιντεοπαιχνίδι «1821 Αγώνας για την Ελευθερία».
#
# Υπάρχει διαθέσιμο για δωρε… https://t.co/pHM5dt3EPU
# ----------------------------------

# %% [markdown]
# ### Example 2: Search tweets by key words
#
# **Twitter** employs a special query language.  For example, the query _"vacation?"_ will return tweets that contain the word "vacation" and are phrased as a question OR the query _"summer :)"_ will return the word "summer" with a positive attitude. [Check out more examples here](https://dev.twitter.com/rest/public/search).
#
# We can mine tweets using either **_search_** or **_stream_**.
#
# >The key difference between **_stream_** and **_search_** is that **_stream_** provides new data as it comes in, while **_search_** can be used to query old data. The **_search_** API is more powerful for queries, and provides faster access to a wide-range of data.
#
# Let's search for a single tweet about "vacation", phrased as a question. Note if request phrase contains URI characters you should [encode](https://en.wikipedia.org/wiki/Percent-encoding) these queries before making the request, because these characters can play role of keys in an URL. Particularly, the question mark "?" is encoded as "%3F".

# %%
import urllib

query = "stern,nyu"
encoded_query = urllib.parse.quote(query)

url_2 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + encoded_query
res = requests.get(url_2, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()
tweets
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=stern%2Cnyu
# {'search_metadata': {'completed_in': 0.11,
#   'count': 15,
#   'max_id': 1375153026575564809,
#   'max_id_str': '1375153026575564809',
#   'next_results': '?max_id=1374854130385219585&q=stern%2Cnyu&include_entities=1',
#   'query': 'stern%2Cnyu',
#   'refresh_url': '?since_id=1375153026575564809&q=stern%2Cnyu&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 18:30:05 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1375153026575564809',
#       'indices': [117, 140],
#       'url': 'https://t.co/Is928W5xqu'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375153026575564809,
#    'id_str': '1375153026575564809',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'text': 'Diagnose the change needs of your company with Professor Anat Lechner in Change Leadership on April 26 - 29! This p… https://t.co/Is928W5xqu',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 02 16:03:24 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'NYU Stern Executive Education programs are designed to have an immediate positive impact on performance, whether in leadership, strategy, finance or marketing.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'execed.stern.nyu.edu',
#         'expanded_url': 'http://execed.stern.nyu.edu',
#         'indices': [0, 22],
#         'url': 'http://t.co/3Mp1iB8X1G'}]}},
#     'favourites_count': 30,
#     'follow_request_sent': False,
#     'followers_count': 1097,
#     'following': False,
#     'friends_count': 151,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 173882135,
#     'id_str': '173882135',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'New York, NY',
#     'name': 'NYU Stern Executive Education',
#     'notifications': False,
#     'profile_background_color': '733973',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/173882135/1506445162',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/912724853689593859/fbgvhLa1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/912724853689593859/fbgvhLa1_normal.jpg',
#     'profile_link_color': '4C00B0',
#     'profile_sidebar_border_color': '5200B0',
#     'profile_sidebar_fill_color': 'ECC7FF',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'NYUSternExecEd',
#     'statuses_count': 737,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/3Mp1iB8X1G',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 17:10:49 +0000 2021',
#    'entities': {'hashtags': [{'indices': [18, 28], 'text': 'NYUOneDay'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 75307315,
#       'id_str': '75307315',
#       'indices': [3, 11],
#       'name': 'NYU Stern Undergrad',
#       'screen_name': 'SternUC'},
#      {'id': 28421825,
#       'id_str': '28421825',
#       'indices': [36, 49],
#       'name': 'New York University',
#       'screen_name': 'nyuniversity'},
#      {'id': 158378207,
#       'id_str': '158378207',
#       'indices': [106, 115],
#       'name': 'NYU Stern',
#       'screen_name': 'NYUStern'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375133079958925316,
#    'id_str': '1375133079958925316',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 13:18:34 +0000 2021',
#     'entities': {'hashtags': [{'indices': [5, 15], 'text': 'NYUOneDay'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1375074630826872832',
#        'indices': [117, 140],
#        'url': 'https://t.co/jxgYqkUyaC'}],
#      'user_mentions': [{'id': 28421825,
#        'id_str': '28421825',
#        'indices': [23, 36],
#        'name': 'New York University',
#        'screen_name': 'nyuniversity'},
#       {'id': 158378207,
#        'id_str': '158378207',
#        'indices': [93, 102],
#        'name': 'NYU Stern',
#        'screen_name': 'NYUStern'}]},
#     'favorite_count': 4,
#     'favorited': False,
#     'geo': None,
#     'id': 1375074630826872832,
#     'id_str': '1375074630826872832',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': "It's #NYUOneDay today, @nyuniversity's fifth annual 24-hour day of giving! \n\nPlease join the @NYUStern community to… https://t.co/jxgYqkUyaC",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Sep 18 15:29:51 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Official Twitter account of the @NYUStern School of Business Undergraduate College • #WeAreStern, no matter where we are in the world •',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'stern.nyu.edu/undergraduate',
#          'expanded_url': 'http://www.stern.nyu.edu/undergraduate',
#          'indices': [0, 23],
#          'url': 'https://t.co/KzkyrFdedS'}]}},
#      'favourites_count': 2364,
#      'follow_request_sent': False,
#      'followers_count': 4042,
#      'following': False,
#      'friends_count': 648,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 75307315,
#      'id_str': '75307315',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 105,
#      'location': 'New York City',
#      'name': 'NYU Stern Undergrad',
#      'notifications': False,
#      'profile_background_color': '482C7C',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75307315/1493835860',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/875383802872434689/QnL6t-jo_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875383802872434689/QnL6t-jo_normal.jpg',
#      'profile_link_color': '4A1F94',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'C9C9C9',
#      'profile_text_color': '140696',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'SternUC',
#      'statuses_count': 5914,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/KzkyrFdedS',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': "RT @SternUC: It's #NYUOneDay today, @nyuniversity's fifth annual 24-hour day of giving! \n\nPlease join the @NYUStern community to support st…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue May 26 19:12:39 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "We connect NYU's business, economics, and entrepreneurship communities with the information and data they need to change the world. Follow for new resources.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'guides.nyu.edu/vbl',
#         'expanded_url': 'https://guides.nyu.edu/vbl',
#         'indices': [0, 23],
#         'url': 'https://t.co/f6MAs3EHM0'}]}},
#     'favourites_count': 801,
#     'follow_request_sent': False,
#     'followers_count': 289,
#     'following': False,
#     'friends_count': 461,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 3299608731,
#     'id_str': '3299608731',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 10,
#     'location': 'New York City, USA',
#     'name': 'NYU Business Library',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3299608731/1567797912',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/603279996770091008/TRMx0wxX_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/603279996770091008/TRMx0wxX_normal.png',
#     'profile_link_color': '57068C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'BusinessLibNYU',
#     'statuses_count': 1225,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/f6MAs3EHM0',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 16:47:05 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1375127106007470081',
#       'indices': [117, 140],
#       'url': 'https://t.co/VXicF0qhWf'}],
#     'user_mentions': [{'id': 1323263510,
#       'id_str': '1323263510',
#       'indices': [0, 11],
#       'name': 'Naughty Mogwai',
#       'screen_name': 'jasonfrat1'},
#      {'id': 857726635465945088,
#       'id_str': '857726635465945088',
#       'indices': [12, 22],
#       'name': 'Nikki “That Labor Woman” Kateman',
#       'screen_name': 'nmkateman'},
#      {'id': 20793816,
#       'id_str': '20793816',
#       'indices': [23, 30],
#       'name': 'Amazon',
#       'screen_name': 'amazon'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375127106007470081,
#    'id_str': '1375127106007470081',
#    'in_reply_to_screen_name': 'jasonfrat1',
#    'in_reply_to_status_id': 1375123537808089090,
#    'in_reply_to_status_id_str': '1375123537808089090',
#    'in_reply_to_user_id': 1323263510,
#    'in_reply_to_user_id_str': '1323263510',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': '@jasonfrat1 @nmkateman @amazon He teaches Marketing at Stern School of Bussiness at NYU. His books are recent and e… https://t.co/VXicF0qhWf',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jan 12 21:38:16 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Functional med, HIIT, IF, Lp(a) LC🙃 Poli-Sci fan, WSMR, Diogenes Station MI6, Yoga gymnast, Good Trouble Enthusiast, #WorldofWeedNews stan, INFJ-T',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 2050,
#     'follow_request_sent': False,
#     'followers_count': 133,
#     'following': False,
#     'friends_count': 399,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1349108415763795970,
#     'id_str': '1349108415763795970',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': '',
#     'name': 'ThinkingOfAProfileNameRightNow',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1349108415763795970/1616088336',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1374844689719947268/f2sQC4SG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1374844689719947268/f2sQC4SG_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'LondonBarcelon2',
#     'statuses_count': 648,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 15:53:24 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 19546277,
#       'id_str': '19546277',
#       'indices': [3, 16],
#       'name': 'Yahoo Finance',
#       'screen_name': 'YahooFinance'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375113594774380545,
#    'id_str': '1375113594774380545',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 15:49:45 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1375112678260236289',
#        'indices': [119, 142],
#        'url': 'https://t.co/xqRJSZesg8'}],
#      'user_mentions': []},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 1375112678260236289,
#     'id_str': '1375112678260236289',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#     'text': "“This is really Kabuki theater,” NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity’ Author… https://t.co/xqRJSZesg8",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Jan 26 17:44:44 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The planet’s biggest business news platform: https://t.co/BRValVvylE\n\nGet the free Yahoo Finance app ⬇️',
#      'entities': {'description': {'urls': [{'display_url': 'finance.yahoo.com',
#          'expanded_url': 'https://finance.yahoo.com/',
#          'indices': [45, 68],
#          'url': 'https://t.co/BRValVvylE'}]},
#       'url': {'urls': [{'display_url': 'bit.ly/2CvQXU1',
#          'expanded_url': 'http://bit.ly/2CvQXU1',
#          'indices': [0, 23],
#          'url': 'https://t.co/3na8DjYVs3'}]}},
#      'favourites_count': 2964,
#      'follow_request_sent': False,
#      'followers_count': 1093124,
#      'following': False,
#      'friends_count': 297,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 19546277,
#      'id_str': '19546277',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 13806,
#      'location': 'New York, NY',
#      'name': 'Yahoo Finance',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19546277/1590010633',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#      'profile_link_color': '9266CC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '3F3F3F',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'YahooFinance',
#      'statuses_count': 282342,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/3na8DjYVs3',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "RT @YahooFinance: “This is really Kabuki theater,” NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity’ Author @profga…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Dec 26 14:54:01 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 145129,
#     'follow_request_sent': False,
#     'followers_count': 1826,
#     'following': False,
#     'friends_count': 4929,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2942221865,
#     'id_str': '2942221865',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 118,
#     'location': '',
#     'name': 'Diana L Bardsley',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2942221865/1435759416',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/617108716157054976/7xn-VPTn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617108716157054976/7xn-VPTn_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DianaBardsley',
#     'statuses_count': 169098,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 15:49:58 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 19546277,
#       'id_str': '19546277',
#       'indices': [3, 16],
#       'name': 'Yahoo Finance',
#       'screen_name': 'YahooFinance'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375112734531010560,
#    'id_str': '1375112734531010560',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 15:49:45 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1375112678260236289',
#        'indices': [119, 142],
#        'url': 'https://t.co/xqRJSZesg8'}],
#      'user_mentions': []},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 1375112678260236289,
#     'id_str': '1375112678260236289',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#     'text': "“This is really Kabuki theater,” NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity’ Author… https://t.co/xqRJSZesg8",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Jan 26 17:44:44 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The planet’s biggest business news platform: https://t.co/BRValVvylE\n\nGet the free Yahoo Finance app ⬇️',
#      'entities': {'description': {'urls': [{'display_url': 'finance.yahoo.com',
#          'expanded_url': 'https://finance.yahoo.com/',
#          'indices': [45, 68],
#          'url': 'https://t.co/BRValVvylE'}]},
#       'url': {'urls': [{'display_url': 'bit.ly/2CvQXU1',
#          'expanded_url': 'http://bit.ly/2CvQXU1',
#          'indices': [0, 23],
#          'url': 'https://t.co/3na8DjYVs3'}]}},
#      'favourites_count': 2964,
#      'follow_request_sent': False,
#      'followers_count': 1093124,
#      'following': False,
#      'friends_count': 297,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 19546277,
#      'id_str': '19546277',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 13806,
#      'location': 'New York, NY',
#      'name': 'Yahoo Finance',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19546277/1590010633',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#      'profile_link_color': '9266CC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '3F3F3F',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'YahooFinance',
#      'statuses_count': 282342,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/3na8DjYVs3',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': "RT @YahooFinance: “This is really Kabuki theater,” NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity’ Author @profga…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 25 19:09:02 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 35,
#     'follow_request_sent': False,
#     'followers_count': 248,
#     'following': False,
#     'friends_count': 2311,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 856948179996168192,
#     'id_str': '856948179996168192',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 3,
#     'location': '',
#     'name': 'Taizun Tapia',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'taizun_tapia',
#     'statuses_count': 102373,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 15:49:45 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1375112678260236289',
#       'indices': [119, 142],
#       'url': 'https://t.co/xqRJSZesg8'}],
#     'user_mentions': []},
#    'favorite_count': 6,
#    'favorited': False,
#    'geo': None,
#    'id': 1375112678260236289,
#    'id_str': '1375112678260236289',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#    'text': "“This is really Kabuki theater,” NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity’ Author… https://t.co/xqRJSZesg8",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jan 26 17:44:44 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The planet’s biggest business news platform: https://t.co/BRValVvylE\n\nGet the free Yahoo Finance app ⬇️',
#     'entities': {'description': {'urls': [{'display_url': 'finance.yahoo.com',
#         'expanded_url': 'https://finance.yahoo.com/',
#         'indices': [45, 68],
#         'url': 'https://t.co/BRValVvylE'}]},
#      'url': {'urls': [{'display_url': 'bit.ly/2CvQXU1',
#         'expanded_url': 'http://bit.ly/2CvQXU1',
#         'indices': [0, 23],
#         'url': 'https://t.co/3na8DjYVs3'}]}},
#     'favourites_count': 2964,
#     'follow_request_sent': False,
#     'followers_count': 1093124,
#     'following': False,
#     'friends_count': 297,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 19546277,
#     'id_str': '19546277',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 13806,
#     'location': 'New York, NY',
#     'name': 'Yahoo Finance',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19546277/1590010633',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1176105064219516928/qwU6ALZR_normal.png',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '3F3F3F',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'YahooFinance',
#     'statuses_count': 282342,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/3na8DjYVs3',
#     'utc_offset': None,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 13:18:34 +0000 2021',
#    'entities': {'hashtags': [{'indices': [5, 15], 'text': 'NYUOneDay'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1375074630826872832',
#       'indices': [117, 140],
#       'url': 'https://t.co/jxgYqkUyaC'}],
#     'user_mentions': [{'id': 28421825,
#       'id_str': '28421825',
#       'indices': [23, 36],
#       'name': 'New York University',
#       'screen_name': 'nyuniversity'},
#      {'id': 158378207,
#       'id_str': '158378207',
#       'indices': [93, 102],
#       'name': 'NYU Stern',
#       'screen_name': 'NYUStern'}]},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 1375074630826872832,
#    'id_str': '1375074630826872832',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': "It's #NYUOneDay today, @nyuniversity's fifth annual 24-hour day of giving! \n\nPlease join the @NYUStern community to… https://t.co/jxgYqkUyaC",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Sep 18 15:29:51 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Official Twitter account of the @NYUStern School of Business Undergraduate College • #WeAreStern, no matter where we are in the world •',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'stern.nyu.edu/undergraduate',
#         'expanded_url': 'http://www.stern.nyu.edu/undergraduate',
#         'indices': [0, 23],
#         'url': 'https://t.co/KzkyrFdedS'}]}},
#     'favourites_count': 2364,
#     'follow_request_sent': False,
#     'followers_count': 4042,
#     'following': False,
#     'friends_count': 648,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 75307315,
#     'id_str': '75307315',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 105,
#     'location': 'New York City',
#     'name': 'NYU Stern Undergrad',
#     'notifications': False,
#     'profile_background_color': '482C7C',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75307315/1493835860',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/875383802872434689/QnL6t-jo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875383802872434689/QnL6t-jo_normal.jpg',
#     'profile_link_color': '4A1F94',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C9C9C9',
#     'profile_text_color': '140696',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'SternUC',
#     'statuses_count': 5914,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/KzkyrFdedS',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 13:12:17 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 324443227,
#       'id_str': '324443227',
#       'indices': [3, 19],
#       'name': 'Paul M. Barrett',
#       'screen_name': 'AuthorPMBarrett'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375073051155517443,
#    'id_str': '1375073051155517443',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 26,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 23 11:35:32 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1374323926109683712',
#        'indices': [117, 140],
#        'url': 'https://t.co/dq6ifDy7xa'}],
#      'user_mentions': []},
#     'favorite_count': 52,
#     'favorited': False,
#     'geo': None,
#     'id': 1374323926109683712,
#     'id_str': '1374323926109683712',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 26,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for… https://t.co/dq6ifDy7xa',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Jun 26 16:40:29 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "Deputy Director, @NYUSternBHR. Former writer, @BW. Author, Law of the Jungle + Glock: The Rise of America's Gun. Married to @FilmmakerJulie. Dachshund fan.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bhr.stern.nyu.edu',
#          'expanded_url': 'http://bhr.stern.nyu.edu',
#          'indices': [0, 23],
#          'url': 'https://t.co/7OR3vMmLst'}]}},
#      'favourites_count': 7561,
#      'follow_request_sent': False,
#      'followers_count': 4300,
#      'following': False,
#      'friends_count': 2447,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 324443227,
#      'id_str': '324443227',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 129,
#      'location': 'Brooklyn, NY',
#      'name': 'Paul M. Barrett',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/324443227/1608062672',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AuthorPMBarrett',
#      'statuses_count': 3355,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/7OR3vMmLst',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jan 30 01:19:28 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Journalist. Feminist. Parent. Widower. Boyfriend. Reader. Prone to kindness, humor, and worry about our democracy.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 392,
#     'follow_request_sent': False,
#     'followers_count': 35,
#     'following': False,
#     'friends_count': 364,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 244740030,
#     'id_str': '244740030',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'Manhattan, NY',
#     'name': 'Eric Messinger',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/244740030/1575956432',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1204274673111969793/c7JQHmcU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204274673111969793/c7JQHmcU_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'PlacidlyAmid',
#     'statuses_count': 69,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 13:00:25 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1015589990967926784,
#       'id_str': '1015589990967926784',
#       'indices': [3, 17],
#       'name': 'アセマネ男子',
#       'screen_name': 'AsemaneDanshi'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375070065872134148,
#    'id_str': '1375070065872134148',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'ja',
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 13 04:30:15 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'amzn.to/2OR1Bev',
#        'expanded_url': 'https://amzn.to/2OR1Bev',
#        'indices': [106, 129],
#        'url': 'https://t.co/Fn0B1JbuBy'}],
#      'user_mentions': []},
#     'favorite_count': 7,
#     'favorited': False,
#     'geo': None,
#     'id': 1370593020786089984,
#     'id_str': '1370593020786089984',
#     'in_reply_to_screen_name': 'AsemaneDanshi',
#     'in_reply_to_status_id': 1370593019699720196,
#     'in_reply_to_status_id_str': '1370593019699720196',
#     'in_reply_to_user_id': 1015589990967926784,
#     'in_reply_to_user_id_str': '1015589990967926784',
#     'is_quote_status': False,
#     'lang': 'ja',
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'NYU Sternの名物教授、Scott Galloway氏の著作。\nGAFA4社がそれぞれ人の脳や本能、心や性器に訴えかけてビジネスを行っているという考え方が面白い。\n各社を俯瞰的に知るには良い書籍だと思う。\nhttps://t.co/Fn0B1JbuBy',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Jul 07 13:34:57 +0000 2018',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Investment Management/CFA\nInvestment Trusts/ETFs/HFs',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 634,
#      'follow_request_sent': False,
#      'followers_count': 4804,
#      'following': False,
#      'friends_count': 91,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1015589990967926784,
#      'id_str': '1015589990967926784',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 56,
#      'location': 'アセットマネジメントの世界',
#      'name': 'アセマネ男子',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015589990967926784/1531153815',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1016358360021590016/q0SX3zeH_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016358360021590016/q0SX3zeH_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AsemaneDanshi',
#      'statuses_count': 1629,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @AsemaneDanshi: NYU Sternの名物教授、Scott Galloway氏の著作。\nGAFA4社がそれぞれ人の脳や本能、心や性器に訴えかけてビジネスを行っているという考え方が面白い。\n各社を俯瞰的に知るには良い書籍だと思う。\nhttps://t.co/F…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jul 07 13:34:57 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Investment Management/CFA\nInvestment Trusts/ETFs/HFs',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 634,
#     'follow_request_sent': False,
#     'followers_count': 4804,
#     'following': False,
#     'friends_count': 91,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1015589990967926784,
#     'id_str': '1015589990967926784',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 56,
#     'location': 'アセットマネジメントの世界',
#     'name': 'アセマネ男子',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015589990967926784/1531153815',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1016358360021590016/q0SX3zeH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016358360021590016/q0SX3zeH_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AsemaneDanshi',
#     'statuses_count': 1629,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 10:09:44 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1375027108519501827',
#       'indices': [117, 140],
#       'url': 'https://t.co/yEuZJDTSP4'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1375027108519501827,
#    'id_str': '1375027108519501827',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': 'Registration has been extended until March 31st at 5pm ET. Please review our COVID-19 format changes and the primer… https://t.co/yEuZJDTSP4',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 07 04:20:43 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "The NYU Global Debates connect students, faculty, alumni and staff in an intellectual enterprise across all of NYU's campuses.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nyudb8.com/global-debate-…',
#         'expanded_url': 'http://www.nyudb8.com/global-debate-faq-1.html',
#         'indices': [0, 23],
#         'url': 'https://t.co/uuztfAiVTu'}]}},
#     'favourites_count': 6,
#     'follow_request_sent': False,
#     'followers_count': 43,
#     'following': False,
#     'friends_count': 88,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 806352715651620864,
#     'id_str': '806352715651620864',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'New York, USA',
#     'name': 'NYU Global Debate',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/806352715651620864/1481859447',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/806356021539209216/cjG355oO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806356021539209216/cjG355oO_normal.jpg',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'NYUGlobalDebate',
# ...
#     'id_str': '1310510516553515009',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'United Kingdom',
#     'name': 'UK Corporate Legal Scholars Association (UKCLA)',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1310510516553515009/1601285874',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1310514055417823233/rZHHa3VY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310514055417823233/rZHHa3VY_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'UKCLA1',
#     'statuses_count': 355,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 01:47:31 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 324443227,
#       'id_str': '324443227',
#       'indices': [3, 19],
#       'name': 'Paul M. Barrett',
#       'screen_name': 'AuthorPMBarrett'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1374900722484002816,
#    'id_str': '1374900722484002816',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 26,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 23 11:35:32 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1374323926109683712',
#        'indices': [117, 140],
#        'url': 'https://t.co/dq6ifDy7xa'}],
#      'user_mentions': []},
#     'favorite_count': 52,
#     'favorited': False,
#     'geo': None,
#     'id': 1374323926109683712,
#     'id_str': '1374323926109683712',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 26,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for… https://t.co/dq6ifDy7xa',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Jun 26 16:40:29 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "Deputy Director, @NYUSternBHR. Former writer, @BW. Author, Law of the Jungle + Glock: The Rise of America's Gun. Married to @FilmmakerJulie. Dachshund fan.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bhr.stern.nyu.edu',
#          'expanded_url': 'http://bhr.stern.nyu.edu',
#          'indices': [0, 23],
#          'url': 'https://t.co/7OR3vMmLst'}]}},
#      'favourites_count': 7561,
#      'follow_request_sent': False,
#      'followers_count': 4300,
#      'following': False,
#      'friends_count': 2447,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 324443227,
#      'id_str': '324443227',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 129,
#      'location': 'Brooklyn, NY',
#      'name': 'Paul M. Barrett',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/324443227/1608062672',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AuthorPMBarrett',
#      'statuses_count': 3355,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/7OR3vMmLst',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': 'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 15 17:29:38 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'It is difficult to free fools from the chains they revere. - Voltaire',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 12482,
#     'follow_request_sent': False,
#     'followers_count': 1662,
#     'following': False,
#     'friends_count': 1522,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 266706213,
#     'id_str': '266706213',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 94,
#     'location': 'Seditionist @SenMastriano 14:3',
#     'name': 'IamSauerKraut',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/266706213/1512688841',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1108713402317398017/EQLmEkfr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1108713402317398017/EQLmEkfr_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ImpeachBDevos',
#     'statuses_count': 241572,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 25 01:11:04 +0000 2021',
#    'entities': {'hashtags': [{'indices': [87, 94], 'text': 'execed'}],
#     'symbols': [],
#     'urls': [{'display_url': 'execed.economist.com/nyu-stern-scho…',
#       'expanded_url': 'https://execed.economist.com/nyu-stern-school-business/coding-r-data-2021-06-08?fsrc=twitter_tweetmachine',
#       'indices': [63, 86],
#       'url': 'https://t.co/uQ6VicBFBl'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1374891551382401024,
#    'id_str': '1374891551382401024',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://execed.economist.com/" rel="nofollow">ExecEd Navigator</a>',
#    'text': 'Improve your Business Analytics skills w/ Coding in R for Data https://t.co/uQ6VicBFBl #execed',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 14 19:47:45 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 246,
#     'following': False,
#     'friends_count': 0,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 720700085462528000,
#     'id_str': '720700085462528000',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 59,
#     'location': '',
#     'name': 'Econ Courses',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/720701486418784257/ScrgFKdc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720701486418784257/ScrgFKdc_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ExecEdCourses',
#     'statuses_count': 35803,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 24 22:42:22 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 324443227,
#       'id_str': '324443227',
#       'indices': [3, 19],
#       'name': 'Paul M. Barrett',
#       'screen_name': 'AuthorPMBarrett'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1374854130385219586,
#    'id_str': '1374854130385219586',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 26,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 23 11:35:32 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1374323926109683712',
#        'indices': [117, 140],
#        'url': 'https://t.co/dq6ifDy7xa'}],
#      'user_mentions': []},
#     'favorite_count': 52,
#     'favorited': False,
#     'geo': None,
#     'id': 1374323926109683712,
#     'id_str': '1374323926109683712',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 26,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for… https://t.co/dq6ifDy7xa',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Jun 26 16:40:29 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "Deputy Director, @NYUSternBHR. Former writer, @BW. Author, Law of the Jungle + Glock: The Rise of America's Gun. Married to @FilmmakerJulie. Dachshund fan.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bhr.stern.nyu.edu',
#          'expanded_url': 'http://bhr.stern.nyu.edu',
#          'indices': [0, 23],
#          'url': 'https://t.co/7OR3vMmLst'}]}},
#      'favourites_count': 7561,
#      'follow_request_sent': False,
#      'followers_count': 4300,
#      'following': False,
#      'friends_count': 2447,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 324443227,
#      'id_str': '324443227',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 129,
#      'location': 'Brooklyn, NY',
#      'name': 'Paul M. Barrett',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/324443227/1608062672',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/458933038710132736/IzFN7OU7_normal.jpeg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AuthorPMBarrett',
#      'statuses_count': 3355,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/7OR3vMmLst',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 22 18:49:49 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'No war No KKK No fascist USA @MomsDemand',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 53995,
#     'follow_request_sent': False,
#     'followers_count': 390,
#     'following': False,
#     'friends_count': 67,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 745690267752226816,
#     'id_str': '745690267752226816',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 7,
#     'location': 'Massachusetts, USA',
#     'name': 'Dr. Paula',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/745690267752226816/1607789687',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261412666729472001/AvN9Ii4h_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261412666729472001/AvN9Ii4h_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'drpaula65',
#     'statuses_count': 51831,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %% [markdown]
# Please pay attention on how much information each tweet contains.

# %%
# And let's see tweets text directly
for num, tweet in enumerate(tweets['statuses']):
    print('Tweet #{0}\t{1}\t{2}\n{3}\n'.format(num+1, tweet['created_at'], 
                                               tweet['retweet_count'], 
                                               tweet['text'].encode("utf-8")))
# Out:
# Tweet #1	Thu Mar 25 18:30:05 +0000 2021	0
# b'Diagnose the change needs of your company with Professor Anat Lechner in Change Leadership on April 26 - 29! This p\xe2\x80\xa6 https://t.co/Is928W5xqu'
#
# Tweet #2	Thu Mar 25 17:10:49 +0000 2021	1
# b"RT @SternUC: It's #NYUOneDay today, @nyuniversity's fifth annual 24-hour day of giving! \n\nPlease join the @NYUStern community to support st\xe2\x80\xa6"
#
# Tweet #3	Thu Mar 25 16:47:05 +0000 2021	0
# b'@jasonfrat1 @nmkateman @amazon He teaches Marketing at Stern School of Bussiness at NYU. His books are recent and e\xe2\x80\xa6 https://t.co/VXicF0qhWf'
#
# Tweet #4	Thu Mar 25 15:53:24 +0000 2021	3
# b"RT @YahooFinance: \xe2\x80\x9cThis is really Kabuki theater,\xe2\x80\x9d NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity\xe2\x80\x99 Author @profga\xe2\x80\xa6"
#
# Tweet #5	Thu Mar 25 15:49:58 +0000 2021	3
# b"RT @YahooFinance: \xe2\x80\x9cThis is really Kabuki theater,\xe2\x80\x9d NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity\xe2\x80\x99 Author @profga\xe2\x80\xa6"
#
# Tweet #6	Thu Mar 25 15:49:45 +0000 2021	3
# b"\xe2\x80\x9cThis is really Kabuki theater,\xe2\x80\x9d NYU Stern Marketing Professor &amp; 'Post Corona: From Crisis to Opportunity\xe2\x80\x99 Author\xe2\x80\xa6 https://t.co/xqRJSZesg8"
#
# Tweet #7	Thu Mar 25 13:18:34 +0000 2021	1
# b"It's #NYUOneDay today, @nyuniversity's fifth annual 24-hour day of giving! \n\nPlease join the @NYUStern community to\xe2\x80\xa6 https://t.co/jxgYqkUyaC"
#
# Tweet #8	Thu Mar 25 13:12:17 +0000 2021	26
# b'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu\xe2\x80\xa6'
#
# Tweet #9	Thu Mar 25 13:00:25 +0000 2021	1
# b'RT @AsemaneDanshi: NYU Stern\xe3\x81\xae\xe5\x90\x8d\xe7\x89\xa9\xe6\x95\x99\xe6\x8e\x88\xe3\x80\x81Scott Galloway\xe6\xb0\x8f\xe3\x81\xae\xe8\x91\x97\xe4\xbd\x9c\xe3\x80\x82\nGAFA4\n\xe5\x90\x84\xe7\xa4\xbe\xe3\x82\x92\xe4\xbf\xaf\xe7\x9e\xb0\xe7\x9a\x84\xe3\x81\xab\xe7\x9f\xa5\xe3\x82\x8b\xe3\x81\xab\xe3\x81\xaf\xe8\x89\xaf\xe3\x81\x84\xe6\x9b\xb8\xe7\xb1\x8d\xe3\x81\xa0\xe3\x81\xa8\xe6\x80\x9d\xe3\x81\x86\xe3\x80\x82\nhttps://t.co/F\xe2\x80\xa6'
#
# Tweet #10	Thu Mar 25 10:09:44 +0000 2021	0
# b'Registration has been extended until March 31st at 5pm ET. Please review our COVID-19 format changes and the primer\xe2\x80\xa6 https://t.co/yEuZJDTSP4'
#
# Tweet #11	Thu Mar 25 08:46:59 +0000 2021	0
# b'\xf0\x9f\x94\xb9 1300/1700: ECB Executive Board Member Isabel Schnabel will participate in a fireside chat at the NYU Stern online\xe2\x80\xa6 https://t.co/skuuUvh53C'
#
# Tweet #12	Thu Mar 25 06:18:43 +0000 2021	26
# b'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu\xe2\x80\xa6'
#
# Tweet #13	Thu Mar 25 01:47:31 +0000 2021	26
# b'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu\xe2\x80\xa6'
#
# Tweet #14	Thu Mar 25 01:11:04 +0000 2021	0
# b'Improve your Business Analytics skills w/ Coding in R for Data https://t.co/uQ6VicBFBl #execed'
#
# Tweet #15	Wed Mar 24 22:42:22 +0000 2021	26
# b'RT @AuthorPMBarrett: New recommendations to the Biden Administration on reducing disinformation -- just released by NYU Stern Center for Bu\xe2\x80\xa6'

# %%
import pandas as pd
df = pd.DataFrame(tweets['statuses'])
df
# Out:
#                         created_at  ...                                   retweeted_status
# 0   Thu Mar 25 18:30:05 +0000 2021  ...                                                NaN
# 1   Thu Mar 25 17:10:49 +0000 2021  ...  {'created_at': 'Thu Mar 25 13:18:34 +0000 2021...
# 2   Thu Mar 25 16:47:05 +0000 2021  ...                                                NaN
# 3   Thu Mar 25 15:53:24 +0000 2021  ...  {'created_at': 'Thu Mar 25 15:49:45 +0000 2021...
# 4   Thu Mar 25 15:49:58 +0000 2021  ...  {'created_at': 'Thu Mar 25 15:49:45 +0000 2021...
# 5   Thu Mar 25 15:49:45 +0000 2021  ...                                                NaN
# 6   Thu Mar 25 13:18:34 +0000 2021  ...                                                NaN
# 7   Thu Mar 25 13:12:17 +0000 2021  ...  {'created_at': 'Tue Mar 23 11:35:32 +0000 2021...
# 8   Thu Mar 25 13:00:25 +0000 2021  ...  {'created_at': 'Sat Mar 13 04:30:15 +0000 2021...
# 9   Thu Mar 25 10:09:44 +0000 2021  ...                                                NaN
# 10  Thu Mar 25 08:46:59 +0000 2021  ...                                                NaN
# 11  Thu Mar 25 06:18:43 +0000 2021  ...  {'created_at': 'Tue Mar 23 11:35:32 +0000 2021...
# 12  Thu Mar 25 01:47:31 +0000 2021  ...  {'created_at': 'Tue Mar 23 11:35:32 +0000 2021...
# 13  Thu Mar 25 01:11:04 +0000 2021  ...                                                NaN
# 14  Wed Mar 24 22:42:22 +0000 2021  ...  {'created_at': 'Tue Mar 23 11:35:32 +0000 2021...
#
# [15 rows x 26 columns]

# %% [markdown]
# ##### A small diversion: The `json_normalize` function in Pandas

# %%
mylist = [
    {"FullName": {
            "Given": {
                "First": "Panos", 
                "Middle": "Gregory"
            }, 
            "Family": "Ipeirotis"
        }, 
     "Age": 40
    },
    {"FullName": {
            "Given": {
                "First": "John", 
                "Middle": "Reuben"
            }, 
            "Family": "Smith"
        }, 
     "Age": 25
    },
    {"FullName": {
            "Given": {
                "First": "Jane", 
                "Middle": "Janet"
            }, 
            "Family": "Smith"}, 
     "Age": 22
    }
]

df_test = pd.DataFrame(mylist)
df_test
# Out:
#                                             FullName  Age
# 0  {'Given': {'First': 'Panos', 'Middle': 'Gregor...   40
# 1  {'Given': {'First': 'John', 'Middle': 'Reuben'...   25
# 2  {'Given': {'First': 'Jane', 'Middle': 'Janet'}...   22

# %%
from pandas.io.json import json_normalize
df_test_normalized = json_normalize(mylist)
df_test_normalized
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#    Age FullName.Given.First FullName.Given.Middle FullName.Family
# 0   40                Panos               Gregory       Ipeirotis
# 1   25                 John                Reuben           Smith
# 2   22                 Jane                 Janet           Smith

# %% [markdown]
# ##### end of diversion... and using the function to make our JSON results more readable

# %%
# If we want to flatten the nested JSON entries
# we can use the json_normalize function
# http://pandas-docs.github.io/pandas-docs-travis/io.html#normalization
import pandas as pd
from pandas.io.json import json_normalize
df_flat = json_normalize(tweets['statuses'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# You may create very specialized and more concrete queries.
#
# Let's find 5 tweets that contains the word "python" or "IPython" near New York. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language). Additional parameters allows build very complicated search requests.

# %%
url_2_2 = 'https://api.twitter.com/1.1/search/tweets.json'

params = {
    "count": 10, 
    "geocode": '40.7127,-74.0059,15mi',
    "lang": 'en',
    "q": 'python'
}

res = requests.get(url_2_2, auth=auth, params=params)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()

for num, tweet in enumerate(tweets['statuses']):
    print("-----------------------------")
    print('Tweet )#{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8")))
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?count=10&geocode=40.7127%2C-74.0059%2C15mi&lang=en&q=python
# -----------------------------
# Tweet )#1	Thu Mar 25 20:30:45 +0000 2021
# b"RT @Paula_Piccard: Facebook's Neural Wristband Could Replace Keyboards https://t.co/1uKpg57Wt0\n\n#MachineLearning #Python #AI #100DaysOfCode\xe2\x80\xa6"
#
# -----------------------------
# Tweet )#2	Thu Mar 25 20:29:46 +0000 2021
# b"RT @Paula_Piccard: Facebook's Neural Wristband Could Replace Keyboards https://t.co/1uKpg57Wt0\n\n#MachineLearning #Python #AI #100DaysOfCode\xe2\x80\xa6"
#
# -----------------------------
# Tweet )#3	Thu Mar 25 20:29:30 +0000 2021
# b"RT @Paula_Piccard: Facebook's Neural Wristband Could Replace Keyboards https://t.co/1uKpg57Wt0\n\n#MachineLearning #Python #AI #100DaysOfCode\xe2\x80\xa6"
#
# -----------------------------
# Tweet )#4	Thu Mar 25 20:29:24 +0000 2021
# b"RT @Paula_Piccard: Facebook's Neural Wristband Could Replace Keyboards https://t.co/1uKpg57Wt0\n\n#MachineLearning #Python #AI #100DaysOfCode\xe2\x80\xa6"
#
# -----------------------------
# Tweet )#5	Thu Mar 25 20:28:48 +0000 2021
# b'RT @writerbayinc: Kindly DM us for your \n#Essay\n#Course work\n#Project\n#Pay write\n#econometrics\n#Paperpay\n#Someone help paper\n#Case study\n#j\xe2\x80\xa6'
#
# -----------------------------
# Tweet )#6	Thu Mar 25 20:28:43 +0000 2021
# b'RT @writerbayinc: Kindly DM us for your \n#Essay\n#Course work\n#Project\n#Pay write\n#econometrics\n#Paperpay\n#Someone help paper\n#Case study\n#j\xe2\x80\xa6'
#
# -----------------------------
# Tweet )#7	Thu Mar 25 20:28:39 +0000 2021
# b'RT @writerbayinc: Pay me to do your;\n#Paper\n#python\n#homeworkdue \n#chemistry\n#Onlineclass\n#Essaypay\n#Econometrics\n#Statistics\n#homework\n#es\xe2\x80\xa6'
#
# -----------------------------
# Tweet )#8	Thu Mar 25 20:28:37 +0000 2021
# b'Kindly DM us for your \n#Essay\n#Course work\n#Project\n#Pay write\n#econometrics\n#Paperpay\n#Someone help paper\n#Case st\xe2\x80\xa6 https://t.co/9fa8Lbhybz'
#
# -----------------------------
# Tweet )#9	Thu Mar 25 20:28:24 +0000 2021
# b'RT @writerbayinc: Pay me to do your;\n#Paper\n#python\n#homeworkdue \n#chemistry\n#Onlineclass\n#Essaypay\n#Econometrics\n#Statistics\n#homework\n#es\xe2\x80\xa6'
#
# -----------------------------
# Tweet )#10	Thu Mar 25 20:28:19 +0000 2021
# b'Pay me to do your;\n#Paper\n#python\n#homeworkdue \n#chemistry\n#Onlineclass\n#Essaypay\n#Econometrics\n#Statistics\xe2\x80\xa6 https://t.co/38KesPctz5'

# %% [markdown]
# ### Example 3: Get a list of all your followers
#
# **Twitter** GET request `followers/list` returns a cursored collection of user objects for users following the specified user. At this time, results are ordered with the most recent following first.

# %%
url_3 = 'https://api.twitter.com/1.1/followers/list.json'
res = requests.get(url_3, auth=auth)
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
followers
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/followers/list.json
# {'next_cursor': 1691782656765190526,
#  'next_cursor_str': '1691782656765190526',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None,
#  'users': [{'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Mon Sep 28 08:14:50 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Professor at @NYUStern. Fmr CEO/Board director of Kakao, a $20B+ tech company. Fmr founder/CEO of Kcube Ventures',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'stern.nyu.edu/faculty/bio/ji…',
#        'expanded_url': 'http://www.stern.nyu.edu/faculty/bio/jihoon-rim',
#        'indices': [0, 23],
#        'url': 'https://t.co/BCfa0BkSj4'}]}},
#    'favourites_count': 693,
#    'follow_request_sent': False,
#    'followers_count': 1659,
#    'following': False,
#    'friends_count': 495,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 3712690760,
#    'id_str': '3712690760',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 23,
#    'live_following': False,
#    'location': 'New York, NY',
#    'muting': False,
#    'name': 'Jihoon Rim',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3712690760/1600190230',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1181885272490958848/7Gsd1Vj7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1181885272490958848/7Gsd1Vj7_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'jihoonrim',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 11 02:09:39 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1369832862825013254',
#        'indices': [117, 140],
#        'url': 'https://t.co/NR8Jwklj7F'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1369832862825013254,
#     'id_str': '1369832862825013254',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-73.9960116519078, 40.72912812259763],
#         [-73.9960116519078, 40.72912812259763],
#         [-73.9960116519078, 40.72912812259763],
#         [-73.9960116519078, 40.72912812259763]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United States',
#      'country_code': 'US',
#      'full_name': 'NYU Stern School of Business',
#      'id': '07d9c97e08c86000',
#      'name': 'NYU Stern School of Business',
#      'place_type': 'poi',
#      'url': 'https://api.twitter.com/1.1/geo/id/07d9c97e08c86000.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Thank you so much Patrick Chun for joining my class today. My students were grateful to learn about Juxtapose’s uni… https://t.co/NR8Jwklj7F',
#     'truncated': True},
#    'statuses_count': 308,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/BCfa0BkSj4',
#    'utc_offset': None,
#    'verified': True},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Sun Dec 20 23:45:03 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Siyaseten agnostiğim.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 234,
#    'follow_request_sent': False,
#    'followers_count': 107,
#    'following': False,
#    'friends_count': 661,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 98232263,
#    'id_str': '98232263',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 4,
#    'live_following': False,
#    'location': 'Istanbul',
#    'muting': False,
#    'name': 'Raad Adam',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/98232263/1408832790',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/503309272394895360/R_FOOej0_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/503309272394895360/R_FOOej0_normal.jpeg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'labisakin',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 24 13:30:47 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 361606857,
#        'id_str': '361606857',
#        'indices': [0, 13],
#        'name': 'es',
#        'screen_name': 'iyidirsenden'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1374715317658730498,
#     'id_str': '1374715317658730498',
#     'in_reply_to_screen_name': 'iyidirsenden',
#     'in_reply_to_status_id': 1374712739755614211,
#     'in_reply_to_status_id_str': '1374712739755614211',
#     'in_reply_to_user_id': 361606857,
#     'in_reply_to_user_id_str': '361606857',
#     'is_quote_status': False,
#     'lang': 'tr',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': '@iyidirsenden ... Köylüler diğer yolun ayı inine çıktığını biliyor olmalılar. Ayı beni yerken etrafta kimse olmamasından anladım.',
#     'truncated': False},
#    'statuses_count': 701,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Mon Jun 09 02:20:52 +0000 2008',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Project Officer at @kmiou. Interested in text-mining and open data, loves #datavis and #soccermatics',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 118,
#    'follow_request_sent': False,
#    'followers_count': 155,
#    'following': False,
#    'friends_count': 624,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 15052750,
#    'id_str': '15052750',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 5,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'anastluc',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/447278641/profile_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/447278641/profile_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'anastluc',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Feb 21 22:03:52 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1363610416216178694',
#        'indices': [116, 139],
#        'url': 'https://t.co/3vpnzqu9ey'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1363610416216178694,
#     'id_str': '1363610416216178694',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': True,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'quoted_status_id': 1363530540092186627,
#     'quoted_status_id_str': '1363530540092186627',
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'I agree. It tries to overwhelm but instead it just diminishes each individual to a single dot and the overall to a… https://t.co/3vpnzqu9ey',
#     'truncated': True},
#    'statuses_count': 415,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Sun Jun 07 08:43:13 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Indian based in Japan. Consultant, coach and investor by profession. Tweets are personal and on matters of interest.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/nuleti',
#        'expanded_url': 'http://linkedin.com/in/nuleti',
#        'indices': [0, 23],
#        'url': 'https://t.co/BiFmwa5Eo9'}]}},
#    'favourites_count': 5,
#    'follow_request_sent': False,
#    'followers_count': 31,
#    'following': False,
#    'friends_count': 495,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1269550432021434369,
#    'id_str': '1269550432021434369',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': 'Tokyo',
#    'muting': False,
#    'name': 'John Nuleti 🇮🇳🇯🇵',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269550432021434369/1616235333',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1325005471812448256/oLubvoqW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1325005471812448256/oLubvoqW_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'johnnuleti',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 04:15:37 +0000 2021',
#     'entities': {'hashtags': [{'indices': [67, 77], 'text': 'Tokyo2020'},
#       {'indices': [78, 92], 'text': 'TokyoOlympics'},
#       {'indices': [93, 111], 'text': 'OlympicTorchRelay'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1374937992830185477,
#     'id_str': '1374937992830185477',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'Olympics torch relay began today at Fukushima on its way to Tokyo. #Tokyo2020 #TokyoOlympics #OlympicTorchRelay',
#     'truncated': False},
#    'statuses_count': 304,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/BiFmwa5Eo9',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Tue Mar 09 03:24:52 +0000 2021',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Virtual Seminar Series on Central Banking and Digital Currencies (CB&DC)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'cbanddc.net',
#        'expanded_url': 'http://cbanddc.net',
#        'indices': [0, 23],
#        'url': 'https://t.co/QuM1VvNTtK'}]}},
#    'favourites_count': 1,
#    'follow_request_sent': False,
#    'followers_count': 178,
#    'following': False,
#    'friends_count': 808,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1369126898542993409,
#    'id_str': '1369126898542993409',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'CB&DC',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1369126898542993409/1615263392',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369128595579432968/3TvtCHMf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369128595579432968/3TvtCHMf_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CBandDC',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Mar 19 01:41:43 +0000 2021',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/JynylVaa63',
#        'expanded_url': 'https://twitter.com/CBandDC/status/1372724936641540099/photo/1',
#        'id': 1372724933139259394,
#        'id_str': '1372724933139259394',
#        'indices': [27, 50],
#        'media_url': 'http://pbs.twimg.com/media/EwzmDb4WYAIZMA4.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EwzmDb4WYAIZMA4.jpg',
#        'sizes': {'large': {'h': 750, 'resize': 'fit', 'w': 1334},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 382, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/JynylVaa63'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/JynylVaa63',
#        'expanded_url': 'https://twitter.com/CBandDC/status/1372724936641540099/photo/1',
#        'id': 1372724933139259394,
#        'id_str': '1372724933139259394',
#        'indices': [27, 50],
#        'media_url': 'http://pbs.twimg.com/media/EwzmDb4WYAIZMA4.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EwzmDb4WYAIZMA4.jpg',
#        'sizes': {'large': {'h': 750, 'resize': 'fit', 'w': 1334},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 382, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/JynylVaa63'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1372724936641540099,
#     'id_str': '1372724936641540099',
#     'in_reply_to_screen_name': 'CBandDC',
#     'in_reply_to_status_id': 1372724593924923398,
#     'in_reply_to_status_id_str': '1372724593924923398',
#     'in_reply_to_user_id': 1369126898542993409,
#     'in_reply_to_user_id_str': '1369126898542993409',
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '... moderated by Jon Frost https://t.co/JynylVaa63',
#     'truncated': False},
#    'statuses_count': 6,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/QuM1VvNTtK',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Wed Feb 06 21:49:36 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'uComp develops a generic human computation framework for knowledge extraction, delegating tough tasks to users and continuously learning from their feedback.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'ucomp.eu',
#        'expanded_url': 'http://www.ucomp.eu/',
#        'indices': [0, 20],
#        'url': 'http://t.co/o4D4ah39'}]}},
#    'favourites_count': 218,
#    'follow_request_sent': False,
#    'followers_count': 173,
#    'following': False,
#    'friends_count': 195,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 1155202766,
#    'id_str': '1155202766',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 20,
#    'live_following': False,
#    'location': 'Europe',
#    'muting': False,
#    'name': 'uComp Project',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3383511712/d77f446ec4ca9897ee00aa60a13ec861_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3383511712/d77f446ec4ca9897ee00aa60a13ec861_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'uCompEU',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 09 20:46:01 +0000 2021',
#     'entities': {'hashtags': [{'indices': [102, 115], 'text': 'DeepLearning'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 17421698,
#        'id_str': '17421698',
#        'indices': [3, 13],
#        'name': 'webLyzard technology',
#        'screen_name': 'webLyzard'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1369389029641293830,
#     'id_str': '1369389029641293830',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'retweet_count': 13,
#     'retweeted': False,
#     'retweeted_status': {'contributors': None,
#      'coordinates': None,
#      'created_at': 'Tue Mar 09 09:20:27 +0000 2021',
#      'entities': {'hashtags': [{'indices': [87, 100], 'text': 'DeepLearning'}],
#       'symbols': [],
#       'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#         'expanded_url': 'https://twitter.com/i/web/status/1369216501367119872',
#         'indices': [117, 140],
#         'url': 'https://t.co/KTAE9JnDrW'}],
#       'user_mentions': []},
#      'favorite_count': 5,
#      'favorited': False,
#      'geo': None,
#      'id': 1369216501367119872,
#      'id_str': '1369216501367119872',
#      'in_reply_to_screen_name': None,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'is_quote_status': False,
#      'lang': 'en',
#      'place': None,
#      'possibly_sensitive': False,
#      'retweet_count': 13,
#      'retweeted': False,
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'text': 'We are Hiring 👩\u200d💻 Join Our Team as a Researcher and Software Developer with a Focus on #DeepLearning for Text and I… https://t.co/KTAE9JnDrW',
#      'truncated': True},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'RT @webLyzard: We are Hiring 👩\u200d💻 Join Our Team as a Researcher and Software Developer with a Focus on #DeepLearning for Text and Impact Opt…',
#     'truncated': False},
#    'statuses_count': 193,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/o4D4ah39',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Sat Aug 28 06:21:13 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Dad, loves gardening, photography, acting , Social & Solidarity economy, Deep Adaptation on Climate emergency. In a self realization path...Godless Ape',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'about.me/kirgidis',
#        'expanded_url': 'http://about.me/kirgidis',
#        'indices': [0, 22],
#        'url': 'http://t.co/pCE9YLCpWf'}]}},
#    'favourites_count': 4303,
#    'follow_request_sent': False,
#    'followers_count': 298,
#    'following': False,
#    'friends_count': 372,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 183923045,
#    'id_str': '183923045',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 15,
#    'live_following': False,
#    'location': 'Thessaloniki',
#    'muting': False,
#    'name': 'Thalassis Yorgos',
#    'notifications': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/183923045/1450377147',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/674159352434040832/YDPhs--o_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/674159352434040832/YDPhs--o_normal.jpg',
#    'profile_link_color': '0000FF',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'F0EAEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'kirgidis',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 16 21:10:44 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 1191441760385470467,
#        'id_str': '1191441760385470467',
#        'indices': [0, 10],
#        'name': '🥇ProfessorAstrones🥇',
#        'screen_name': 'Astrones2'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1371931965776093188,
#     'id_str': '1371931965776093188',
#     'in_reply_to_screen_name': 'Astrones2',
#     'in_reply_to_status_id': 1371889491586191364,
#     'in_reply_to_status_id_str': '1371889491586191364',
#     'in_reply_to_user_id': 1191441760385470467,
#     'in_reply_to_user_id_str': '1191441760385470467',
#     'is_quote_status': False,
#     'lang': 'fr',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': '@Astrones2 Vacations',
#     'truncated': False},
#    'statuses_count': 3959,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/pCE9YLCpWf',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Tue Jun 02 13:38:29 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 9,
#    'follow_request_sent': False,
#    'followers_count': 0,
#    'following': False,
#    'friends_count': 47,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1267812752673828865,
#    'id_str': '1267812752673828865',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': 'Beijing ,China',
#    'muting': False,
#    'name': 'Masud Talukdar',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267812752673828865/1591107992',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1319998597472030720/F6jv0QMb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319998597472030720/F6jv0QMb_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'masud_talukdar7',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Mar 07 12:58:38 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 262387823,
#        'id_str': '262387823',
#        'indices': [0, 10],
#        'name': 'Ihab Ilyas',
#        'screen_name': 'ihabilyas'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1368546633860997122,
#     'id_str': '1368546633860997122',
#     'in_reply_to_screen_name': 'ihabilyas',
#     'in_reply_to_status_id': 1349396487776706560,
#     'in_reply_to_status_id_str': '1349396487776706560',
#     'in_reply_to_user_id': 262387823,
#     'in_reply_to_user_id_str': '262387823',
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': '@ihabilyas Congratulations Prof.',
#     'truncated': False},
#    'statuses_count': 8,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Mon May 04 16:59:20 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'the laws of physics are merely a suggestion | complexity & society @redcompleja',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'jrncarlock.github.io',
#        'expanded_url': 'https://jrncarlock.github.io/',
#        'indices': [0, 23],
#        'url': 'https://t.co/w9OYdHLoz6'}]}},
#    'favourites_count': 6387,
#    'follow_request_sent': False,
#    'followers_count': 848,
#    'following': False,
#    'friends_count': 1088,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3185442680,
#    'id_str': '3185442680',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 15,
#    'live_following': False,
#    'location': 'earth',
#    'muting': False,
#    'name': 'jrnc',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3185442680/1523997745',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1358177740092960768/14X2pftu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1358177740092960768/14X2pftu_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'jrncarlock',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 20:26:17 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 253151846,
#        'id_str': '253151846',
#        'indices': [0, 12],
#        'name': 'mariana m',
#        'screen_name': 'marianamf84'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1375182269980286980,
#     'id_str': '1375182269980286980',
#     'in_reply_to_screen_name': 'marianamf84',
#     'in_reply_to_status_id': 1375162158946906119,
#     'in_reply_to_status_id_str': '1375162158946906119',
#     'in_reply_to_user_id': 253151846,
#     'in_reply_to_user_id_str': '253151846',
#     'is_quote_status': False,
#     'lang': 'und',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '@marianamf84 💯',
#     'truncated': False},
#    'statuses_count': 5058,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/w9OYdHLoz6',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Tue Mar 01 03:59:07 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'The Matrix Project. Global Knowledge Network. Knowledge is language.™',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'vk.com/american_engli…',
#        'expanded_url': 'https://vk.com/american_english_center',
#        'indices': [0, 23],
#        'url': 'https://t.co/G1yof2Cnsj'}]}},
#    'favourites_count': 894,
#    'follow_request_sent': False,
#    'followers_count': 1251,
#    'following': False,
#    'friends_count': 5003,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 704516289197449216,
#    'id_str': '704516289197449216',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 16,
#    'live_following': False,
#    'location': 'Ekaterinburg, Russia',
#    'muting': False,
#    'name': 'Michael Molin',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/704516289197449216/1512537821',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291766443470737411/qhjBO4QU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291766443470737411/qhjBO4QU_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thematrixcom',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 24 15:53:31 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1374751239163023361',
#        'indices': [117, 140],
#        'url': 'https://t.co/ecwuyzY7gm'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1374751239163023361,
#     'id_str': '1374751239163023361',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': '“You never change things by fighting the existing reality. To change something, build a new model that makes the ex… https://t.co/ecwuyzY7gm',
#     'truncated': True},
#    'statuses_count': 1744,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/G1yof2Cnsj',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Wed Sep 21 23:57:13 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Clinical Associate Professor of Entrepreneurship & Academic Director of BTE @NYUStern #Entrepreneurship #Innovation #DadJokes • https://t.co/M8vPhC89fd •',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/38EySj5',
#        'expanded_url': 'http://bit.ly/38EySj5',
#        'indices': [128, 151],
#        'url': 'https://t.co/M8vPhC89fd'}]},
#     'url': {'urls': [{'display_url': 'ashishkbhatia.com',
#        'expanded_url': 'http://ashishkbhatia.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/P3f7plJtHK'}]}},
#    'favourites_count': 2696,
#    'follow_request_sent': False,
#    'followers_count': 385,
#    'following': False,
#    'friends_count': 1129,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 377696554,
#    'id_str': '377696554',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 17,
#    'live_following': False,
#    'location': 'New Jersey, USA',
#    'muting': False,
#    'name': 'Ashish K. Bhatia',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/377696554/1530535346',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1224514897498791936/wS_q9aPH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1224514897498791936/wS_q9aPH_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AshishKBhatia',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 11:46:51 +0000 2021',
#     'entities': {'hashtags': [{'indices': [7, 14], 'text': 'Yesday'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1375051551002218498',
#        'indices': [116, 139],
#        'url': 'https://t.co/H3mrL47xdz'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1375051551002218498,
#     'id_str': '1375051551002218498',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'We did #Yesday I also enjoyed leaving balance by the wayside-pancakes for breakfast, donuts for lunch, and brownie… https://t.co/H3mrL47xdz',
#     'truncated': True},
#    'statuses_count': 515,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/P3f7plJtHK',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Mon May 07 12:10:52 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Doctoral candidate- IIM Bangalore. I study decision making and consumer behaviour.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1390,
#    'follow_request_sent': False,
#    'followers_count': 88,
#    'following': False,
#    'friends_count': 463,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 573584768,
#    'id_str': '573584768',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'Parvathy',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1057976473351446529/aPEdF8xU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1057976473351446529/aPEdF8xU_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Parvathyb21',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Mar 19 11:55:32 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 469232894,
#        'id_str': '469232894',
#        'indices': [3, 16],
#        'name': 'Gilad Feldman',
#        'screen_name': 'giladfeldman'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1372879408923435016,
#     'id_str': '1372879408923435016',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': True,
#     'lang': 'en',
#     'place': None,
#     'quoted_status_id': 1363748403667083266,
#     'quoted_status_id_str': '1363748403667083266',
#     'retweet_count': 5,
#     'retweeted': False,
#     'retweeted_status': {'contributors': None,
#      'coordinates': None,
#      'created_at': 'Fri Mar 19 09:49:39 +0000 2021',
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#         'expanded_url': 'https://twitter.com/i/web/status/1372847726958813189',
#         'indices': [117, 140],
#         'url': 'https://t.co/U2qXpt2lIZ'}],
#       'user_mentions': []},
#      'favorite_count': 6,
#      'favorited': False,
#      'geo': None,
#      'id': 1372847726958813189,
#      'id_str': '1372847726958813189',
#      'in_reply_to_screen_name': None,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'is_quote_status': True,
#      'lang': 'en',
#      'place': None,
#      'possibly_sensitive': False,
#      'quoted_status_id': 1363748403667083266,
#      'quoted_status_id_str': '1363748403667083266',
#      'retweet_count': 5,
#      'retweeted': False,
#      'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      'text': "Upcoming on Monday, March 22nd. Register and join me, if you're interested. Feel free to pass along to others who m… https://t.co/U2qXpt2lIZ",
#      'truncated': True},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "RT @giladfeldman: Upcoming on Monday, March 22nd. Register and join me, if you're interested. Feel free to pass along to others who might b…",
#     'truncated': False},
#    'statuses_count': 196,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Tue Mar 04 17:56:42 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#AI Systems = Code + Data. A brain is not a computer, language is not thought, & souls are BS. #MachineLearning #Deeplearning #Mindscience #Atheism',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'instagram.com/brydgreg/',
#        'expanded_url': 'https://www.instagram.com/brydgreg/',
#        'indices': [0, 23],
#        'url': 'https://t.co/q1uNOwtskv'}]}},
#    'favourites_count': 6485,
#    'follow_request_sent': False,
#    'followers_count': 285,
#    'following': False,
#    'friends_count': 3614,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2372232535,
#    'id_str': '2372232535',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 4,
#    'live_following': False,
#    'location': 'Boston, MA',
#    'muting': False,
#    'name': 'Bryan Gregor',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2372232535/1612569478',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/823354340463312896/dDIIN8ck_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/823354340463312896/dDIIN8ck_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': True,
#    'screen_name': 'bryandgregor',
#    'statuses_count': 1206,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/q1uNOwtskv',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Wed Oct 12 03:43:02 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 5447,
#    'follow_request_sent': False,
#    'followers_count': 49,
#    'following': False,
#    'friends_count': 503,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 389262562,
#    'id_str': '389262562',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'JF',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757771286072274944/ozD913Y-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757771286072274944/ozD913Y-_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JeremyFenwick',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Sep 03 02:43:02 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1036444429236625408',
#        'indices': [116, 139],
#        'url': 'https://t.co/5QnqkPtwm6'}],
#      'user_mentions': [{'id': 20481521,
#        'id_str': '20481521',
#        'indices': [37, 43],
#        'name': 'Kogan.com',
#        'screen_name': 'Kogan'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1036444429236625408,
#     'id_str': '1036444429236625408',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'Well, I purchased a Surface Pro from @Kogan almost two months ago that was defective and they will neither replace… https://t.co/5QnqkPtwm6',
#     'truncated': True},
#    'statuses_count': 6,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Thu Aug 10 12:04:28 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '\u200e\u200ebla bla bla',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 9787,
#    'follow_request_sent': False,
#    'followers_count': 160,
#    'following': False,
#    'friends_count': 991,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 895616839006531584,
#    'id_str': '895616839006531584',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': 'Cairo, Egypt',
#    'muting': False,
#    'name': 'Mohamed Abdallah',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/895616839006531584/1601827751',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1345938990638231552/5B1amHIg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1345938990638231552/5B1amHIg_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '7ammo20',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 24 00:08:31 +0000 2021',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/L8ZrV0DoVg',
#        'expanded_url': 'https://twitter.com/HumansNoContext/status/1374424093185904656/photo/1',
#        'id': 1374424086261108737,
#        'id_str': '1374424086261108737',
#        'indices': [21, 44],
#        'media_url': 'http://pbs.twimg.com/media/ExLvbKhVkAEuqio.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ExLvbKhVkAEuqio.jpg',
#        'sizes': {'large': {'h': 894, 'resize': 'fit', 'w': 1284},
#         'medium': {'h': 836, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 473, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'source_status_id': 1374424093185904656,
#        'source_status_id_str': '1374424093185904656',
#        'source_user_id': 855300206086168576,
#        'source_user_id_str': '855300206086168576',
#        'type': 'photo',
#        'url': 'https://t.co/L8ZrV0DoVg'}],
#      'symbols': [],
# ...
#       'symbols': [],
#       'urls': [{'display_url': 'scipython.com/blog/iceberg-d…',
#         'expanded_url': 'https://scipython.com/blog/iceberg-dynamics/',
#         'indices': [54, 77],
#         'url': 'https://t.co/6ZQeGz0ops'}],
#       'user_mentions': []},
#      'extended_entities': {'media': [{'display_url': 'pic.twitter.com/mDgp4pd2ZP',
#         'expanded_url': 'https://twitter.com/scipython3/status/1363788722265808898/photo/1',
#         'id': 1363788649746354177,
#         'id_str': '1363788649746354177',
#         'indices': [78, 101],
#         'media_url': 'http://pbs.twimg.com/tweet_video_thumb/Eu0mjSDXUAEsJOI.jpg',
#         'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/Eu0mjSDXUAEsJOI.jpg',
#         'sizes': {'large': {'h': 480, 'resize': 'fit', 'w': 640},
#          'medium': {'h': 480, 'resize': 'fit', 'w': 640},
#          'small': {'h': 480, 'resize': 'fit', 'w': 640},
#          'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#         'type': 'animated_gif',
#         'url': 'https://t.co/mDgp4pd2ZP',
#         'video_info': {'aspect_ratio': [4, 3],
#          'variants': [{'bitrate': 0,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/tweet_video/Eu0mjSDXUAEsJOI.mp4'}]}}]},
#      'favorite_count': 66,
#      'favorited': False,
#      'geo': None,
#      'id': 1363788722265808898,
#      'id_str': '1363788722265808898',
#      'in_reply_to_screen_name': None,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'is_quote_status': False,
#      'lang': 'en',
#      'place': None,
#      'possibly_sensitive': False,
#      'retweet_count': 13,
#      'retweeted': False,
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'text': 'Iceberg dynamics explored in #Python with #Matplotlib https://t.co/6ZQeGz0ops https://t.co/mDgp4pd2ZP',
#      'truncated': False},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'RT @scipython3: Iceberg dynamics explored in #Python with #Matplotlib https://t.co/6ZQeGz0ops https://t.co/mDgp4pd2ZP',
#     'truncated': False},
#    'statuses_count': 3,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Sat Feb 18 19:32:30 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 70,
#    'follow_request_sent': False,
#    'followers_count': 18,
#    'following': False,
#    'friends_count': 166,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 496257280,
#    'id_str': '496257280',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'Yarkın Altınel',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1022585665215717379/a3vNuzHd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022585665215717379/a3vNuzHd_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'YarknAltnel',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 18:02:07 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 733989240665694208,
#        'id_str': '733989240665694208',
#        'indices': [3, 18],
#        'name': 'Kıvanç Özbilgiç',
#        'screen_name': 'kivancozbilgic'},
#       {'id': 551716253,
#        'id_str': '551716253',
#        'indices': [57, 71],
#        'name': 'Scala Kitapçı',
#        'screen_name': 'Scala_Kitapci'}]},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 1375145988936056837,
#     'id_str': '1375145988936056837',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'tr',
#     'place': None,
#     'retweet_count': 3920,
#     'retweeted': False,
#     'retweeted_status': {'contributors': None,
#      'coordinates': None,
#      'created_at': 'Thu Mar 25 18:00:01 +0000 2021',
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#         'expanded_url': 'https://twitter.com/i/web/status/1375145459568762893',
#         'indices': [117, 140],
#         'url': 'https://t.co/B2FB7nnb5O'}],
#       'user_mentions': [{'id': 551716253,
#         'id_str': '551716253',
#         'indices': [37, 51],
#         'name': 'Scala Kitapçı',
#         'screen_name': 'Scala_Kitapci'}]},
#      'favorite_count': 1710,
#      'favorited': False,
#      'geo': None,
#      'id': 1375145459568762893,
#      'id_str': '1375145459568762893',
#      'in_reply_to_screen_name': None,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'is_quote_status': False,
#      'lang': 'tr',
#      'place': None,
#      'possibly_sensitive': False,
#      'retweet_count': 3920,
#      'retweeted': False,
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'text': '📣DUYURU📣\n\nBu tweeti RETWEETLEYEN ve \n@Scala_Kitapci HESABINI TAKİP EDEN 2 kişiye:\n\n-İndirimsiz fiyatı yaklaşık 1300… https://t.co/B2FB7nnb5O',
#      'truncated': True},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'RT @kivancozbilgic: 📣DUYURU📣\n\nBu tweeti RETWEETLEYEN ve \n@Scala_Kitapci HESABINI TAKİP EDEN 2 kişiye:\n\n-İndirimsiz fiyatı yaklaşık 1300 TL…',
#     'truncated': False},
#    'statuses_count': 4,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Sun Jan 03 18:54:26 +0000 2021',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'The 8-week online program exclusive for Greek tech founders globally. #settleformore\nBook your seat now.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'greekstartupuniverse.org',
#        'expanded_url': 'http://greekstartupuniverse.org',
#        'indices': [0, 23],
#        'url': 'https://t.co/IdoZV4HSnu'}]}},
#    'favourites_count': 40,
#    'follow_request_sent': False,
#    'followers_count': 338,
#    'following': False,
#    'friends_count': 1102,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1345805236284383233,
#    'id_str': '1345805236284383233',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 6,
#    'live_following': False,
#    'location': '',
#    'muting': False,
#    'name': 'Greek Startup Universe',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1345805236284383233/1610556205',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1345805929028214785/yeit42sv_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1345805929028214785/yeit42sv_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'GreekStartupUni',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Mar 25 15:21:07 +0000 2021',
#     'entities': {'hashtags': [{'indices': [75, 87], 'text': 'proudgreeks'},
#       {'indices': [88, 104], 'text': 'independenceday'},
#       {'indices': [105, 116], 'text': 'greece2021'}],
#      'media': [{'display_url': 'pic.twitter.com/2Ll1BMiR37',
#        'expanded_url': 'https://twitter.com/GreekStartupUni/status/1375105470571118593/photo/1',
#        'id': 1375105467698020356,
#        'id_str': '1375105467698020356',
#        'indices': [117, 140],
#        'media_url': 'http://pbs.twimg.com/media/ExVbIyLWgAQ2sQR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ExVbIyLWgAQ2sQR.jpg',
#        'sizes': {'large': {'h': 1080, 'resize': 'fit', 'w': 1080},
#         'medium': {'h': 1080, 'resize': 'fit', 'w': 1080},
#         'small': {'h': 680, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/2Ll1BMiR37'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/2Ll1BMiR37',
#        'expanded_url': 'https://twitter.com/GreekStartupUni/status/1375105470571118593/photo/1',
#        'id': 1375105467698020356,
#        'id_str': '1375105467698020356',
#        'indices': [117, 140],
#        'media_url': 'http://pbs.twimg.com/media/ExVbIyLWgAQ2sQR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ExVbIyLWgAQ2sQR.jpg',
#        'sizes': {'large': {'h': 1080, 'resize': 'fit', 'w': 1080},
#         'medium': {'h': 1080, 'resize': 'fit', 'w': 1080},
#         'small': {'h': 680, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/2Ll1BMiR37'}]},
#     'favorite_count': 2,
#     'favorited': False,
#     'geo': None,
#     'id': 1375105470571118593,
#     'id_str': '1375105470571118593',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'und',
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="https://www.loomly.com/" rel="nofollow">Loomly</a>',
#     'text': 'Celebrating 200 Years of Independence in Greece!\n\nΧρόνια πολλά Ελλάδα! 🇬🇷\n\n#proudgreeks #independenceday #greece2021 https://t.co/2Ll1BMiR37',
#     'truncated': False},
#    'statuses_count': 140,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/IdoZV4HSnu',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Tue Aug 02 20:44:22 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Associate Prof. @Harvard. #AnalyticsScience #Healthcare #orms #MachineLearning #AI #DecisionMaking #Policy. Lab: #Public #Impact #Analytics #Science (#PIASLab).',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'scholar.harvard.edu/saghafian',
#        'expanded_url': 'http://scholar.harvard.edu/saghafian',
#        'indices': [0, 23],
#        'url': 'https://t.co/kyyNZOLaiF'}]}},
#    'favourites_count': 202,
#    'follow_request_sent': False,
#    'followers_count': 1028,
#    'following': False,
#    'friends_count': 2231,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 760577001669419008,
#    'id_str': '760577001669419008',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 8,
#    'live_following': False,
#    'location': 'Harvard University',
#    'muting': False,
#    'name': 'Soroush Saghafian',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/760577001669419008/1611525801',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1219291238844846082/RP4ByA1o_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219291238844846082/RP4ByA1o_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Soroush_Saghaf',
#    'status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Mar 21 15:11:29 +0000 2021',
#     'entities': {'hashtags': [{'indices': [4, 9], 'text': 'blog'},
#       {'indices': [45, 62], 'text': 'analyticsscience'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1373653494876491784',
#        'indices': [117, 140],
#        'url': 'https://t.co/pZc6J7MX9G'}],
#      'user_mentions': []},
#     'favorite_count': 8,
#     'favorited': False,
#     'geo': None,
#     'id': 1373653494876491784,
#     'id_str': '1373653494876491784',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': True,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'quoted_status_id': 1371899251333074944,
#     'quoted_status_id_str': '1371899251333074944',
#     'retweet_count': 2,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'The #blog series is devoted to public impact #analyticsscience. Via these posts, I’m communicating some important a… https://t.co/pZc6J7MX9G',
#     'truncated': True},
#    'statuses_count': 170,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/kyyNZOLaiF',
#    'utc_offset': None,
#    'verified': False},
#   {'blocked_by': False,
#    'blocking': False,
#    'contributors_enabled': False,
#    'created_at': 'Mon Feb 15 14:57:29 +0000 2021',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8,
#    'follow_request_sent': False,
#    'followers_count': 0,
#    'following': False,
#    'friends_count': 39,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1361328753234878469,
#    'id_str': '1361328753234878469',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'live_following': False,
#    'location': 'Houston, TX',
#    'muting': False,
#    'name': 'Yelena Kiyanitsa',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1361328753234878469/1613408532',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1364335998193131520/tfy5RYPO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364335998193131520/tfy5RYPO_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': True,
#    'screen_name': 'yelenakiy',
#    'statuses_count': 1,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}]}

# %%
# And let's see only followers' name
for num, follower in enumerate(followers['users']):
    print('My follower #{0}\t{1}'.format(num+1, follower['name'].encode("utf-8")))
# Out:
# My follower #1	b'Jihoon Rim'
# My follower #2	b'Raad Adam'
# My follower #3	b'anastluc'
# My follower #4	b'John Nuleti \xf0\x9f\x87\xae\xf0\x9f\x87\xb3\xf0\x9f\x87\xaf\xf0\x9f\x87\xb5'
# My follower #5	b'CB&DC'
# My follower #6	b'uComp Project'
# My follower #7	b'Thalassis Yorgos'
# My follower #8	b'Masud Talukdar'
# My follower #9	b'jrnc'
# My follower #10	b'Michael Molin'
# My follower #11	b'Ashish K. Bhatia'
# My follower #12	b'Parvathy'
# My follower #13	b'Bryan Gregor'
# My follower #14	b'JF'
# My follower #15	b'Mohamed Abdallah'
# My follower #16	b'science'
# My follower #17	b'Yark\xc4\xb1n Alt\xc4\xb1nel'
# My follower #18	b'Greek Startup Universe'
# My follower #19	b'Soroush Saghafian'
# My follower #20	b'Yelena Kiyanitsa'

# %%
# And now an example of using a "cursor" to go through pages of results
cursor = res.json().get("next_cursor_str")
res = requests.get(url_3, auth=auth, params={"cursor": cursor})
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
for num, follower in enumerate(followers['users']):
    print('My follower #{0}\t{1}'.format(num+1, follower['name'].encode("utf-8")))
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/followers/list.json?cursor=1691782656765190526
# My follower #1	b'Qiuzhuang Lian'
# My follower #2	b'33rd British Human-Computer Interaction Conference'
# My follower #3	b'Deborah Collier M.Sc. FRSA'
# My follower #4	b'Matt Reiner'
# My follower #5	b'Amrita Dey'
# My follower #6	b'Make Use of Data'
# My follower #7	b'Pablo Jimeno \xf0\x9f\x94\x8d'
# My follower #8	b'Association for Computing Machinery'
# My follower #9	b'Hans-Cees\xf0\x9f\x90\xb0'
# My follower #10	b'Ioannis Foukarakis'
# My follower #11	b'Simon Crosby'
# My follower #12	b'Sahil Gupta'
# My follower #13	b'Val Eagora'
# My follower #14	b'tdrenis'
# My follower #15	b'John Sumser'
# My follower #16	b'Joni Baboci'
# My follower #17	b'Paul'
# My follower #18	b'Prabishan'
# My follower #19	b'Sriramjee Singh'
# My follower #20	b'\xf0\x9f\x8c\xab'

# %% [markdown]
# ### Example 4:  Finding what is trending
#
# According to the [tweepy API](http://tweepy.readthedocs.org/en/v3.5.0/api.html), we can return the top 50 trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, New York has a `WOEID` of 2459115. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in New York

# %%
url_4 = 'https://api.twitter.com/1.1/trends/place.json?id=2459115'
res = requests.get(url_4, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

top50_trends = res.json()
top50_trends
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/trends/place.json?id=2459115
# [{'as_of': '2021-03-25T20:31:40Z',
#   'created_at': '2021-03-23T20:41:45Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}],
#   'trends': [{'name': 'Knicks',
#     'promoted_content': None,
#     'query': 'Knicks',
#     'tweet_volume': 29757,
#     'url': 'http://twitter.com/search?q=Knicks'},
#    {'name': 'Terrance Ferguson',
#     'promoted_content': None,
#     'query': '%22Terrance+Ferguson%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Terrance+Ferguson%22'},
#    {'name': 'Iggy',
#     'promoted_content': None,
#     'query': 'Iggy',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Iggy'},
#    {'name': 'Austin Rivers',
#     'promoted_content': None,
#     'query': '%22Austin+Rivers%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Austin+Rivers%22'},
#    {'name': 'LeVert',
#     'promoted_content': None,
#     'query': 'LeVert',
#     'tweet_volume': 13654,
#     'url': 'http://twitter.com/search?q=LeVert'},
#    {'name': '#RestoreTheSnyderVerse',
#     'promoted_content': None,
#     'query': '%23RestoreTheSnyderVerse',
#     'tweet_volume': 673365,
#     'url': 'http://twitter.com/search?q=%23RestoreTheSnyderVerse'},
#    {'name': 'Leon Rose',
#     'promoted_content': None,
#     'query': '%22Leon+Rose%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Leon+Rose%22'},
#    {'name': 'Pulisic',
#     'promoted_content': None,
#     'query': 'Pulisic',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Pulisic'},
#    {'name': '#FilmOutbyBTS',
#     'promoted_content': None,
#     'query': '%23FilmOutbyBTS',
#     'tweet_volume': 165214,
#     'url': 'http://twitter.com/search?q=%23FilmOutbyBTS'},
#    {'name': 'Blazers',
#     'promoted_content': None,
#     'query': 'Blazers',
#     'tweet_volume': 15847,
#     'url': 'http://twitter.com/search?q=Blazers'},
#    {'name': 'Triangle Shirtwaist Factory',
#     'promoted_content': None,
#     'query': '%22Triangle+Shirtwaist+Factory%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Triangle+Shirtwaist+Factory%22'},
#    {'name': 'Suez Canal',
#     'promoted_content': None,
#     'query': '%22Suez+Canal%22',
#     'tweet_volume': 165399,
#     'url': 'http://twitter.com/search?q=%22Suez+Canal%22'},
#    {'name': 'Shams',
#     'promoted_content': None,
#     'query': 'Shams',
#     'tweet_volume': 14341,
#     'url': 'http://twitter.com/search?q=Shams'},
#    {'name': 'White Sox',
#     'promoted_content': None,
#     'query': '%22White+Sox%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22White+Sox%22'},
#    {'name': 'Ghost of Tsushima',
#     'promoted_content': None,
#     'query': '%22Ghost+of+Tsushima%22',
#     'tweet_volume': 27742,
#     'url': 'http://twitter.com/search?q=%22Ghost+of+Tsushima%22'},
#    {'name': 'Elfrid Payton',
#     'promoted_content': None,
#     'query': '%22Elfrid+Payton%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Elfrid+Payton%22'},
#    {'name': 'Broadway',
#     'promoted_content': None,
#     'query': 'Broadway',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Broadway'},
#    {'name': 'Robinson',
#     'promoted_content': None,
#     'query': 'Robinson',
#     'tweet_volume': 25396,
#     'url': 'http://twitter.com/search?q=Robinson'},
#    {'name': 'Nuggets',
#     'promoted_content': None,
#     'query': 'Nuggets',
#     'tweet_volume': 58732,
#     'url': 'http://twitter.com/search?q=Nuggets'},
#    {'name': 'Vucevic',
#     'promoted_content': None,
#     'query': 'Vucevic',
#     'tweet_volume': 58310,
#     'url': 'http://twitter.com/search?q=Vucevic'},
#    {'name': '#ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': 42074,
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts'},
#    {'name': 'Micah Parsons',
#     'promoted_content': None,
#     'query': '%22Micah+Parsons%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Micah+Parsons%22'},
#    {'name': 'Powell',
#     'promoted_content': None,
#     'query': 'Powell',
#     'tweet_volume': 66914,
#     'url': 'http://twitter.com/search?q=Powell'},
#    {'name': 'Jessica Walter',
#     'promoted_content': None,
#     'query': '%22Jessica+Walter%22',
#     'tweet_volume': 98803,
#     'url': 'http://twitter.com/search?q=%22Jessica+Walter%22'},
#    {'name': 'Arrested Development',
#     'promoted_content': None,
#     'query': '%22Arrested+Development%22',
#     'tweet_volume': 37428,
#     'url': 'http://twitter.com/search?q=%22Arrested+Development%22'},
#    {'name': 'Lucille Bluth',
#     'promoted_content': None,
#     'query': '%22Lucille+Bluth%22',
#     'tweet_volume': 25980,
#     'url': 'http://twitter.com/search?q=%22Lucille+Bluth%22'},
#    {'name': '#bidenpressconference',
#     'promoted_content': None,
#     'query': '%23bidenpressconference',
#     'tweet_volume': 54854,
#     'url': 'http://twitter.com/search?q=%23bidenpressconference'},
#    {'name': 'Oladipo',
#     'promoted_content': None,
#     'query': 'Oladipo',
#     'tweet_volume': 65845,
#     'url': 'http://twitter.com/search?q=Oladipo'},
#    {'name': 'Lakers',
#     'promoted_content': None,
#     'query': 'Lakers',
#     'tweet_volume': 94642,
#     'url': 'http://twitter.com/search?q=Lakers'},
#    {'name': 'Clippers',
#     'promoted_content': None,
#     'query': 'Clippers',
#     'tweet_volume': 49615,
#     'url': 'http://twitter.com/search?q=Clippers'},
#    {'name': 'Rondo',
#     'promoted_content': None,
#     'query': 'Rondo',
#     'tweet_volume': 41748,
#     'url': 'http://twitter.com/search?q=Rondo'},
#    {'name': 'Lowry',
#     'promoted_content': None,
#     'query': 'Lowry',
#     'tweet_volume': 162175,
#     'url': 'http://twitter.com/search?q=Lowry'},
#    {'name': 'Lou Will',
#     'promoted_content': None,
#     'query': '%22Lou+Will%22',
#     'tweet_volume': 13426,
#     'url': 'http://twitter.com/search?q=%22Lou+Will%22'},
#    {'name': 'Pat Riley',
#     'promoted_content': None,
#     'query': '%22Pat+Riley%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Pat+Riley%22'},
#    {'name': 'Archer',
#     'promoted_content': None,
#     'query': 'Archer',
#     'tweet_volume': 25075,
#     'url': 'http://twitter.com/search?q=Archer'},
#    {'name': 'Play Misty for Me',
#     'promoted_content': None,
#     'query': '%22Play+Misty+for+Me%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Play+Misty+for+Me%22'},
#    {'name': 'Theis',
#     'promoted_content': None,
#     'query': 'Theis',
#     'tweet_volume': 19641,
#     'url': 'http://twitter.com/search?q=Theis'},
#    {'name': 'Drummond',
#     'promoted_content': None,
#     'query': 'Drummond',
#     'tweet_volume': 29014,
#     'url': 'http://twitter.com/search?q=Drummond'},
#    {'name': 'Magic City',
#     'promoted_content': None,
#     'query': '%22Magic+City%22',
#     'tweet_volume': 12258,
#     'url': 'http://twitter.com/search?q=%22Magic+City%22'},
#    {'name': 'Aldridge',
#     'promoted_content': None,
#     'query': 'Aldridge',
#     'tweet_volume': 17482,
#     'url': 'http://twitter.com/search?q=Aldridge'},
#    {'name': 'Rockets',
#     'promoted_content': None,
#     'query': 'Rockets',
#     'tweet_volume': 37224,
#     'url': 'http://twitter.com/search?q=Rockets'},
#    {'name': 'Jim Eagle',
#     'promoted_content': None,
#     'query': '%22Jim+Eagle%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jim+Eagle%22'},
#    {'name': 'Bulls',
#     'promoted_content': None,
#     'query': 'Bulls',
#     'tweet_volume': 92396,
#     'url': 'http://twitter.com/search?q=Bulls'},
#    {'name': '#IWatchPMSNoClueWhy',
#     'promoted_content': None,
#     'query': '%23IWatchPMSNoClueWhy',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23IWatchPMSNoClueWhy'},
#    {'name': 'Avery Bradley',
#     'promoted_content': None,
#     'query': '%22Avery+Bradley%22',
#     'tweet_volume': 12809,
#     'url': 'http://twitter.com/search?q=%22Avery+Bradley%22'},
#    {'name': 'Heat',
#     'promoted_content': None,
#     'query': 'Heat',
#     'tweet_volume': 125494,
#     'url': 'http://twitter.com/search?q=Heat'},
#    {'name': 'Lemon Pepper Lou',
#     'promoted_content': None,
#     'query': '%22Lemon+Pepper+Lou%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Lemon+Pepper+Lou%22'},
#    {'name': 'Mo Wagner',
#     'promoted_content': None,
#     'query': '%22Mo+Wagner%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Mo+Wagner%22'},
#    {'name': 'Herro',
#     'promoted_content': None,
#     'query': 'Herro',
#     'tweet_volume': 24985,
#     'url': 'http://twitter.com/search?q=Herro'},
#    {'name': 'Olynyk',
#     'promoted_content': None,
#     'query': 'Olynyk',
#     'tweet_volume': 15844,
#     'url': 'http://twitter.com/search?q=Olynyk'}]}]

# %%
# And let's see only the first 10 trends names and the respective URL
for i, trend in enumerate(top50_trends[0]['trends'][:10]):
    print('{0} - {1} - URL: {2}'.format(i+1, trend['name'], trend['url']))
# Out:
# 1 - Knicks - URL: http://twitter.com/search?q=Knicks
# 2 - Terrance Ferguson - URL: http://twitter.com/search?q=%22Terrance+Ferguson%22
# 3 - Iggy - URL: http://twitter.com/search?q=Iggy
# 4 - Austin Rivers - URL: http://twitter.com/search?q=%22Austin+Rivers%22
# 5 - LeVert - URL: http://twitter.com/search?q=LeVert
# 6 - #RestoreTheSnyderVerse - URL: http://twitter.com/search?q=%23RestoreTheSnyderVerse
# 7 - Leon Rose - URL: http://twitter.com/search?q=%22Leon+Rose%22
# 8 - Pulisic - URL: http://twitter.com/search?q=Pulisic
# 9 - #FilmOutbyBTS - URL: http://twitter.com/search?q=%23FilmOutbyBTS
# 10 - Blazers - URL: http://twitter.com/search?q=Blazers

# %% [markdown]
# ### Example 5: Streaming
#
# **Twitter** offers a [Streaming API](https://dev.twitter.com/streaming/overview) to make it easier to query streams of tweets.  The Stream API encapsulates some pain points of REST access to ensure that Stream calls don't exceed the rate limit. These tool allows to get tweet data when it appears in real time. There are three stream types:
#
# - `Public Streams:` Streams of public data flowthing through **Twitter**. Suitable for followign specific users, topics or for data mining.
# - `User Streams:` Single-user streams. Containing roughly all of the data corresponding with a single user's view of **Twitter**.
# - `Site Streams:` The multi-user version of user streams.
#
# >Connecting to the streaming API requires keeping a persistent HTTP connection open. In many cases this involves thinking about your application differently than if you were interacting with the REST API. An app which connects to the Streaming APIs will not be able to establish a connection in response to a user request. Instead, the code for maintaining the Streaming connection is typically run in a process separate from the process which handles HTTP requests. The streaming process gets the input tweets and performs any parsing, filtering, and/or aggregation needed before storing the result to a data store. The HTTP handling process queries the data store for results in response to user requests. While this model is more complex than the first example, the benefits from having a realtime stream of tweet data make the integration worthwhile for many types of apps.
#
# With `requests.Response.iter_lines()` you can easily iterate over streaming APIs including the **Twitter Streaming API**. Simply set `stream` parameter to `True` and iterate over the response with `iter_lines()`.
#
# Depending on the search term/terms, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#iphone_ hashtag:

# %%
import time
import urllib

query = "#iphone"
encoded_query = urllib.parse.quote(query)
url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=' + encoded_query
res = requests.get(url_5, auth=auth, stream=True)

print(res, res.status_code, res.headers['content-type'])
print(res.url, "\n")

# Let's measure the time elapsed after the start of streaming 
start = time.time()
stop_after = 10
tweets_printed = 0
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line.decode(encoding='utf-8') )
        print("Elapsed:", time.time()-start, "sec",  
                parsed_line["created_at"], "\n", 
                parsed_line['text'].encode("utf-8"), "\n")
        tweets_printed = tweets_printed + 1
        if tweets_printed>stop_after:
            break

print("Time Elapsed for getting", stop_after, " tweets about ", query, " ==>" , time.time()-start)
# Out:
# <Response [200]> 200 application/json
# https://stream.twitter.com/1.1/statuses/filter.json?track=%23iphone
#
# Elapsed: 10.729570865631104 sec Thu Mar 25 20:33:14 +0000 2021
#  b'RT @AppleZein: Apple Event SENZA le AirPods 3 https://t.co/FjI486zcnU\n\n#AirPods3 #AppleEvent #iPhone #Apple #AppleNews #AppleItalia #AppleU\xe2\x80\xa6'
#
# Elapsed: 28.569089651107788 sec Thu Mar 25 20:33:32 +0000 2021
#  b'RT @hentaiser: All #hentai and #anime in one #free #app for #Android #iPhone #iPad \n https://t.co/nrLiNUu5Xr https://t.co/myaDb3ngLt'
#
# Elapsed: 90.86928009986877 sec Thu Mar 25 20:34:34 +0000 2021
#  b'All #hentai and #anime in one #free #app for #Android #iPhone #iPad \n https://t.co/nrLiNUu5Xr https://t.co/alUZqNjrHR'
#
# Elapsed: 97.02242255210876 sec Thu Mar 25 20:34:41 +0000 2021
#  b'\xf0\x9f\x91\xa0\xf0\x9f\x91\x95\xf0\x9f\x93\x99\xf0\x9f\x93\x93\xf0\x9f\x8e\x80\xf0\x9f\xa5\xb0 When a friend falls, dare to be the first to extend a hand. #rt for your friends https://t.co/kgIeS8p69v\xe2\x80\xa6 https://t.co/gmeaWQNWxb'
#
# Elapsed: 120.97514820098877 sec Thu Mar 25 20:35:05 +0000 2021
#  b'Iran blamed as Israeli-owned ship said hit by missile near Oman\n#android #iPhone #phone #phones #mobile #Apple\xe2\x80\xa6 https://t.co/OPERnCKT6f'
#
# Elapsed: 127.86798596382141 sec Thu Mar 25 20:35:11 +0000 2021
#  b'Apple Now Accepts Google Pixel 4a and Pixel 5 and Samsung Note 20 for Trade-In Towards New iPhone Purchase, with th\xe2\x80\xa6 https://t.co/CGm9SnQk3k'
#
# Elapsed: 130.9946174621582 sec Thu Mar 25 20:35:15 +0000 2021
#  b'RT @Vcream_unknow: \xe3\x81\x93\xe3\x82\x8c\xe3\x81\xa7\xe5\xae\x89\xe5\xbf\x83\xe3\x83\xbb\xe3\x83\xbb\xe3\x83\xbb\xe3\x81\xa7\xe3\x81\x99\xe3\x81\xad\xe3\x83\xbb\xe3\x83\xbb\n#\xe8\x99\xb9\xe3\x83\xb6\xe5\x92\xb2 \n#iPhone\xe3\x82\xb7\xe3\x83\xa3\xe3\x83\xaf\xe3\x83\xbc https://t.co/92KsWJf2UJ'
#
# Elapsed: 139.6039400100708 sec Thu Mar 25 20:35:23 +0000 2021
#  b'RT @hentaiser: All #hentai and #anime in one #free #app for #Android #iPhone #iPad \n https://t.co/nrLiNUu5Xr https://t.co/alUZqNjrHR'
#
# Elapsed: 140.89215898513794 sec Thu Mar 25 20:35:25 +0000 2021
#  b'RT @applipo_jp: \xe3\x80\x90\xe7\x84\xa1\xe6\x96\x99\xe3\x80\x91iPhone\xe5\x90\x91\xe3\x81\x91\xe3\x82\xa2\xe3\x82\xa4\xe3\x82\xb3\xe3\x83\xb3\xe7\xb4\xa0\xe6\x9d\x90\xe3\x83\x80\xe3\x82\xa6\xe3\x83\xb3\xe3\x83\xad\xe3\x83\xbc\xe3\x83\x89\xe3\x83\x9a\xe3\x83\xbc\xe3\x82\xb8\xe3\x80\x82iOS14\xe3\x81\xa7\xe3\x81\x8a\xe3\x81\x97\xe3\x82\x83\xe3\x82\x8c\xe3\x81\xa7\xe3\x81\x8b\xe3\x82\x8f\xe3\x81\x84\xe3\x81\x84\xe3\x83\x9b\xe3\x83\xbc\xe3\x83\xa0\xe7\x94\xbb\xe9\x9d\xa2\xe3\x82\x92\nhttps://t.co/XKl3fJHwm9\n#iOS14 #iPhone #\xe3\x82\xa2\xe3\x82\xa4\xe3\x83\x95\xe3\x82\xa9\xe3\x83\xb3 #\xe3\x82\xa2\xe3\x82\xa4\xe3\x82\xb3\xe3\x83\xb3\xe5\xa4\x89\xe6\x9b\xb4 #\xe3\x82\xa2\xe3\x82\xa4\xe3\x82\xb3\xe3\x83\xb3\xe7\xb4\xa0\xe6\x9d\x90 #\xe3\x83\x9b\xe3\x83\xbc\xe3\x83\xa0\xe7\x94\xbb\xe9\x9d\xa2\xe3\x82\xab\xe3\x82\xb9\xe3\x82\xbf\xe3\x83\x9e\xe3\x82\xa4\xe3\x82\xba'
#
# Elapsed: 226.02186608314514 sec Thu Mar 25 20:36:50 +0000 2021
#  b'RT @hentaiser: All #hentai and #anime in one #free #app for #Android #iPhone #iPad \n https://t.co/nrLiNUu5Xr https://t.co/alUZqNjrHR'
#
# Elapsed: 230.26105976104736 sec Thu Mar 25 20:36:54 +0000 2021
#  b'RT @Hotbid_uk: Win the giftcard of your choice!\nFollow us @Hotbid_uk \nRetweet\nTag a friend\nComment with #hotbid\nCheck out https://t.co/VsGe\xe2\x80\xa6'
#
# Time Elapsed for getting 10  tweets about  #iphone  ==> 230.26443910598755

# %% [markdown]
# ---
# ## Exercises
# ---

# %% [markdown]
# ## Exercise #1:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display, the list of all your friends and sort them by its followers amounts in descending order.
#
# #### HINT: `GET friends/list`  will be helpfull for you here.

# %% [markdown]
# ## Exercise #2:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library, display the list of 5 (or less if there is not so much) most recent tweets liked by you, which were also retweeted (`retweet_count` is not equal to zero). You shoud show the date of creation, author of the tweet and its text.
#
# #### HINT: `GET favorites/list` will be helpfull for you here

# %% [markdown]
# ## Exercise #3:
#
# > Using [Twitter Streaming API](https://dev.twitter.com/streaming/overview) and `requests` Python library count how many tweets with hashtags _#twitter_, _#tweet_ and _#world_ are appearing each minute over 5 minutes and display these 5 numbers. Please display also the shortest and the longest time period between to closest tweets for all 5 measures.
#
# #### HINT: `POST statuses/filter` will be helpfull for you here

# %% [markdown]
# ### Note: You can use the twitter API as part of your team's project. Simple idea.  Find tweets about a subject, and use the Watson API to do sentiment analysis.
