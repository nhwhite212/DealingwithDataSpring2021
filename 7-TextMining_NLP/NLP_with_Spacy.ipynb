# %% [markdown]
# # spaCy - A natural language library for python
# Unfortunately, it needs too much memory for our virtual machine

# %% [markdown]
# ### Installation

# %% [markdown]
# We follow the instructions from https://spacy.io/docs/usage/

# %%
# !sudo python3 -m pip uninstall spacy
# Out:
# The directory '/home/ubuntu/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Uninstalling spacy-1.9.0:
#   /usr/local/lib/python3.5/dist-packages/spacy-1.9.0.egg-info
#   /usr/local/lib/python3.5/dist-packages/spacy/__init__.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/__main__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/__main__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/about.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/compat.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/deprecated.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/glossary.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/language.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/lemmatizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/scorer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/train.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/__pycache__/util.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/about.py
#   /usr/local/lib/python3.5/dist-packages/spacy/attrs.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/attrs.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/attrs.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/lemma_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/morph_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/punctuation.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/lemma_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/morph_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/punctuation.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/bn/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cfile.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/cfile.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/cfile.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/convert.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/download.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/info.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/link.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/model.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/package.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/__pycache__/train.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/convert.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/converters/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/converters/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/converters/__pycache__/conllu2json.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/converters/conllu2json.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/download.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/info.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/link.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/model.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/package.py
#   /usr/local/lib/python3.5/dist-packages/spacy/cli/train.py
#   /usr/local/lib/python3.5/dist-packages/spacy/compat.py
#   /usr/local/lib/python3.5/dist-packages/spacy/data/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/data/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/download.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/de/download.py
#   /usr/local/lib/python3.5/dist-packages/spacy/de/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/de/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/de/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/de/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/deprecated.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/download.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/morph_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/__pycache__/word_sets.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/download.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_adjectives.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_adjectives_irreg.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_adverbs.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_adverbs_irreg.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_lemma_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_nouns.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_nouns_irreg.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_verbs.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/__pycache__/_verbs_irreg.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_adjectives.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_adjectives_irreg.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_adverbs.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_adverbs_irreg.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_lemma_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_nouns.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_nouns_irreg.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_verbs.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/lemmatizer/_verbs_irreg.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/morph_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/en/word_sets.py
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/es/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/es/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/es/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/es/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/es/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fi/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/_tokenizer_exceptions_list.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/punctuation.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/_tokenizer_exceptions_list.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/punctuation.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/fr/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/glossary.py
#   /usr/local/lib/python3.5/dist-packages/spacy/gold.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/gold.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/gold.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/he/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/he/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/he/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/he/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/he/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/he/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__pycache__/punctuation.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/punctuation.py
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/hu/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/it/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/it/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/it/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/it/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/it/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/it/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/ja/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/abbreviations.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/emoticons.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/entity_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/punctuation.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/tag_map.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/__pycache__/util.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/abbreviations.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/emoticons.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/entity_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/punctuation.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/tag_map.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/language_data/util.py
#   /usr/local/lib/python3.5/dist-packages/spacy/lemmatizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/lexeme.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/lexeme.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/lexeme.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/matcher.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/matcher.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/morphology.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/morphology.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/morphology.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/align_raw.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/read_conll.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/read_ner.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/read_ontonotes.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/__pycache__/read_ptb.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/align_raw.py
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/read_conll.py
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/read_ner.py
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/read_ontonotes.py
#   /usr/local/lib/python3.5/dist-packages/spacy/munge/read_ptb.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__pycache__/morph_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/morph_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nb/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/__pycache__/word_sets.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/nl/word_sets.py
#   /usr/local/lib/python3.5/dist-packages/spacy/orth.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/orth.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/orth.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/parts_of_speech.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/parts_of_speech.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/parts_of_speech.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/pipeline.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/pipeline.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/pipeline.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/pt/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/scorer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/__init__.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/bits.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/bits.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/bits.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/huffman.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/huffman.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/huffman.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/packer.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/packer.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/serialize/packer.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/strings.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/strings.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/strings.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/structs.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/language_data.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/lemma_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/morph_rules.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/stop_words.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/__pycache__/tokenizer_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/language_data.py
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/lemma_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/morph_rules.py
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/stop_words.py
#   /usr/local/lib/python3.5/dist-packages/spacy/sv/tokenizer_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/symbols.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/symbols.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/symbols.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/__init__.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_parse_features.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_parse_features.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_parse_features.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_state.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_state.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/_state.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/arc_eager.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/arc_eager.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/arc_eager.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/beam_parser.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/beam_parser.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/beam_parser.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/iterators.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/iterators.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/iterators.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/ner.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/ner.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/ner.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/nonproj.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/nonproj.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/nonproj.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/parser.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/parser.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/parser.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/stateclass.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/stateclass.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/stateclass.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/transition_system.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/transition_system.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/syntax/transition_system.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/tagger.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/tagger.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tagger.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/conftest.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/test_attrs.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/test_cli.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/test_misc.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/test_orth.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/test_pickles.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/__pycache__/util.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/bn/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/bn/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/bn/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/bn/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/conftest.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/__pycache__/test_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/__pycache__/test_prefix_suffix_infix.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/__pycache__/test_text.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/test_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/test_prefix_suffix_infix.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/de/test_text.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/test_add_entities.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/test_array.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/test_doc_api.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/test_noun_chunks.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/__pycache__/test_token_api.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/test_add_entities.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/test_array.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/test_doc_api.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/test_noun_chunks.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/doc/test_token_api.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_contractions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_indices.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_prefix_suffix_infix.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_punct.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/__pycache__/test_text.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_contractions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_indices.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_prefix_suffix_infix.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_punct.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/en/test_text.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/__pycache__/test_exception.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/__pycache__/test_text.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/test_exception.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/es/test_text.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fi/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fi/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fi/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fi/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/__pycache__/test_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/__pycache__/test_text.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/test_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/fr/test_text.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/__pycache__/test_biluo.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/__pycache__/test_lev_align.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/test_biluo.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/gold/test_lev_align.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/he/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/he/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/he/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/he/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/hu/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/hu/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/hu/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/hu/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/integration/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/integration/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/integration/__pycache__/test_model_sanity.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/integration/test_model_sanity.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/ja/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/ja/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/ja/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/ja/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/__pycache__/test_entity_id.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/__pycache__/test_matcher.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/test_entity_id.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/matcher/test_matcher.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/nb/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/nb/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/nb/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/nb/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_ner.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_nonproj.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_noun_chunks.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_parse.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_parse_navigate.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_sbd.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_sbd_prag.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/__pycache__/test_space_attachment.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_ner.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_nonproj.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_noun_chunks.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_parse.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_parse_navigate.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_sbd.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_sbd_prag.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/parser/test_space_attachment.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue1031.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue1061.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue118.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue1207.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue242.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue309.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue351.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue360.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue361.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue401.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue429.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue514.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue54.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue587.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue588.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue589.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue590.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue595.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue599.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue600.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue605.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue615.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue617.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue686.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue693.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue704.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue717.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue719.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue736.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue740.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue743.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue744.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue758.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue759.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue768.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue775.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue781.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue792.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue801.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue805.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue834.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue850.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue852.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue859.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue886.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue891.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue903.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue910.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue912.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue957.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue995.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/__pycache__/test_issue999.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue1031.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue1061.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue118.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue1207.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue242.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue309.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue351.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue360.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue361.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue401.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue429.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue514.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue54.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue587.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue588.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue589.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue590.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue595.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue599.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue600.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue605.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue615.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue617.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue686.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue693.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue704.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue717.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue719.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue736.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue740.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue743.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue744.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue758.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue759.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue768.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue775.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue781.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue792.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue801.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue805.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue834.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue850.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue852.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue859.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue886.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue891.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue903.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue910.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue912.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue957.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue995.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/regression/test_issue999.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/test_codecs.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/test_huffman.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/test_io.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/test_packer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/__pycache__/test_serialization.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/test_codecs.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/test_huffman.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/test_io.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/test_packer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/serialize/test_serialization.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/__pycache__/test_merge.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/__pycache__/test_span.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/test_merge.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/spans/test_span.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/__pycache__/test_freeze_string_store.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/__pycache__/test_stringstore.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/test_freeze_string_store.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/stringstore/test_stringstore.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/sv/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/sv/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/sv/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/sv/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__pycache__/test_lemmatizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__pycache__/test_morph_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__pycache__/test_spaces.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/__pycache__/test_tag_names.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/test_lemmatizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/test_morph_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/test_spaces.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tagger/test_tag_names.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/test_attrs.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/test_cli.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/test_misc.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/test_orth.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/test_pickles.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__pycache__/test_exceptions.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__pycache__/test_tokenizer.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__pycache__/test_urls.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/__pycache__/test_whitespace.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/sun.txt
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/test_exceptions.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/test_tokenizer.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/test_urls.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/tokenizer/test_whitespace.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/util.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/__pycache__/test_similarity.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/__pycache__/test_vectors.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/test_similarity.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vectors/test_vectors.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/__pycache__/test_add_vectors.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/__pycache__/test_lexeme.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/__pycache__/test_vocab_api.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/test_add_vectors.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/test_lexeme.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tests/vocab/test_vocab_api.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tokenizer.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/tokenizer.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tokenizer.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/__init__.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/__pycache__/__init__.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/__pycache__/printers.cpython-35.pyc
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/doc.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/doc.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/doc.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/printers.py
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/span.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/span.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/span.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/token.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/token.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/tokens/token.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/train.py
#   /usr/local/lib/python3.5/dist-packages/spacy/typedefs.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/typedefs.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/util.py
#   /usr/local/lib/python3.5/dist-packages/spacy/vocab.cpython-35m-x86_64-linux-gnu.so
#   /usr/local/lib/python3.5/dist-packages/spacy/vocab.pxd
#   /usr/local/lib/python3.5/dist-packages/spacy/vocab.pyx
#   /usr/local/lib/python3.5/dist-packages/spacy/zh/__init__.py
#   /usr/local/lib/python3.5/dist-packages/spacy/zh/__pycache__/__init__.cpython-35.pyc
# Proceed (y/n)?

# %%
# Support for english
# !sudo python3 -m spacy.en.download all
# Out:
#     Warning: deprecated command
#
#     The spacy.en.download command is now deprecated. Please use python -m
#     spacy download [model name or shortcut] instead. For more info and
#     available models, see the documentation: https://spacy.io/docs/usage.
#     Downloading default 'en' model now...
#
#
#     Downloading en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz (52.2MB)
#     100% |████████████████████████████████| 52.2MB 53.9MB/s ta 0:00:011 6% |██                              | 3.2MB 33.1MB/s eta 0:00:02    20% |██████▌                         | 10.5MB 40.6MB/s eta 0:00:02
# Requirement already satisfied: spacy<2.0.0,>=1.7.0 in /usr/local/lib/python3.5/dist-packages (from en-core-web-sm==1.2.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: thinc<6.6.0,>=6.5.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: pip<10.0.0,>=9.0.0 in /home/ubuntu/.local/lib/python3.5/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: regex<2017.12.1,>=2017.4.1 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.5/dist-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.5/dist-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.5/dist-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.5/dist-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.5/dist-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Installing collected packages: en-core-web-sm
#   Running setup.py install for en-core-web-sm ... done
# Successfully installed en-core-web-sm-1.2.0
#
#     Linking successful
#
#     /usr/local/lib/python3.5/dist-packages/en_core_web_sm/en_core_web_sm-1.2.0
#     --> /usr/local/lib/python3.5/dist-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en').

# %%
# Support for german
# !sudo python3 -m spacy.de.download all
# Out:
#     Warning: deprecated command
#
#     The spacy.de.download command is now deprecated. Please use python -m
#     spacy download [model name or shortcut] instead. For more info and
#     available models, see the documentation: https://spacy.io/docs/usage.
#     Downloading default 'de' model now...
#
#
#     Downloading de_core_news_md-1.0.0/de_core_news_md-1.0.0.tar.gz
#
# Collecting https://github.com/explosion/spacy-models/releases/download/de_core_news_md-1.0.0/de_core_news_md-1.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_md-1.0.0/de_core_news_md-1.0.0.tar.gz (675.5MB)
#     50% |████████████████                | 339.4MB 44.7MB/s eta 0:00:08
#     50% |████████████████▏               | 341.0MB 46.2MB/s eta 0:00:08
#     50% |████████████████▎               | 342.5MB 55.5MB/s eta 0:00:06
#     50% |████████████████▎               | 344.3MB 54.8MB/s eta 0:00:07
#     51% |████████████████▍               | 345.9MB 18.0MB/s eta 0:00:19
#     51% |████████████████▌               | 347.7MB 60.8MB/s eta 0:00:06
#     51% |████████████████▋               | 349.6MB 36.6MB/s eta 0:00:09
#     52% |████████████████▋               | 351.3MB 39.3MB/s eta 0:00:09
#     52% |████████████████▊               | 353.2MB 30.0MB/s eta 0:00:11
#     52% |████████████████▉               | 354.8MB 24.9MB/s eta 0:00:13
#     52% |████████████████▉               | 356.2MB 22.4MB/s eta 0:00:15
#     52% |█████████████████               | 358.0MB 37.6MB/s eta 0:00:09
#     53% |█████████████████               | 359.5MB 57.7MB/s eta 0:00:06
#     91% |█████████████████████████████▍  | 620.2MB 70.8MB/s eta 0:00:011   53% |█████████████████▏              | 362.3MB 50.9MB/s eta 0:00:07    54% |█████████████████▎              | 365.3MB 65.6MB/s eta 0:00:05    54% |█████████████████▍              | 366.8MB 32.6MB/s eta 0:00:10    54% |█████████████████▌              | 368.5MB 29.0MB/s eta 0:00:11  54% |█████████████████▌              | 370.1MB 56.2MB/s eta 0:00:06    55% |█████████████████▋              | 372.0MB 38.6MB/s eta 0:00:08    55% |█████████████████▊              | 373.8MB 19.5MB/s eta 0:00:16    55% |█████████████████▉              | 375.5MB 26.3MB/s eta 0:00:12    56% |██████████████████              | 380.6MB 28.7MB/s eta 0:00:11    56% |██████████████████              | 382.3MB 42.9MB/s eta 0:00:07| 383.5MB 67.7MB/s eta 0:00:05    56% |██████████████████▎             | 384.8MB 15.6MB/s eta 0:00:19    57% |██████████████████▎             | 385.9MB 16.8MB/s eta 0:00:18    57% |██████████████████▍             | 388.7MB 35.4MB/s eta 0:00:09    57% |██████████████████▌             | 390.5MB 39.1MB/s eta 0:00:08    58% |██████████████████▋             | 392.3MB 42.5MB/s eta 0:00:07    58% |██████████████████▊             | 395.9MB 30.2MB/s eta 0:00:107MB 21.7MB/s eta 0:00:13�████████▉             | 397.6MB 12.7MB/s eta 0:00:22    59% |███████████████████             | 399.6MB 19.9MB/s eta 0:00:14    59% |███████████████████             | 401.6MB 52.2MB/s eta 0:00:06    59% |███████████████████▏            | 403.6MB 32.1MB/s eta 0:00:09    60% |███████████████████▏            | 405.3MB 23.3MB/s eta 0:00:12    60% |███████████████████▎            | 407.0MB 64.9MB/s eta 0:00:05    60% |███████████████████▍            | 408.8MB 50.8MB/s eta 0:00:06    61% |███████████████████▌            | 412.7MB 62.0MB/s eta 0:00:05    61% |███████████████████▋            | 413.6MB 83.9MB/s eta 0:00:04    61% |███████████████████▋            | 414.5MB 2.9MB/s eta 0:01:30    61% |███████████████████▊            | 416.2MB 25.2MB/s eta 0:00:11    61% |███████████████████▉            | 417.9MB 37.7MB/s eta 0:00:07    62% |███████████████████▉            | 419.7MB 36.0MB/s eta 0:00:08████████            | 421.8MB 33.8MB/s eta 0:00:08    62% |████████████████████            | 423.6MB 24.0MB/s eta 0:00:11��███████████████▏           | 425.4MB 51.8MB/s eta 0:00:05    63% |████████████████████▎           | 427.3MB 50.7MB/s eta 0:00:05    63% |████████████████████▍           | 429.3MB 70.5MB/s eta 0:00:04�███████████████████▍           | 431.2MB 24.7MB/s eta 0:00:10��████▌           | 431.9MB 29.1MB/s eta 0:00:09    64% |████████████████████▌           | 433.8MB 55.2MB/s eta 0:00:05    64% |████████████████████▋           | 435.6MB 55.4MB/s eta 0:00:05    64% |████████████████████▊           | 437.6MB 55.0MB/s eta 0:00:05    65% |████████████████████▉           | 439.3MB 91.3MB/s eta 0:00:03    65% |█████████████████████           | 441.0MB 25.6MB/s eta 0:00:10    65% |█████████████████████           | 443.1MB 52.5MB/s eta 0:00:05    65% |█████████████████████           | 444.8MB 86.4MB/s eta 0:00:031.5MB/s eta 0:00:08�█████████████▏          | 447.3MB 1.7MB/s eta 0:02:15MB 3.2MB/s eta 0:01:11█████████████▎          | 448.4MB 74.1MB/s eta 0:00:04  | 448.9MB 25.8MB/s eta 0:00:09��██████████████████▍          | 450.4MB 6.3MB/s eta 0:00:36�██████████████████▍          | 452.3MB 36.2MB/s eta 0:00:071MB/s eta 0:00:0700:03    67% |█████████████████████▊          | 458.9MB 57.7MB/s eta 0:00:04    68% |█████████████████████▉          | 461.1MB 88.9MB/s eta 0:00:034.6MB/s eta 0:00:03    | 464.8MB 94.2MB/s eta 0:00:03�████████████████          | 466.2MB 82.2MB/s eta 0:00:03    69% |██████████████████████▏         | 468.3MB 28.1MB/s eta 0:00:08    69% |██████████████████████▎         | 470.2MB 24.7MB/s eta 0:00:09�████████████████████▍         | 472.2MB 20.9MB/s eta 0:00:10��████████▌         | 473.8MB 69.4MB/s eta 0:00:03    70% |██████████████████████▋         | 476.2MB 21.8MB/s eta 0:00:10          ...
#     92% |██�
#     92% |█████████████████████████████�
#     92% |
#     100% |████████████████████████████████| 675.5MB 3.6MB/s ta 0:00:0111█████████████▉  | 630.2MB 13.4MB/s eta 0:00:04K    93% |██████████████████████████████  | 631.4MB 30.3MB/s eta 0:00:02�███████████████████  | 632.6MB 19.4MB/s eta 0:00:03   93% |██████████████████████████████  | 633.7MB 29.8MB/s eta 0:00:02�████████████████████  | 635.2MB 84.7MB/s eta 0:00:01�██████████████▏ | 636.1MB 80.6MB/s eta 0:00:0161.8MB/s eta 0:00:01�████▎ | 638.5MB 102.3MB/s eta 0:00:01�████████████████▎ | 639.7MB 19.3MB/s eta 0:00:02.5MB/s eta 0:00:01��██████████████████████▍ | 642.3MB 86.9MB/s eta 0:00:01█████████████▌ | 643.4MB 74.3MB/s eta 0:00:01█████████████████████████▌ | 645.0MB 84.1MB/s eta 0:00:018MB 25.3MB/s eta 0:00:02�█████████████▊ | 649.7MB 56.6MB/s eta 0:00:01██████████████████████▉ | 651.3MB 20.0MB/s eta 0:00:02��███████████████████████ | 652.7MB 82.5MB/s eta 0:00:01��█████ | 653.3MB 26.5MB/s eta 0:00:016% |███████████████████████████████ | 654.4MB 23.4MB/s eta 0:00:01�██████████████ | 656.3MB 88.3MB/s eta 0:00:01��███████████████████████▏| 657.5MB 19.3MB/s eta 0:00:01��████████████████▎| 659.1MB 19.0MB/s eta 0:00:01████▎| 660.8MB 19.3MB/s eta 0:00:01██████████████▍| 662.3MB 96.7MB/s eta 0:00:01��█████████▌| 665.3MB 91.1MB/s eta 0:00:01██████████████▋| 667.0MB 57.4MB/s eta 0:00:01�███████████▋| 668.2MB 55.5MB/s eta 0:00:01[K    99% |███████████████████████████████▊| 669.7MB 20.1MB/s eta 0:00:01███████████████████████████▊| 670.2MB 23.9MB/s eta 0:00:01| 670.8MB 1.4MB/s eta 0:00:040:00:01MB/s eta 0:00:01
# Requirement already satisfied: spacy<2.0.0,>=0.101.0 in /usr/local/lib/python3.5/dist-packages (from de-core-news-md==1.0.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: thinc<6.6.0,>=6.5.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: pip<10.0.0,>=9.0.0 in /home/ubuntu/.local/lib/python3.5/site-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: regex<2017.12.1,>=2017.4.1 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /usr/local/lib/python3.5/dist-packages (from spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.5/dist-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.5/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.5/dist-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.5/dist-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.5/dist-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.5/dist-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.5/dist-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=0.101.0->de-core-news-md==1.0.0)
# Installing collected packages: de-core-news-md
#   Running setup.py install for de-core-news-md ... done
# Successfully installed de-core-news-md-1.0.0
#
#     Linking successful
#
#     /usr/local/lib/python3.5/dist-packages/de_core_news_md/de_core_news_md-1.0.0
#     --> /usr/local/lib/python3.5/dist-packages/spacy/data/de
#
#     You can now load the model via spacy.load('de').

# %% [markdown]
# ### Starting with Spacy
#
# We first import the library and create an `nlp` variable, instantiated for English (`'en'`).

# %%
import spacy

# Load the space library, instantiated for English
#note: the first time you run spaCy in a file it takes a little while to load up its modules
nlp = spacy.load('en')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-6d6423a29718> in <module>()
#       3 # Load the space library, instantiated for English
#       4 #note: the first time you run spaCy in a file it takes a little while to load up its modules
# ----> 5 nlp = spacy.load('en')
#
# /usr/local/lib/python3.5/dist-packages/spacy/__init__.py in load(name, **overrides)
#      40     overrides['meta'] = meta
#      41     overrides['path'] = model_path
# ---> 42     return cls(**overrides)
#
# /usr/local/lib/python3.5/dist-packages/spacy/en/__init__.py in __init__(self, **overrides)
#      32         # Special-case hack for loading the GloVe vectors, to support <1.0
#      33         overrides = fix_glove_vectors_loading(overrides)
# ---> 34         Language.__init__(self, **overrides)
#
# /usr/local/lib/python3.5/dist-packages/spacy/language.py in __init__(self, **overrides)
#     277                          else overrides['tagger']
#     278         self.parser    = self.Defaults.create_parser(self) \
# --> 279                          if 'parser' not in overrides \
#     280                          else overrides['parser']
#     281         self.entity    = self.Defaults.create_entity(self) \
#
# /usr/local/lib/python3.5/dist-packages/spacy/language.py in create_parser(cls, nlp, **cfg)
#      98             return None
#      99         else:
# --> 100             return DependencyParser.load(nlp.path / 'deps', nlp.vocab, **cfg)
#     101
#     102     @classmethod
#
# /usr/local/lib/python3.5/dist-packages/spacy/syntax/parser.pyx in spacy.syntax.parser.Parser.load (spacy/syntax/parser.cpp:7659)()
#
# /usr/local/lib/python3.5/dist-packages/thinc/linear/avgtron.pyx in thinc.linear.avgtron.AveragedPerceptron.load (thinc/linear/avgtron.cpp:3514)()
#
# /usr/local/lib/python3.5/dist-packages/preshed/maps.pyx in preshed.maps.PreshMap.__init__ (preshed/maps.cpp:1193)()
#
# /usr/local/lib/python3.5/dist-packages/preshed/maps.pyx in preshed.maps.map_init (preshed/maps.cpp:3058)()
#
# /usr/local/lib/python3.5/dist-packages/cymem/cymem.pyx in cymem.cymem.Pool.alloc (cymem/cymem.cpp:1091)()
#
# MemoryError: Error assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytesError assigning 33554432 bytes

# %% [markdown]
# From https://nicschrading.com/project/Intro-to-NLP-with-spaCy/

# %%
text = """There is an art, it says, or rather, a knack to flying. 
The knack lies in learning how to throw yourself at the ground and miss.
In the beginning the Universe was created. This has made a lot of people
very angry and been widely regarded as a bad move.
This Prof. Panos, Ph.D. costs $12,345.67"""

# %%
# all you have to do to parse text is this:
doc = nlp(text)

# %%
tokens = [token for token in doc]
tokens[:10]
# Out:
# [There, is, an, art, ,, it, says, ,, or, rather]

# %%
# Let's look at the tokens
# All you have to do is iterate through the doc
# Each token is an object with lots of different properties
# A property with an underscore at the end returns the string representation
# while a property without the underscore returns an index (int) into spaCy's vocabulary
# The probability estimate is based on counts from a 3 billion word corpus
for i, token in enumerate(doc):
    print("original:", token.orth, token.orth_)
    print("lowercased:", token.lower, token.lower_)
    print("lemma:", token.lemma, token.lemma_)
    print("shape:", token.shape, token.shape_)
    print("prefix:", token.prefix, token.prefix_)
    print("suffix:", token.suffix, token.suffix_)
    print("part of speech:", token.pos_)
    print("log probability:", token.prob)
    print("Brown cluster id:", token.cluster)
    print("----------------------------------------")
    if i > 5:
        break
# Out:
# original: 640 There
# lowercased: 530 there
# lemma: 530 there
# shape: 489815 Xxxxx
# prefix: 2907 T
# suffix: 48458 ere
# part of speech: ADV
# log probability: -7.347356796264648
# Brown cluster id: 1918
# ----------------------------------------
# original: 474 is
# lowercased: 474 is
# lemma: 488 be
# shape: 21581 xx
# prefix: 570 i
# suffix: 474 is
# part of speech: VERB
# log probability: -4.457748889923096
# Brown cluster id: 762
# ----------------------------------------
# original: 523 an
# lowercased: 523 an
# lemma: 523 an
# shape: 21581 xx
# prefix: 469 a
# suffix: 523 an
# part of speech: DET
# log probability: -6.014852046966553
# Brown cluster id: 3
# ----------------------------------------
# original: 1630 art
# lowercased: 1630 art
# lemma: 1630 art
# shape: 28983 xxx
# prefix: 469 a
# suffix: 1630 art
# part of speech: NOUN
# log probability: -9.584548950195312
# Brown cluster id: 633
# ----------------------------------------
# original: 416 ,
# lowercased: 416 ,
# lemma: 416 ,
# shape: 416 ,
# prefix: 416 ,
# suffix: 416 ,
# part of speech: PUNCT
# log probability: -3.4549596309661865
# Brown cluster id: 4
# ----------------------------------------
# original: 473 it
# lowercased: 473 it
# lemma: 473 it
# shape: 21581 xx
# prefix: 570 i
# suffix: 473 it
# part of speech: PRON
# log probability: -4.388050079345703
# Brown cluster id: 474
# ----------------------------------------
# original: 880 says
# lowercased: 880 says
# lemma: 594 say
# shape: 53740 xxxx
# prefix: 1012 s
# suffix: 338329 ays
# part of speech: VERB
# log probability: -8.426565170288086
# Brown cluster id: 244
# ----------------------------------------

# %% [markdown]
# #### Get some data
#
# First let's get a few text files, so that we can run our examples.

# %%
# !mkdir data
# !curl -L 'https://raw.githubusercontent.com/cytora/pycon-nlp-in-10-lines/master/data/article.txt' -o data/article.txt
# !curl -L 'https://raw.githubusercontent.com/cytora/pycon-nlp-in-10-lines/master/data/pride_and_prejudice.txt' -o data/pride_and_prejudice.txt
# !curl -L 'https://raw.githubusercontent.com/cytora/pycon-nlp-in-10-lines/master/data/rand-terrorism-dataset.txt'  -o data/rand-terrorism-dataset.txt

# %% [markdown]
# Now we will read the text file and then we will use the `nlp` object from spacy to analyze the text.

# %%
filename = "data/article.txt"
text = open(filename, 'r').read()
doc = nlp(text)

# %% [markdown]
# ##### Print tokens

# %%
# Print tokens, one token per line
# The enumerate function is just used to add a counter
for token in doc:
    print(token)

# %% [markdown]
# ###### Print Sentences

# %%
# Print the first 5 sentences (one sentence per line)
# The enumerate function is just used to add a counter
for i, sent in enumerate(doc.sents):
    print(i, "==>", sent)
    if i>5:
        break

# %% [markdown]
# #### Named Entities

# %%
entities = set([ent.lemma_ for ent in doc.ents])
entities
# Out:
# {'',
#  '1',
#  '1.e.1',
#  '1.e.2',
#  '1.e.3',
#  '1.e.4',
#  '1.e.7',
#  '1.e.8',
#  '1.f.3',
#  '1.f.5',
#  '1.f.6',
#  '1342',
#  '1342.txt',
#  '15th october',
#  '1998',
#  '2',
#  '2001',
#  '26th',
#  '3',
#  '30 day',
#  '33',
#  '4',
#  '5,000',
#  '50',
#  '596',
#  '60 day',
#  '64 - 6221541',
#  '801',
#  '809 north 1500 west',
#  '90 day',
#  'a',
#  'a day',
#  'a day later',
#  'a few day',
#  'a few day before',
#  'a few hour',
#  'a few line',
#  'a few minute',
#  'a few month ago',
#  'a few struggle',
#  'a few week',
#  'a month',
#  'a morning',
#  'a thousand',
#  'a week',
#  'a year ago',
#  'a year or',
#  'about a fortnight',
#  'about a month',
#  'about a month ago',
#  'about a year ago',
#  'about eight year ago',
#  'about fifteen or sixteen',
#  'about five year ago',
#  'about half',
#  'about ten',
#  'about thirty',
#  'about three or four hundred',
#  'about three year',
#  'all day long',
#  'almost a week',
#  'almost every day',
#  'an hour',
#  'anne',
#  'annesley',
#  'anonymous volunteers',
#  'as little as',
#  'as little as \n possible',
#  'as many as you',
#  'ashworth',
#  'august 26 , 2008',
#  'aye',
#  'bakewell',
#  'barnet',
#  'bath',
#  'bell',
#  'bennet',
#  'bennets',
#  'bingley',
#  'bingleys',
#  'birmingham',
#  'blenheim',
#  'brighton',
#  'british',
#  'bromley',
#  'cambridge',
#  'captain carter',
#  'caroline',
#  'caroline bingley',
#  'carter',
#  'catherine',
#  'catherine de bourgh',
#  "catherine de bourgh 's",
#  'chamberlayne',
#  'chapter 11',
#  'chapter 12',
#  'chapter 15',
#  'chapter 18',
#  'chapter 2',
#  'chapter 22',
#  'chapter 23 \n\n\n elizabeth',
#  'chapter 24',
#  'chapter 26',
#  'chapter 29',
#  'chapter 30',
#  'chapter 31',
#  'chapter 34',
#  'chapter 38',
#  'chapter 39',
#  'chapter 43',
#  'chapter 44',
#  'chapter 45',
#  'chapter 46',
#  'chapter 48',
#  'chapter 49',
#  'chapter 50',
#  'chapter 53',
#  'chapter 54',
#  'chapter 59',
#  'chapter 60',
#  'charles',
#  'charlotte',
#  'charlotte lucas',
#  'chatsworth',
#  'cheapside',
#  'christian',
#  'christmas',
#  'clapham',
#  'clarke',
#  'collins',
#  "collins 's",
#  'collinses',
#  'colonel',
#  "colonel \n miller 's",
#  'colonel fitzwilliam',
#  "colonel fitzwilliam 's",
#  'colonel forster',
#  'commerce',
#  'could colonel forster repeat',
#  'daily',
#  'darcy',
#  "darcy 's",
#  'darcy!--and',
#  'darcy:--but',
#  'dawson',
#  'day',
#  'denny',
#  'derbyshire',
#  'dove dale',
#  'eastbourne',
#  'easter',
#  'easter - day',
#  'ebooks',
#  'edw',
#  'edward',
#  'eight hundred pound',
#  'eight month',
#  "eight o'clock",
#  'eight to eight and twenty',
#  'eight year old',
#  'ein',
#  'eleven',
#  'eliza',
#  'elizabeth',
#  'elizabeth bennet',
#  "elizabeth bennet 's",
#  'england',
#  'english',
#  'epsom',
#  'esq',
#  'evening',
#  'f.',
#  'fairbanks',
#  'february',
#  'february 15 , 2015',
#  'fifteen',
#  'fifty',
#  'fifty mile',
#  'fifty pound',
#  'first',
#  'fitzwilliam',
#  'five',
#  'five \n minute',
#  'five - and - twenty year',
#  'five day ago',
#  'five mile',
#  'five minute',
#  "five o'clock",
#  'five shilling',
#  'five thousand',
#  'five thousand pound',
#  'fordyce',
#  'forster',
#  'forsters',
#  'foundation',
#  'four',
#  'four \n month',
#  'four \n year old',
#  'four day',
#  'four hour',
#  'four mile',
#  'four week',
#  'four year old',
#  'fourthly',
#  'french',
#  'friday',
#  'gardiner',
#  "gardiner 's",
#  'gardiners',
#  'george',
#  'george wickham',
#  'georgiana',
#  'georgiana darcy',
#  'gouldings',
#  'gracechurch street',
#  'grantley',
#  'great britain',
#  'gregory b. newby',
#  'gretna green',
#  'grosvenor street',
#  'haggerston',
#  'half',
#  'half - hour',
#  'half a day',
#  'half a minute',
#  'half a quarter of',
#  'half a year',
#  'half an hour',
#  "half an hour 's",
#  'half an hour ago',
#  'harriet',
#  'harringtons',
#  'hatfield',
#  'haye park',
#  'hertfordshire',
#  'hill',
#  'hour',
#  'hour and hour',
#  'hundred',
#  'hunsford',
#  'hunsford lane',
#  'hunsford parsonage',
#  'hurst',
#  "hurst 's",
#  'hursts',
#  'i. " \n\n "',
#  'irish',
#  'irs',
#  'italian',
#  'jane',
#  'jane ; "',
#  'jane austen',
#  'jane bennet',
#  'january',
#  'jenkinson',
#  'john',
#  'jones',
#  'july',
#  'june',
#  'kenilworth',
#  'kent',
#  'king',
#  'kitty',
#  'kympton',
#  'la',
#  'la !',
#  'lady',
#  'lady anne',
#  'lady anne darcy',
#  'lady catherine',
#  "lady catherine 's",
#  'lady catherine de',
#  'lady catherine de bourgh',
#  'lady lucas',
#  "lady metcalf 's",
#  'lambton',
#  'last \n night',
#  'last april',
#  'last day',
#  'last hour',
#  'last may',
#  'last month',
#  'last night',
#  'last november',
#  'last spring',
#  'last summer',
#  'last wednesday',
#  'last week',
#  'last winter',
#  'last year',
#  'laugh',
#  'less than a fortnight',
#  'lewis de bourgh',
#  'liverpool',
#  'lizzy',
#  'london',
#  'long',
#  'longbourn',
#  'longbourn house',
#  'louisa',
#  'lucas',
#  'lucas lodge',
#  'lucases',
#  'lydia',
#  'lydia bennet',
#  'lydia wickham',
#  'mamma',
#  'many month',
#  'many year',
#  'march',
#  'maria',
#  'maria lucas',
#  'mary',
#  'mary king',
#  'meryton',
#  'michael \n hart',
#  'michael s. hart',
#  'michaelmas',
#  'miss bennet',
#  "miss bennet 's",
#  'miss bingley',
#  "miss bingley 's",
#  'miss darcy',
#  'miss de bourgh',
#  'miss king',
#  'miss lucas',
#  'miss pope',
#  'mississippi',
#  'monday',
#  'month',
#  'monthly',
#  'more than half',
#  'more than one',
#  'morning',
#  'morris',
#  'mount',
#  'nearly fifty mile',
#  'nearly three',
#  'netherfield',
#  'netherfield house',
#  'netherfield park',
#  'newcastle',
#  'next \n day',
#  'next day',
#  'next saturday',
#  'next week',
#  'next year',
#  'nicholls',
#  'night',
#  'nine',
#  'noon',
#  'north',
#  'november',
#  'oakham mount',
#  'obstinate',
#  'occupied',
#  'one',
#  'one - and - twenty',
#  'one day',
#  "one day 's",
#  'one hundred',
#  'one hundred pound',
#  'one mile',
#  'one morning',
#  'one night',
#  'one thousand pound',
#  'only a few week',
#  'only a week',
#  'only eight year old',
#  'only five',
#  'only four month ago',
#  'only one',
#  'only one day',
#  'only three mile',
#  'only twenty - four',
#  'only two',
#  'oxford',
#  'park every day',
#  'pemberley',
#  'pemberley house',
#  'philips',
#  'phillip',
#  'phillips',
#  'phillipses',
#  'pratt',
#  'pride',
#  'project \n gutenberg',
#  'project \n gutenberg - tm',
#  'project gutenberg',
#  'project gutenberg - tm',
#  "project gutenberg - tm 's",
#  'proud',
#  'pulvis lodge',
#  'ramsgate',
#  'refund',
#  'regard',
#  'reynolds',
#  'richard',
#  'robinson',
#  'rosings',
#  'rosings park',
#  'sally',
#  'salt lake city',
#  'sarah',
#  'saturday',
#  'scarborough',
#  'scotch',
#  'scotland',
#  'second',
#  'secondly',
#  'section 3',
#  'section 4',
#  'sept. 6',
#  'september',
#  'seven',
#  'several \n week',
#  'several day',
#  'several year',
#  'six',
#  'six inch',
#  'six month',
#  'six thousand',
#  'six week',
#  'sixteen',
#  'some day',
#  'some hour',
#  'spanish',
#  "st. \n james 's",
#  "st. clement 's",
#  "st. james 's",
#  'states',
#  'stoke',
#  'stone',
#  'summer',
#  'sunday',
#  'tease',
#  'ten',
#  'ten \n minute',
#  'ten \n thousand',
#  'ten day',
#  'ten mile',
#  'ten minute',
#  'ten pound',
#  'ten thousand',
#  'ten thousand a year',
#  'ten thousand pound',
#  'that day',
#  'that morning',
#  'the \n day before',
#  'the church of england',
#  'the day',
#  'the day before',
#  'the end of',
#  'the end of a',
#  'the end of next week',
#  'the evening',
#  'the follow day',
#  'the follow morning',
#  'the full project',
#  'the last day',
#  'the last half - year',
#  'the last week',
#  'the longbourn party',
#  'the morning',
#  'the next day',
#  "the next day 's",
#  'the next morning',
#  'the next ten year',
#  'the night',
#  'the project gutenberg \n literary archive foundation',
#  'the project gutenberg - tm',
#  'the project gutenberg - tm license',
#  'the project gutenberg ebook of',
#  'the project gutenberg ebook of pride',
#  'the project gutenberg license',
#  'the project gutenberg literary',
#  'the project gutenberg literary archive \n foundation',
#  'the project gutenberg literary archive foundation',
#  'the project gutenberg web',
#  'the right honourable lady catherine de \n bourgh',
#  'the second week in may',
#  'the spring',
#  'the summer',
#  'the summer month',
#  'the united states',
#  'the war office',
#  'the week',
#  'these three month',
#  'third',
#  'thirdly',
#  'thirteen',
#  'thirty mile',
#  'thirty thousand pound',
#  'thirty year',
#  'this day',
#  'this evening',
#  'this morning',
#  'this summer',
#  'this week',
#  'this winter',
#  'this year',
#  'thousand',
#  'three',
#  'three \n week',
#  'three - and - twenty',
#  "three _ month '",
#  'three day',
#  'three mile',
#  'three minute',
#  'three month',
#  'three or four day',
#  'three thousand pound',
#  'three week',
#  'thursday',
#  'times',
#  'tuesday',
#  'twelve',
#  'twelve last night',
#  'twenty',
#  'twenty - seven',
#  'twenty thousand',
#  'twenty yard',
#  'two',
#  'two day',
#  'two day ago',
#  'two hour',
#  'two month',
#  'two or three',
#  'two or three day',
#  'two or three time',
#  'two whole hour',
#  'two year',
#  'two year ago',
#  'u.s.',
#  'united states',
#  'vingt - un',
#  'w.',
#  'warwick',
#  'watson',
#  'wednesday',
#  'week',
#  'westerham',
#  "what's",
#  'wickham',
#  "wickham 's",
#  'wilfully',
#  'william',
#  'william collins',
#  'william goulding',
#  'william lucas',
#  "william lucas 's",
#  'winter',
#  'www.gutenberg.org',
#  'yesterday',
#  'york',
#  'younge'}

# %%
entities_with_type = set([ent.lemma_+" # "+ent.label_ for ent in doc.ents])
entities_with_type
# Out:
# {' # CARDINAL',
#  ' # GPE',
#  ' # NORP',
#  ' # ORG',
#  ' # PERSON',
#  '1 # CARDINAL',
#  '1.e.1 # CARDINAL',
#  '1.e.2 # CARDINAL',
#  '1.e.3 # CARDINAL',
#  '1.e.4 # CARDINAL',
#  '1.e.7 # CARDINAL',
#  '1.e.8 # CARDINAL',
#  '1.f.3 # CARDINAL',
#  '1.f.5 # CARDINAL',
#  '1.f.6 # CARDINAL',
#  '1342 # MONEY',
#  '1342.txt # CARDINAL',
#  '15th october # DATE',
#  '1998 # DATE',
#  '2 # CARDINAL',
#  '2001 # DATE',
#  '26th # ORDINAL',
#  '3 # CARDINAL',
#  '30 day # DATE',
#  '33 # CARDINAL',
#  '4 # CARDINAL',
#  '5,000 # MONEY',
#  '50 # CARDINAL',
#  '596 # CARDINAL',
#  '60 day # DATE',
#  '64 - 6221541 # CARDINAL',
#  '801 # CARDINAL',
#  '809 north 1500 west # FAC',
#  '90 day # DATE',
#  'a # TIME',
#  'a day # DATE',
#  'a day later # DATE',
#  'a few day # DATE',
#  'a few day before # DATE',
#  'a few hour # TIME',
#  'a few line # TIME',
#  'a few minute # TIME',
#  'a few month ago # DATE',
#  'a few struggle # MONEY',
#  'a few week # DATE',
#  'a month # DATE',
#  'a morning # TIME',
#  'a thousand # CARDINAL',
#  'a week # DATE',
#  'a year ago # DATE',
#  'a year or # DATE',
#  'about a fortnight # CARDINAL',
#  'about a month # DATE',
#  'about a month ago # DATE',
#  'about a year ago # DATE',
#  'about eight year ago # DATE',
#  'about fifteen or sixteen # CARDINAL',
#  'about five year ago # DATE',
#  'about half # CARDINAL',
#  'about ten # CARDINAL',
#  'about thirty # DATE',
#  'about three or four hundred # CARDINAL',
#  'about three year # DATE',
#  'all day long # DATE',
#  'almost a week # DATE',
#  'almost every day # DATE',
#  'an hour # TIME',
#  'anne # PERSON',
#  'annesley # PERSON',
#  'anonymous volunteers # PERSON',
#  'as little as \n possible # MONEY',
#  'as little as # PERCENT',
#  'as many as you # CARDINAL',
#  'ashworth # PERSON',
#  'august 26 , 2008 # DATE',
#  'aye # PERSON',
#  'bakewell # PERSON',
#  'barnet # PERSON',
#  'bath # PERSON',
#  'bell # ORG',
#  'bennet # PERSON',
#  'bennets # NORP',
#  'bennets # PERSON',
#  'bingley # GPE',
#  'bingley # LOC',
#  'bingley # ORG',
#  'bingley # PERSON',
#  'bingley # WORK_OF_ART',
#  'bingleys # PERSON',
#  'birmingham # GPE',
#  'blenheim # ORG',
#  'brighton # GPE',
#  'british # NORP',
#  'bromley # PERSON',
#  'cambridge # GPE',
#  'captain carter # PERSON',
#  'caroline # PERSON',
#  'caroline bingley # PERSON',
#  'carter # PERSON',
#  'catherine # PERSON',
#  'catherine de bourgh # PERSON',
#  "catherine de bourgh 's # PERSON",
#  'chamberlayne # PERSON',
#  'chapter 11 # LAW',
#  'chapter 12 # LAW',
#  'chapter 15 # LAW',
#  'chapter 18 # LAW',
#  'chapter 2 # LAW',
#  'chapter 22 # LAW',
#  'chapter 23 \n\n\n elizabeth # LAW',
#  'chapter 24 # LAW',
#  'chapter 26 # LAW',
#  'chapter 29 # LAW',
#  'chapter 30 # LAW',
#  'chapter 31 # LAW',
#  'chapter 34 # LAW',
#  'chapter 38 # LAW',
#  'chapter 39 # LAW',
#  'chapter 43 # LAW',
#  'chapter 44 # LAW',
#  'chapter 45 # LAW',
#  'chapter 46 # LAW',
#  'chapter 48 # LAW',
#  'chapter 49 # LAW',
#  'chapter 50 # LAW',
#  'chapter 53 # LAW',
#  'chapter 54 # LAW',
#  'chapter 59 # LAW',
#  'chapter 60 # LAW',
#  'charles # PERSON',
#  'charlotte # GPE',
#  'charlotte # PERSON',
#  'charlotte lucas # PERSON',
#  'chatsworth # GPE',
#  'cheapside # GPE',
#  'christian # NORP',
#  'christmas # DATE',
#  'clapham # GPE',
#  'clapham # PERSON',
#  'clarke # PERSON',
#  'collins # PERSON',
#  "collins 's # PERSON",
#  'collinses # ORG',
#  'collinses # PERSON',
#  "colonel \n miller 's # ORG",
#  'colonel # ORG',
#  'colonel fitzwilliam # PERSON',
#  "colonel fitzwilliam 's # GPE",
#  'colonel forster # ORG',
#  'colonel forster # PERSON',
#  'commerce # ORG',
#  'could colonel forster repeat # WORK_OF_ART',
#  'daily # DATE',
#  'darcy # ORG',
#  'darcy # PERSON',
#  "darcy 's # ORG",
#  'darcy!--and # PERSON',
#  'darcy:--but # PERSON',
#  'dawson # PERSON',
#  'day # DATE',
#  'denny # PERSON',
#  'derbyshire # GPE',
#  'derbyshire # PERSON',
#  'dove dale # PERSON',
#  'eastbourne # PERSON',
#  'easter # LANGUAGE',
#  'easter - day # DATE',
#  'ebooks # PRODUCT',
#  'edw # ORG',
#  'edward # LANGUAGE',
#  'eight hundred pound # MONEY',
#  'eight month # DATE',
#  "eight o'clock # TIME",
#  'eight to eight and twenty # DATE',
#  'eight year old # DATE',
#  'ein # ORG',
#  'eleven # CARDINAL',
#  'eliza # ORG',
#  'eliza # PERSON',
#  'elizabeth # PERSON',
#  'elizabeth bennet # PERSON',
#  "elizabeth bennet 's # PERSON",
#  'england # GPE',
#  'english # LANGUAGE',
#  'epsom # GPE',
#  'esq # PERSON',
#  'evening # TIME',
#  'f. # PERSON',
#  'fairbanks # GPE',
#  'february # DATE',
#  'february 15 , 2015 # DATE',
#  'fifteen # CARDINAL',
#  'fifteen # DATE',
#  'fifty # CARDINAL',
#  'fifty mile # QUANTITY',
#  'fifty pound # QUANTITY',
#  'first # ORDINAL',
#  'fitzwilliam # GPE',
#  'fitzwilliam # PERSON',
#  'five \n minute # TIME',
#  'five # CARDINAL',
#  'five - and - twenty year # DATE',
#  'five day ago # DATE',
#  'five mile # QUANTITY',
#  'five minute # TIME',
#  "five o'clock # TIME",
#  'five shilling # MONEY',
#  'five thousand # CARDINAL',
#  'five thousand pound # QUANTITY',
#  'fordyce # PERSON',
#  'forster # PERSON',
#  'forsters # PERSON',
#  'foundation # ORG',
#  'four \n month # DATE',
#  'four \n year old # DATE',
#  'four # CARDINAL',
#  'four day # DATE',
#  'four hour # TIME',
#  'four mile # QUANTITY',
#  'four week # DATE',
#  'four year old # DATE',
#  'fourthly # ORDINAL',
#  'french # NORP',
#  'friday # DATE',
#  'gardiner # ORG',
#  'gardiner # PERSON',
#  "gardiner 's # PERSON",
#  'gardiners # ORG',
#  'gardiners # PERSON',
#  'george # PERSON',
#  'george wickham # PERSON',
#  'georgiana # GPE',
#  'georgiana # PERSON',
#  'georgiana darcy # PERSON',
#  'gouldings # PERSON',
#  'gracechurch street # FAC',
#  'gracechurch street # WORK_OF_ART',
#  'grantley # ORG',
#  'great britain # GPE',
#  'gregory b. newby # PERSON',
#  'gretna green # PERSON',
#  'grosvenor street # FAC',
#  'haggerston # GPE',
#  'half # CARDINAL',
#  'half - hour # TIME',
#  'half a day # DATE',
#  'half a minute # TIME',
#  'half a quarter of # DATE',
#  'half a year # DATE',
#  'half an hour # TIME',
#  "half an hour 's # TIME",
#  'half an hour ago # TIME',
#  'harriet # PERSON',
#  'harringtons # NORP',
#  'hatfield # PERSON',
#  'haye park # PERSON',
#  'hertfordshire # GPE',
#  'hertfordshire # NORP',
#  'hertfordshire # ORG',
#  'hertfordshire # PERSON',
#  'hill # PERSON',
#  'hour # TIME',
#  'hour and hour # TIME',
#  'hundred # CARDINAL',
#  'hunsford # GPE',
#  'hunsford # ORG',
#  'hunsford # PERSON',
#  'hunsford lane # PERSON',
#  'hunsford parsonage # ORG',
#  'hunsford parsonage # PERSON',
#  'hurst # PERSON',
#  "hurst 's # PERSON",
#  'hursts # ORG',
#  'i. " \n\n " # PERSON',
#  'irish # NORP',
#  'irs # ORG',
#  'italian # NORP',
#  'jane # PERSON',
#  'jane # WORK_OF_ART',
#  'jane ; " # PERSON',
#  'jane austen # PERSON',
#  'jane bennet # PERSON',
#  'january # DATE',
#  'jenkinson # PERSON',
#  'john # PERSON',
#  'jones # PERSON',
#  'july # DATE',
#  'june # DATE',
#  'kenilworth # GPE',
#  'kent # GPE',
#  'kent # PERSON',
#  'king # PERSON',
#  'kitty # PERSON',
#  'kympton # GPE',
#  'la ! # WORK_OF_ART',
#  'la # WORK_OF_ART',
#  'lady # PERSON',
#  'lady anne # PERSON',
#  'lady anne darcy # PERSON',
#  'lady catherine # PERSON',
#  "lady catherine 's # PERSON",
#  'lady catherine de # PERSON',
#  'lady catherine de bourgh # PERSON',
#  'lady catherine de bourgh # WORK_OF_ART',
#  'lady lucas # PERSON',
#  "lady metcalf 's # PERSON",
#  'lambton # GPE',
#  'lambton # ORG',
#  'lambton # PERSON',
#  'last \n night # TIME',
#  'last april # DATE',
#  'last day # DATE',
#  'last hour # TIME',
#  'last may # DATE',
#  'last month # DATE',
#  'last night # TIME',
#  'last november # DATE',
#  'last spring # DATE',
#  'last summer # DATE',
#  'last wednesday # DATE',
#  'last week # DATE',
#  'last winter # DATE',
#  'last year # DATE',
#  'laugh # PERSON',
#  'less than a fortnight # DATE',
#  'lewis de bourgh # PERSON',
#  'liverpool # GPE',
#  'lizzy # GPE',
#  'lizzy # PERSON',
#  'london # GPE',
#  'long # PERSON',
#  'longbourn # GPE',
#  'longbourn # ORG',
#  'longbourn # PERSON',
#  'longbourn house # ORG',
#  'louisa # GPE',
#  'louisa # ORG',
#  'louisa # PERSON',
#  'lucas # PERSON',
#  'lucas lodge # PERSON',
#  'lucases # PERSON',
#  'lydia # PERSON',
#  'lydia bennet # PERSON',
#  'lydia wickham # PERSON',
#  'mamma # PERSON',
#  'mamma # WORK_OF_ART',
#  'many month # DATE',
#  'many year # DATE',
#  'march # DATE',
#  'maria # PERSON',
#  'maria lucas # PERSON',
#  'mary # PERSON',
#  'mary king # PERSON',
#  'meryton # GPE',
#  'meryton # ORG',
#  'meryton # PERSON',
#  'michael \n hart # PERSON',
#  'michael s. hart # PERSON',
#  'michaelmas # ORG',
#  'miss bennet # PERSON',
#  "miss bennet 's # PERSON",
#  'miss bingley # PERSON',
#  "miss bingley 's # PERSON",
#  'miss darcy # PERSON',
#  'miss de bourgh # PERSON',
#  'miss king # PERSON',
#  'miss lucas # PERSON',
#  'miss pope # PERSON',
#  'mississippi # GPE',
#  'monday # DATE',
#  'month # DATE',
#  'monthly # DATE',
#  'more than half # CARDINAL',
#  'more than half # DATE',
#  'more than one # CARDINAL',
#  'morning # TIME',
#  'morris # PERSON',
#  'mount # LOC',
#  'nearly fifty mile # QUANTITY',
#  'nearly three # CARDINAL',
#  'netherfield # GPE',
#  'netherfield # ORG',
#  'netherfield # PERSON',
#  'netherfield # PRODUCT',
#  'netherfield house # ORG',
#  'netherfield park # PERSON',
#  'newcastle # GPE',
#  'newcastle # ORG',
#  'next \n day # DATE',
#  'next day # DATE',
#  'next saturday # DATE',
#  'next week # DATE',
#  'next year # DATE',
#  'nicholls # ORG',
#  'nicholls # PERSON',
#  'night # TIME',
#  'nine # CARDINAL',
#  'noon # TIME',
#  'north # LOC',
#  'november # DATE',
#  'oakham mount # PERSON',
#  'obstinate # WORK_OF_ART',
#  'occupied # ORG',
#  'one # CARDINAL',
#  'one - and - twenty # CARDINAL',
#  'one day # DATE',
#  "one day 's # DATE",
#  'one hundred # CARDINAL',
#  'one hundred pound # QUANTITY',
#  'one mile # QUANTITY',
#  'one morning # TIME',
#  'one night # TIME',
#  'one thousand pound # QUANTITY',
#  'only a few week # DATE',
#  'only a week # DATE',
#  'only eight year old # DATE',
#  'only five # CARDINAL',
#  'only four month ago # DATE',
#  'only one # CARDINAL',
#  'only one day # DATE',
#  'only three mile # QUANTITY',
#  'only twenty - four # CARDINAL',
#  'only two # CARDINAL',
#  'oxford # GPE',
#  'park every day # DATE',
#  'pemberley # FAC',
#  'pemberley # GPE',
#  'pemberley # NORP',
#  'pemberley # ORG',
#  'pemberley # PERSON',
#  'pemberley # WORK_OF_ART',
#  'pemberley house # ORG',
#  'philips # ORG',
#  'phillip # PERSON',
#  'phillips # PERSON',
#  'phillipses # PERSON',
#  'pratt # ORG',
#  'pride # ORG',
#  'project \n gutenberg # WORK_OF_ART',
#  'project \n gutenberg - tm # ORG',
#  'project gutenberg # ORG',
#  'project gutenberg - tm # ORG',
#  'project gutenberg - tm # PERSON',
#  "project gutenberg - tm 's # PERSON",
#  'proud # PERSON',
#  'pulvis lodge # PERSON',
#  'ramsgate # GPE',
#  'refund # LAW',
#  'regard # PERSON',
#  'reynolds # ORG',
#  'reynolds # PERSON',
#  'richard # PERSON',
#  'robinson # PERSON',
#  'rosings # FAC',
#  'rosings # GPE',
#  'rosings # MONEY',
#  'rosings # ORG',
#  'rosings # PERSON',
#  'rosings park # GPE',
#  'rosings park # PERSON',
#  'sally # PERSON',
#  'salt lake city # GPE',
#  'sarah # PERSON',
#  'saturday # DATE',
#  'scarborough # GPE',
#  'scotch # PERSON',
#  'scotland # GPE',
#  'second # ORDINAL',
#  'secondly # ORDINAL',
#  'section 3 # LAW',
#  'section 4 # LAW',
#  'sept. 6 # DATE',
#  'september # DATE',
#  'seven # CARDINAL',
#  'several \n week # DATE',
#  'several day # DATE',
#  'several year # DATE',
#  'six # CARDINAL',
#  'six inch # QUANTITY',
#  'six month # DATE',
#  'six thousand # CARDINAL',
#  'six week # DATE',
#  'sixteen # DATE',
#  'some day # DATE',
#  'some hour # TIME',
#  'spanish # NORP',
#  "st. \n james 's # FAC",
#  "st. clement 's # ORG",
#  "st. james 's # FAC",
#  "st. james 's # GPE",
#  "st. james 's # ORG",
#  'states # GPE',
#  'stoke # GPE',
#  'stone # PERSON',
#  'summer # DATE',
#  'sunday # DATE',
#  'tease # PERSON',
#  'ten \n minute # TIME',
#  'ten \n thousand # MONEY',
#  'ten # CARDINAL',
#  'ten # DATE',
#  'ten # QUANTITY',
#  'ten day # DATE',
#  'ten mile # QUANTITY',
#  'ten minute # TIME',
#  'ten pound # QUANTITY',
#  'ten thousand # CARDINAL',
#  'ten thousand a year # DATE',
#  'ten thousand pound # QUANTITY',
#  'that day # DATE',
#  'that morning # TIME',
#  'the \n day before # DATE',
#  'the church of england # ORG',
#  'the day # DATE',
#  'the day before # DATE',
#  'the end of # DATE',
#  'the end of a # DATE',
#  'the end of next week # DATE',
#  'the evening # TIME',
#  'the follow day # DATE',
#  'the follow morning # TIME',
#  'the full project # ORG',
#  'the last day # DATE',
#  'the last half - year # DATE',
#  'the last week # DATE',
#  'the longbourn party # ORG',
#  'the morning # TIME',
#  'the next day # DATE',
#  "the next day 's # DATE",
#  'the next morning # TIME',
#  'the next ten year # DATE',
#  'the night # TIME',
#  'the project gutenberg \n literary archive foundation # ORG',
#  'the project gutenberg - tm # ORG',
#  'the project gutenberg - tm license # ORG',
#  'the project gutenberg ebook of # ORG',
#  'the project gutenberg ebook of pride # ORG',
#  'the project gutenberg license # ORG',
#  'the project gutenberg literary # ORG',
#  'the project gutenberg literary archive \n foundation # ORG',
#  'the project gutenberg literary archive foundation # ORG',
#  'the project gutenberg web # ORG',
#  'the right honourable lady catherine de \n bourgh # ORG',
#  'the second week in may # DATE',
#  'the spring # DATE',
#  'the summer # DATE',
#  'the summer month # DATE',
#  'the united states # GPE',
#  'the war office # ORG',
#  'the week # DATE',
#  'these three month # DATE',
#  'third # ORDINAL',
#  'thirdly # ORDINAL',
#  'thirteen # CARDINAL',
#  'thirty mile # QUANTITY',
#  'thirty thousand pound # MONEY',
#  'thirty year # DATE',
#  'this day # DATE',
#  'this evening # TIME',
#  'this morning # TIME',
#  'this summer # DATE',
#  'this week # DATE',
#  'this winter # DATE',
#  'this year # DATE',
#  'thousand # CARDINAL',
#  'three \n week # DATE',
#  'three # CARDINAL',
#  'three - and - twenty # DATE',
#  'three - and - twenty # QUANTITY',
#  "three _ month ' # DATE",
#  'three day # DATE',
#  'three mile # QUANTITY',
#  'three minute # TIME',
#  'three month # DATE',
#  'three or four day # DATE',
#  'three thousand pound # QUANTITY',
#  'three week # DATE',
#  'thursday # DATE',
#  'times # ORG',
#  'tuesday # DATE',
#  'twelve # CARDINAL',
#  'twelve last night # TIME',
#  'twenty # CARDINAL',
#  'twenty - seven # QUANTITY',
#  'twenty thousand # CARDINAL',
#  'twenty yard # QUANTITY',
#  'two # CARDINAL',
#  'two day # DATE',
#  'two day ago # DATE',
#  'two hour # TIME',
#  'two month # DATE',
#  'two or three # CARDINAL',
#  'two or three day # DATE',
#  'two or three time # DATE',
#  'two whole hour # TIME',
#  'two year # DATE',
#  'two year ago # DATE',
#  'u.s. # GPE',
#  'united states # GPE',
#  'vingt - un # PERSON',
#  'w. # ORG',
#  'w. # PERSON',
#  'warwick # ORG',
#  'watson # PERSON',
#  'wednesday # DATE',
#  'week # DATE',
#  'westerham # GPE',
#  "what's # PERSON",
#  'wickham # PERSON',
#  "wickham 's # PERSON",
#  'wilfully # PERSON',
#  'william # PERSON',
#  'william collins # PERSON',
#  'william goulding # PERSON',
#  'william lucas # PERSON',
#  "william lucas 's # PERSON",
#  'winter # DATE',
#  'www.gutenberg.org # FAC',
#  'yesterday # DATE',
#  'york # ORG',
#  'younge # PERSON'}

# %% [markdown]
# #### Noun chunks

# %%
chunks = [chunk.lemma_ for chunk in doc.noun_chunks if chunk.lemma_ not in entities]
chunks
# Out:
# ['the project gutenberg ebook',
#  'this ebook',
#  'the use',
#  'anyone',
#  'no cost',
#  'almost no restriction',
#  'you',
#  'it',
#  'it',
#  'it',
#  'the term',
#  'this ebook',
#  'title',
#  'ebook',
#  'august 26 , 2008 [ ebook # 1342 ] \n release date',
#  'language',
#  'this project gutenberg ebook',
#  'chapter',
#  'it',
#  'a truth',
#  'a single man',
#  'possession',
#  'a good fortune',
#  'want',
#  'a wife',
#  'the feeling',
#  'view',
#  'such a man',
#  'a neighbourhood',
#  'this truth',
#  'the mind',
#  'the surround family',
#  'he',
#  'their daughter',
#  '" my dear mr. bennet',
#  'his lady',
#  'him',
#  'you',
#  'mr. bennet',
#  'he',
#  'it',
#  'she',
#  'mrs. long',
#  'she',
#  'me',
#  'it',
#  'mr. bennet',
#  'no answer',
#  'you',
#  'who',
#  'it',
#  'his wife',
#  'you',
#  'me',
#  'i',
#  'no objection',
#  'it',
#  'invitation',
#  'you',
#  'mrs. long',
#  'a young man',
#  'large fortune',
#  'the north',
#  'he',
#  'a chaise',
#  'the place',
#  'it',
#  'he',
#  'mr. morris',
#  'he',
#  'possession',
#  'his servant',
#  'the house',
#  'the end',
#  'what',
#  'his name',
#  '" bingley',
#  'he',
#  'a single man',
#  'large fortune',
#  'what a fine thing',
#  'our girl',
#  'it',
#  'them',
#  '" my dear mr. bennet',
#  'his wife',
#  'you',
#  'you',
#  'i',
#  'them',
#  'his design',
#  'you',
#  'it',
#  'he',
#  'love',
#  'them',
#  'you',
#  'him',
#  'he',
#  'i',
#  'no occasion',
#  'you',
#  'the girl',
#  'you',
#  'them',
#  'themselves',
#  'you',
#  'them',
#  'mr. bingley',
#  'you',
#  'the \n party',
#  'you',
#  'me',
#  'i',
#  'my share',
#  'beauty',
#  'i',
#  'anything',
#  'a woman',
#  'five \n grow - up daughter',
#  'she',
#  'thinking',
#  'her own beauty',
#  'such case',
#  '" in such case , a woman have not often much beauty',
#  'you',
#  'mr. bingley',
#  'he',
#  'the neighbourhood',
#  'it',
#  'i',
#  'i',
#  'you',
#  'your daughter',
#  'what an establishment',
#  'it',
#  'them',
#  'sir william',
#  'that account',
#  'you',
#  'they',
#  'no \n newcomer',
#  'you',
#  'it',
#  'us',
#  'him',
#  'you',
#  'you',
#  'i',
#  'mr. bingley',
#  'you',
#  'i',
#  'you',
#  'him',
#  'my \n hearty consent',
#  'whichever',
#  'he',
#  'the girl',
#  'i',
#  'a good word',
#  'my little lizzy',
#  'i',
#  'you',
#  'no such thing',
#  'the \n others',
#  'i',
#  'she',
#  'you',
#  'the preference',
#  'they',
#  'none',
#  'them',
#  'them',
#  'he',
#  'they',
#  'other girl',
#  'something',
#  'quickness',
#  'her sister',
#  'you',
#  'your own child',
#  'such a way',
#  'you',
#  'delight',
#  'me',
#  'you',
#  'no compassion',
#  'my poor nerve',
#  'you',
#  'me',
#  'i',
#  'a high respect',
#  'your nerve',
#  'they',
#  'my old friend',
#  'i',
#  'you',
#  'them',
#  'consideration',
#  'you',
#  'what',
#  'i',
#  'i',
#  'you',
#  'it',
#  'many young man',
#  'the neighbourhood',
#  'it',
#  'no use',
#  'us',
#  'you',
#  'them',
#  'it',
#  'i',
#  'them',
#  'mr. bennet',
#  'quick part',
#  'sarcastic humour',
#  'the experience',
#  'three - and - twenty year',
#  'his wife',
#  'his character',
#  'mind',
#  'she',
#  'a woman',
#  'mean understanding',
#  'little information',
#  'uncertain temper',
#  'she',
#  'she',
#  'herself',
#  'the business',
#  'her life',
#  'her \n daughter',
#  'its solace',
#  'news',
#  'chapter 2 \n\n\n mr. bennet',
#  'who',
#  'mr. bingley',
#  'he',
#  'him',
#  'his wife',
#  'he',
#  'the visit',
#  'she',
#  'no knowledge',
#  'it',
#  'it',
#  'the follow \n manner',
#  'his second daughter',
#  'a hat',
#  'he',
#  'her',
#  'i',
#  'mr. bingley',
#  'it',
#  'we',
#  'a way',
#  'what',
#  'mr. bingley',
#  'her mother',
#  'we',
#  'you',
#  'we',
#  'him',
#  'the \n assembly',
#  'mrs. long',
#  'him',
#  'i',
#  'mrs. long',
#  'any such thing',
#  'she',
#  'two niece',
#  'she',
#  'a selfish , hypocritical woman',
#  'i',
#  'no opinion',
#  'her',
#  'i',
#  'mr. bennet',
#  'i',
#  'you',
#  'you',
#  'mrs. bennet',
#  'any reply',
#  'herself',
#  'her daughter',
#  "heaven 's sake",
#  'a little \n compassion',
#  'my nerve',
#  'you',
#  'them',
#  'piece',
#  'no discretion',
#  'her cough',
#  'her father',
#  'she',
#  'them',
#  'i',
#  'my own amusement',
#  'your next ball',
#  'morrow',
#  '" when be \n your next ball to be , lizzy ? " \n\n " to - morrow fortnight',
#  'it',
#  'her mother',
#  'mrs. long',
#  'it',
#  'her',
#  'him',
#  'she',
#  'him',
#  'you',
#  'the advantage',
#  'your friend',
#  'mr. bingley',
#  'her_.',
#  'i',
#  'him',
#  'you',
#  'i',
#  'your circumspection',
#  "a fortnight 's acquaintance",
#  'what',
#  'a man',
#  'the end',
#  'a \n fortnight',
#  'we',
#  'somebody',
#  'mrs. long',
#  'her neices',
#  'their chance',
#  'she',
#  'it',
#  'kindness',
#  'you',
#  'the office',
#  'i',
#  'it',
#  'myself',
#  'the girl',
#  'their father',
#  'mrs. bennet',
#  'what',
#  'the meaning',
#  'that emphatic exclamation',
#  'he',
#  'you',
#  'the form',
#  'introduction',
#  'the stress',
#  'them',
#  'nonsense',
#  'i',
#  'you',
#  'you',
#  'you',
#  'a young lady',
#  'deep reflection',
#  'i',
#  'great book',
#  'extract',
#  'something',
#  'her idea',
#  'he',
#  'us',
#  'mr. \n bingley',
#  'i',
#  'mr. bingley',
#  'his wife',
#  'i',
#  'you',
#  'i',
#  'i',
#  'him',
#  'it',
#  'i',
#  'the visit',
#  'we',
#  'the acquaintance',
#  'the astonishment',
#  'the lady',
#  'what',
#  'he',
#  'mrs. \n bennet',
#  'the rest',
#  'the first tumult',
#  'joy',
#  'she',
#  'it',
#  'what',
#  'she',
#  'it',
#  'you',
#  'i',
#  'i',
#  'you',
#  'i',
#  'you',
#  'your girl',
#  'such an acquaintance',
#  'i',
#  'it',
#  'such a \n good joke',
#  'you',
#  'a \n word',
#  'it',
#  'you',
#  'you',
#  'mr. bennet',
#  'he',
#  'he',
#  'the room',
#  'the rapture',
#  'his wife',
#  'what an excellent father',
#  'you',
#  'girl',
#  'she',
#  'the door',
#  'i',
#  'you',
#  'him',
#  'his kindness',
#  'that matter',
#  'our time',
#  'life',
#  'it',
#  'i',
#  'you',
#  'new acquaintance',
#  'your sake',
#  'we',
#  'anything',
#  'you',
#  'i',
#  'mr. bingley',
#  'you',
#  'the next \n ball',
#  'i',
#  'i',
#  '-PRON-',
#  'the rest',
#  'he',
#  "mr. bennet 's visit",
#  'they',
#  'him',
#  'dinner',
#  'the assistance',
#  'her five \n daughter',
#  'the subject',
#  'her \n husband',
#  'any satisfactory description',
#  'mr. bingley',
#  'they',
#  'him',
#  'various way',
#  'barefaced question',
#  'ingenious supposition',
#  'distant surmise',
#  'he',
#  'the skill',
#  'them',
#  'they',
#  '-PRON-',
#  'the second - hand intelligence',
#  'their neighbour',
#  'her report',
#  'sir william',
#  'him',
#  'he',
#  'the whole',
#  'he',
#  'the next assembly',
#  'a large party',
#  'nothing',
#  'dancing',
#  'a certain step',
#  'love',
#  'very lively \n hope',
#  "mr. bingley 's heart",
#  '-PRON-',
#  'i',
#  'my daughter',
#  'mrs. bennet',
#  'her husband',
#  'all the others',
#  'i',
#  'nothing',
#  'mr. bingley',
#  "mr. bennet 's visit",
#  'him',
#  'his library',
#  'he',
#  'hope',
#  'a sight',
#  'the young lady',
#  'whose beauty',
#  'he',
#  'he',
#  'only the father',
#  'the lady',
#  '-PRON-',
#  'they',
#  'the advantage',
#  'an upper \n window',
#  'he',
#  'a blue coat',
#  'a black horse',
#  'an invitation',
#  'dinner',
#  'mrs. bennet',
#  'the course',
#  '-PRON-',
#  'credit',
#  'her \n housekeeping',
#  'an answer',
#  'it',
#  'mr. bingley',
#  'town',
#  'the honour',
#  'their invitation',
#  'mrs. bennet',
#  'she',
#  'what business',
#  'he',
#  'town',
#  'his arrival',
#  'she',
#  'he',
#  'one place',
#  'he',
#  'her fear',
#  'the idea',
#  'a large party',
#  'the ball',
#  'a report',
#  'mr. bingley',
#  'twelve lady',
#  'seven gentleman',
#  'him',
#  'the assembly',
#  'the girl',
#  'such a number',
#  '-PRON-',
#  'the ball',
#  'hearing',
#  'he',
#  'him',
#  'his five sister',
#  'a cousin',
#  'the party',
#  'the assembly room',
#  'it',
#  'his two sister',
#  'another young man',
#  'mr. bingley',
#  'he',
#  'a pleasant \n countenance',
#  'easy , unaffected manner',
#  'his sister',
#  '-PRON-',
#  'fine woman',
#  'an air',
#  'decide fashion',
#  'law',
#  'mr. hurst',
#  'the gentleman',
#  'his friend',
#  'the attention',
#  'the room',
#  'his fine , tall person',
#  'general circulation',
#  'his entrance',
#  'the gentleman',
#  'him',
#  'a fine figure',
#  'a man',
#  'the lady',
#  'he',
#  'much handsomer',
#  'mr. bingley',
#  'he',
#  'great \n admiration',
#  'about half the evening',
#  'his manner',
#  'a disgust',
#  'the tide',
#  'his popularity',
#  'he',
#  'his company',
#  'not all \n his large estate',
#  'him',
#  ', disagreeable countenance',
#  'his friend',
#  'mr. bingley',
#  'himself',
#  'all the principal \n people',
#  'the room',
#  'he',
#  'every dance',
#  'the ball',
#  'such amiable quality',
#  'themselves',
#  'what a contrast',
#  'him',
#  'his friend',
#  'mr. darcy',
#  'mrs. hurst',
#  'any other lady',
#  'the rest',
#  'the room',
#  'his own party',
#  'his character',
#  'he',
#  'the proud , most disagreeable man',
#  'the world',
#  'everybody',
#  'he',
#  'him',
#  'mrs. bennet',
#  'whose dislike',
#  'his general behaviour',
#  'particular resentment',
#  'her daughter',
#  'the scarcity',
#  'gentleman',
#  'two dance',
#  'part',
#  'that time',
#  'mr. darcy',
#  'her',
#  'a conversation',
#  'him',
#  'who',
#  'the dance',
#  'his friend',
#  'it',
#  'he',
#  'i',
#  'you',
#  'you dance',
#  'i',
#  'you',
#  'yourself',
#  'this stupid manner',
#  'you',
#  'much good \n dance',
#  'i',
#  'you',
#  'i',
#  'it',
#  'i',
#  'my partner',
#  'such an assembly',
#  'it',
#  'your sister',
#  'another woman',
#  'the room',
#  'whom',
#  'it',
#  'a punishment',
#  'me',
#  'i',
#  'you',
#  'mr. bingley',
#  'a \n kingdom',
#  'my honour',
#  'i',
#  'so many pleasant girl',
#  'my life',
#  'i',
#  'them',
#  'you',
#  'you',
#  'the only handsome girl',
#  'the room',
#  'mr. \n darcy',
#  'the eldest miss bennet',
#  'she',
#  'the most beautiful creature',
#  'i',
#  'her sister',
#  'you',
#  'who',
#  'i',
#  'me',
#  'my partner',
#  'you',
#  'you',
#  'he',
#  'a moment',
#  'her eye',
#  'he',
#  'she',
#  'me',
#  'i',
#  'no \n humour',
#  'consequence',
#  'young lady',
#  'who',
#  'other man',
#  'you',
#  'good return',
#  'your partner',
#  'her \n smile',
#  'you',
#  'your time',
#  'me',
#  'mr. bingley',
#  'his advice',
#  'mr. darcy',
#  'no very cordial feeling',
#  'him',
#  'she',
#  'the story',
#  'great spirit',
#  'her friend',
#  'she',
#  'a lively , \n playful disposition',
#  'anything',
#  'the whole family',
#  'mrs. \n bennet',
#  'her eldest daughter',
#  'the netherfield \n party',
#  'mr. bingley',
#  'she',
#  'his sister',
#  'her mother',
#  'a quiet way',
#  "jane 's \n pleasure",
#  'herself',
#  'the most \n accomplish girl',
#  'the neighbourhood',
#  'partner',
#  'they',
#  'a ball',
#  'they',
#  'good \n spirit',
#  'they',
#  '-PRON-',
#  'the principal inhabitant',
#  'they',
#  'mr. bennet',
#  'a book',
#  'he',
#  'time',
#  'the present occasion',
#  'he',
#  'a \n good deal',
#  'curiosity',
#  'the event',
#  'an evening',
#  'such splendid expectation',
#  'he',
#  "his wife 's view",
#  'the stranger',
#  'he',
#  'he',
#  'a \n different story',
#  'my dear mr. bennet',
#  'she',
#  'the room',
#  'we',
#  'a most \n delightful evening',
#  'i',
#  'you',
#  'nothing',
#  'it',
#  'everybody',
#  'she',
#  'mr. bingley',
#  'he',
#  'her',
#  'she',
#  'the only creature',
#  'the room',
#  'he',
#  'he',
#  'i',
#  'him',
#  'her',
#  'he',
#  'her',
#  'nobody',
#  'you',
#  'he',
#  'she',
#  'the dance',
#  'he',
#  'who',
#  'she',
#  'her',
#  'then the two third',
#  'he',
#  'he',
#  'any compassion',
#  'me',
#  'her husband',
#  'he',
#  "god 's sake",
#  'his partner',
#  'he',
#  'his ankle',
#  'the first dance',
#  'i',
#  'him',
#  'he',
#  'his sister',
#  'charming woman',
#  'i',
#  'my life',
#  'anything',
#  'their dress',
#  'i',
#  'the lace',
#  "mrs. \n hurst 's gown--",
#  'she',
#  'mr. bennet',
#  'any \n description',
#  'finery',
#  'she',
#  'another branch',
#  'the subject',
#  'much bitterness',
#  'spirit',
#  'some \n exaggeration',
#  'the shocking rudeness',
#  'mr. darcy',
#  'i',
#  'you',
#  'she',
#  'not \n suiting',
#  'he',
#  'a most disagreeable , horrid man',
#  'him',
#  'he',
#  'he',
#  'himself',
#  'i',
#  'you',
#  'my \n dear',
#  'your set - down',
#  'i',
#  'the man',
#  'chapter',
#  '-PRON-',
#  'who',
#  'her praise',
#  'mr. bingley',
#  'her sister',
#  'she',
#  'him',
#  'he',
#  'just what',
#  'a young man',
#  'she',
#  'i',
#  'such happy manners!--so',
#  'such perfect good breeding',
#  'he',
#  'a young man',
#  'he',
#  'his character',
#  'i',
#  'me',
#  'i',
#  'such a compliment',
#  'you',
#  'i',
#  'you',
#  'one great difference',
#  'us',
#  'compliment',
#  'you',
#  'surprise',
#  'me',
#  'what',
#  'you',
#  'he',
#  'you',
#  '-PRON-',
#  'the room',
#  'no thanks',
#  'his gallantry',
#  'he',
#  'i',
#  'him',
#  'you',
#  'many a \n stupid person',
#  '" dear lizzy',
#  'you',
#  'a great deal',
#  'you',
#  'people',
#  'you',
#  'a fault',
#  'anybody',
#  'all the world',
#  'your eye',
#  'i',
#  'you',
#  'a human being',
#  'your \n life',
#  'i',
#  'anyone',
#  'i',
#  'what',
#  'i',
#  'i',
#  'you',
#  'it',
#  'the wonder',
#  'your _ \n good sense',
#  'the folly',
#  'nonsense',
#  'others',
#  'affectation',
#  'candour',
#  'it',
#  'ostentation',
#  'design',
#  'the \n good',
#  "everybody 's character",
#  'it',
#  'nothing',
#  'you',
#  'you',
#  "this man 's sister",
#  'you',
#  'their manner',
#  'they',
#  'very pleasing woman',
#  'you',
#  'them',
#  'her brother',
#  'his house',
#  'i',
#  'we',
#  'a very charming \n neighbour',
#  'her',
#  'silence',
#  'their behaviour',
#  'the assembly',
#  'more \n quickness',
#  'observation',
#  'less pliancy',
#  'temper',
#  'her sister',
#  'a judgement',
#  'any attention',
#  'herself',
#  'she',
#  'them',
#  'they',
#  'fact',
#  'very fine \n lady',
#  'good humour',
#  'they',
#  '-PRON-',
#  'the \n power',
#  'themselves',
#  'they',
#  'it',
#  'they',
#  '-PRON-',
#  'the \n first private seminary',
#  'town',
#  'a fortune',
#  'twenty thousand \n pound',
#  '-PRON-',
#  'the habit',
#  'they',
#  'people',
#  'rank',
#  '-PRON-',
#  'every respect',
#  'themselves',
#  'others',
#  '-PRON-',
#  'a respectable family',
#  'the north',
#  'a circumstance',
#  'their memory',
#  "that their brother 's fortune",
#  'trade',
#  'mr. bingley',
#  'property',
#  'the amount',
#  'nearly a hundred \n thousand pound',
#  'his father',
#  'who',
#  'an \n estate',
#  'it',
#  'mr. bingley',
#  'it',
#  'choice',
#  'his county',
#  'he',
#  'a \n good house',
#  'the liberty',
#  ...]

# %%
from collections import Counter

keywords = Counter()
for chunk in chunks:
    # print(chunk, nlp.vocab[chunk].prob )
    if nlp.vocab[chunk].prob < -8: # probablity value -8 is arbitrarily selected threshold
        keywords[chunk] += 1

keywords.most_common(20)
# Out:
# [('-PRON-', 538),
#  ('mr. darcy', 194),
#  ('herself', 172),
#  ('mrs. bennet', 118),
#  ('mr. collins', 107),
#  ('himself', 91),
#  ('whom', 84),
#  ('mr. bingley', 79),
#  ('her sister', 73),
#  ('myself', 72),
#  ('the room', 67),
#  ('mr. bennet', 58),
#  ('town', 54),
#  ('the house', 53),
#  ('her mother', 53),
#  ('the world', 52),
#  ('mr. wickham', 51),
#  ('the subject', 47),
#  ('chapter', 45),
#  ('yourself', 43)]

# %%
for ent1 in doc.ents:
    for ent2 in doc.ents:
        similarity = ent1.similarity(ent2)
        if similarity > 0.5:
            print('{} - {} - {}' .format(ent1, ent2, similarity))

# %%
from numpy import dot
from numpy.linalg import norm

# cosine similarity
cosine = lambda v1, v2: dot(v1, v2) / (norm(v1) * norm(v2))

# Let's see if it can figure out this analogy
# B is to A as C is to ???
a = nlp.vocab['London']
b = nlp.vocab['UK']
c = nlp.vocab['France']

result = a.vector - b.vector + c.vector

# gather all known words, take only the lowercased versions
allWords = list({w for w in nlp.vocab if w.has_vector and w.is_title and w.lower_ not in set({a.lower_,b.lower_,c.lower_})})
# sort by similarity to the result
allWords.sort(key=lambda w: cosine(w.vector, result))
allWords.reverse()
print("\n----------------------------\nTop 3 closest results:")
for word in allWords[:3]:   
    print(word.orth_)
    
# it got it!
# Out:
# ----------------------------
# Top 3 closest results:
# Paris
# Italy
# Europe

# %%
filename = "data/rand-terrorism-dataset.txt"
text = open(filename, 'r').read()
doc = nlp(text)

# %%
filename = "data/pride_and_prejudice.txt"
text = open(filename, 'r').read()
doc = nlp(text)
