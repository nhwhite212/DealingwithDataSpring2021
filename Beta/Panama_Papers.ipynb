# %%
url = 'https://raw.githubusercontent.com/amaboura/panama-papers-dataset-2016/master/en.csv'

# %%
import pandas as pd

df = pd.read_csv(url)
# Out:
#      id                                fieldname  \
# 0     1                              story-title
# 1     1                           story-subtitle
# 2     1             story-image-if-linked-person
# 3     1                          story-narrative
# 4     1                  story-narrative-summary
# 5     1                          story-biography
# 6     1                      story-category-code
# 7     1                           story-priority
# 8     1                       story-region-codes
# 9     1                     story-country-1-code
# 10    1                     story-country-1-name
# 11    1                     story-country-2-code
# 12    1                     story-country-2-name
# 13    1                   story-document-1-title
# 14    1                   story-document-2-title
# 15    1                   story-document-3-title
# 16    1                   story-document-4-title
# 17    1                   story-document-5-title
# ...

# %%
df.drop(labels =range(1799,1905), inplace=True)

# %%
pivot = df.pivot(index="id", columns="fieldname", values="text")
# Out:
# fieldname                              data-person-1-comment  \
# id
# 1          Allawi's media office confirmed that he "is th...
# 10         Ndahiro<br/><br/>and Sekoko<br/><br/>did not r...
# 11         Kgyungu Kabila did not respond to repeated req...
# 12         Despite repeated attempts, ICIJ was unable to ...
# 13         Kufuor did not respond to repeated requests fo...
# 14         Ian Cameron died on Sept. 8, 2010.<br/><br/>Da...
# 15         Touré did not respond to repeated requests for...
# 16         Initially Papastavrou said he didn't remember ...
# 17         Shansonga did not respond to repeated requests...
# 18         A spokesman for Fleurette, the owner of the tw...
# 19         Sharif's daughter and sons did not respond to ...
# 2          A spokesman for Poroshenko said that creation ...
# 20         Mubarak did not respond to repeated requests f...
# 21         An attorney for Al Thani said in a phone inter...
# ...

# %%
pivot.columns
# Out:
# Index([u'data-person-1-comment', u'data-person-1-description-if-politician',
#        u'data-person-1-image', u'data-person-1-name',
#        u'data-person-1-relationship', u'data-person-1-viz-publish',
#        u'data-person-2-comment', u'data-person-2-description-if-politician',
#        u'data-person-2-image', u'data-person-2-name',
#        u'data-person-2-relationship', u'data-person-2-viz-publish',
#        u'data-person-3-comment', u'data-person-3-description-if-politician',
#        u'data-person-3-image', u'data-person-3-name',
#        u'data-person-3-relationship', u'data-person-3-viz-publish',
#        u'data-person-4-comment', u'data-person-4-description-if-politician',
#        u'data-person-4-image', u'data-person-4-name',
#        u'data-person-4-relationship', u'data-person-4-viz-publish',
#        u'data-person-5-comment', u'data-person-5-description-if-politician',
#        u'data-person-5-image', u'data-person-5-name',
# ...

# %%
pivot[["data-person-1-name", "data-person-2-name", "data-person-3-name", 'data-person-4-name', 'data-person-5-name', "linked-person-name" ]].head(100)
# Out:
# fieldname                       data-person-1-name  data-person-2-name  \
# id
# 1                                      Ayad Allawi                None
# 10                                Emmanuel Ndahiro                None
# 11                    Jaynet Désirée Kabila Kyungu                None
# 12                                   César Almeyda                None
# 13                                John Addo Kufuor                None
# 14                                     Ian Cameron                None
# 15                                   Mamadie Touré                None
# 16                             Stavros Papastavrou                None
# 17                                 Attan Shansonga                None
# 18                            Clive Khulubuse Zuma                None
# 19                                   Mariam Safdar  Hasan Nawaz Sharif
# 2                                 Petro Poroshenko                None
# ...

# %%
# Out:
#    archetype archived bookmarked bumped                 bumped_at  \
# 0    regular    False       None   True  2017-02-09T16:54:38.629Z
# 1    regular    False       None   True  2017-02-08T20:42:44.082Z
# 2    regular    False       None   True  2017-02-07T19:15:23.543Z
# 3    regular    False       None   True  2017-02-07T18:10:58.937Z
# 4    regular    False       None   True  2017-02-07T11:41:07.710Z
# 5    regular    False       None   True  2017-02-07T11:40:53.384Z
# 6    regular    False       None   True  2017-02-06T23:04:13.670Z
# 7    regular    False       None   True  2017-02-06T22:05:45.717Z
# 8    regular    False       None   True  2017-02-06T17:33:32.651Z
# 9    regular    False       None   True  2017-02-03T21:33:35.317Z
# 10   regular    False       None   True  2017-02-03T17:50:17.880Z
# 11   regular    False       None   True  2017-02-03T15:20:11.159Z
# 12   regular    False       None   True  2017-02-02T22:02:35.934Z
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-65ce3c1b1068> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.DataFrame(data)
#       4 df
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
# --> 266             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     267         elif isinstance(data, ma.MaskedArray):
#     268             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     400             arrays = [data[k] for k in keys]
#     401
# --> 402         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     403
# ...

# %%
data.keys()
# Out:
# dict_keys(['users', 'topic_list'])

# %%
# Out:
#    archetype archived bookmarked bumped                 bumped_at  \
# 0    regular    False       None   True  2017-02-09T16:54:38.629Z
# 1    regular    False       None   True  2017-02-08T20:42:44.082Z
# 2    regular    False       None   True  2017-02-07T19:15:23.543Z
# 3    regular    False       None   True  2017-02-07T18:10:58.937Z
# 4    regular    False       None   True  2017-02-07T11:41:07.710Z
# 5    regular    False       None   True  2017-02-07T11:40:53.384Z
# 6    regular    False       None   True  2017-02-06T23:04:13.670Z
# 7    regular    False       None   True  2017-02-06T22:05:45.717Z
# 8    regular    False       None   True  2017-02-06T17:33:32.651Z
# 9    regular    False       None   True  2017-02-03T21:33:35.317Z
# 10   regular    False       None   True  2017-02-03T17:50:17.880Z
# 11   regular    False       None   True  2017-02-03T15:20:11.159Z
# 12   regular    False       None   True  2017-02-02T22:02:35.934Z
# ...
