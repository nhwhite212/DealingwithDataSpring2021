# %% [markdown]
# ### Twitter example using Panos Ipeirotis authentication
# Here is an example of using Oauth1 with twitter. It was developed by Pano I. and uses his twitter account.

# %% [markdown]
# ## Example: Twitter API in Python, with OAuth1 authentication

# %% [markdown]
# <img src="images/Python_Twitter.jpg" width="300px">
#
# The guide below shows the steps of registering an application that you can integrate with **Twitter**. Registering the application is the first step in developing an application that is integrated into its users' social graph.

# %% [markdown]
# ## Register a new application
#
# All **Twitter** users are potentially **Twitter** application developers. Simply visit https://apps.twitter.com/ and sign in with your **Twitter** credentials.
#
# Click the "Create a new application" button near the top. A new page with the **_Create an application_** form requires basic information about your application.
#
# <img src="images/create_an_application_1.jpg">
#
# - In the **_Name_** field name your application in 32 characters or fewer.
# - In the **_Description_** field describe your application in 10 to 200 characters.
# - In the **_Website_** field, you can give a pointer to your website. (It does not really matter, as we will not be using that functionality yet).
# - The **_Callback URL_** leave it empty for now.
#
# The **Developer Agreement** section outlines rules you must agree to follow if you build an application that uses **Twitter’s** API. If you agree to the rules, check "Yes, I agree".
#
# <img src="images/create_an_application_2.jpg">
#
# After Captcha challenge click "Create your **Twitter** application" to complete the form and go to the application settings page.
#
# In the opened window you’ll then be presented with lots of information. The main fields to note are **_Consumer key_** and **_Consumer secret_**. These values are your application’s credentials for **Twitter**. You need them to do almost anything with **Twitter**, including going through the OAuth authorization flow and working with **Twitter’s** REST API. But we’re not quite done yet. We now need to authorise the **Twitter** app for your **Twitter** account. To do this you should select "Key and Access Tokens" menu button and create your access token. This **access token** will allow your **Twitter** application to read **Twitter** information. You’ll be able to get data of your tweets, mentions, lists and more.
#
# <img src="images/create_an_application_3.jpg">
#
# As a result you will see the window with consumer and token keys for your application
#
# <img src="images/create_an_application_4.jpg">
#
# Above the four fields are highlighted. You will need these long horrible strings of characters for your **Twitter** app. It goes without saying that you should keep these secret. If anyone was to get these keys, they could effectively access your **Twitter** account.
#
# However, if you want to do more advanced stuff like sending tweets or deleting, you’ll need to change your access type in the "Permission" menu window. Change the access type to "Read and Write" to be able to read **Twitter** data and send tweets and select "Read, Write and access direct messages" if you want to also have access to your direct messages.

# %% [markdown]
# ---
# ## Getting access to Twitter APIs using main Python tools
# ---

# %% [markdown]
# Many web services including **Twitter** require authentication, and there are many different types.
#
# Python library `requests` provides a pythonic way to make complex HTTP requests, and handles difficult tasks like authentication.
#
# A common form of authentication for several web APIs is OAuth. The `requests-oauthlib` library allows `requests`'s users to easily make OAuth authenticated requests.

# %%
# !pip3 install -U requests_oauthlib
# Out:
# Requirement already up-to-date: requests_oauthlib in /usr/local/lib/python3.6/dist-packages (1.2.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib) (2.22.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.0.0->requests_oauthlib) (2.6)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/lib/python3/dist-packages (from requests>=2.0.0->requests_oauthlib) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib) (2019.6.16)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib) (1.25.3)

# %%
import requests
from requests_oauthlib import OAuth1

import json

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
consumer_key = 'ZFSlBaBhgAnoI5Cb5YJ8Q2iSL'
consumer_secret = 'QBFuxdiXsGypn1fEL3Nu8BQtYiFXC97RIsaCf6xv7Rq7E4Dcyg'
access_token = '16976496-hhbdqyfoVqgYbFmVz076IwWxa4vM58my0v1nJNlW0'
access_secret = '3aTWUUdNMTVWDBjxCOApzRdSiiySFM4yaZcGJ1YYaub75'

# You will authenticate yourself using OAuth1 object
auth = OAuth1(consumer_key, consumer_secret, access_token, access_secret)
print(auth)
# Out:
# <requests_oauthlib.oauth1_auth.OAuth1 object at 0x2ad00dd2b630>

# %%
# If the authentication was successful, you should see the name of the account print(out)
url_0 = 'https://api.twitter.com/1.1/account/verify_credentials.json'
res = requests.get(url_0, auth=auth)

print("My name is", res.json()["name"])
# Out:
# My name is Panos Ipeirotis

# %%
res.json()
# Out:
# {'id': 16976496,
#  'id_str': '16976496',
#  'name': 'Panos Ipeirotis',
#  'screen_name': 'ipeirotis',
#  'location': 'New York, NY',
#  'description': 'Professor of Data Science and Information Systems at Stern School of Business, New York University. \n\nI have opinions.',
#  'url': 'https://t.co/BvP8qHhk1r',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/BvP8qHhk1r',
#      'expanded_url': 'http://ipeirotis.org',
#      'display_url': 'ipeirotis.org',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 4383,
#  'friends_count': 287,
#  'listed_count': 259,
#  'created_at': 'Sun Oct 26 04:16:42 +0000 2008',
#  'favourites_count': 172,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 3434,
#  'lang': None,
#  'status': {'created_at': 'Thu Aug 15 16:25:44 +0000 2019',
#   'id': 1162037668575961097,
#   'id_str': '1162037668575961097',
#   'text': '@mattyglesias There is already a very similar policy for medical doctors, "Green Card Through a Physician National… https://t.co/V5lONdjFHT',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'mattyglesias',
#      'name': 'Matthew Yglesias',
#      'id': 15446531,
#      'id_str': '15446531',
#      'indices': [0, 13]}],
#    'urls': [{'url': 'https://t.co/V5lONdjFHT',
#      'expanded_url': 'https://twitter.com/i/web/status/1162037668575961097',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1161986735770873857,
#   'in_reply_to_status_id_str': '1161986735770873857',
#   'in_reply_to_user_id': 15446531,
#   'in_reply_to_user_id_str': '15446531',
#   'in_reply_to_screen_name': 'mattyglesias',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '131516',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16976496/1398193510',
#  'profile_link_color': 'FF691F',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'EFEFEF',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# ### Example 1: Read Tweets from Your Homepage
#
# The list of all available **Twitter** API you can find here https://dev.twitter.com/rest/public. Let's use `home_timeline` that returns a collection of the most recent tweets and retweets posted by the authenticating user and the users they follow.

# %%
url_1 = 'https://api.twitter.com/1.1/statuses/home_timeline.json'
res = requests.get(url_1, auth=auth, params={"count": 20})

# The res object encapsulates the "response" of the server. Notice the status code that is displayed. 
# Code 200 means that things went fine
# Code 403 means that the server understood the request, but is refusing to fulfill it
# Code 404 means that the URL was not found
# Codes 5xx mean that something went wrong

print(res, "Status code:", res.status_code)
# Let's see how looks the url
print(res.url)
print("Content type:", res.headers['content-type'], '\n')

tweets = res.json()
if res.status_code == 200:
    for tweet in tweets:
        print("* ", tweet['text'])
        print("----------------------------------")
else:   # You have no tweets
    pass
# Out:
# <Response [200]> Status code: 200
# https://api.twitter.com/1.1/statuses/home_timeline.json?count=20
# Content type: application/json;charset=utf-8
#
# *  The latest The KDnuggets Observer! https://t.co/UkHkLQxflB
# ----------------------------------
# *  Who among you is nerd enough to play this gerrymandering board game with me? https://t.co/EHqzhrzan2
#
# Its creators… https://t.co/mgkePRV7ZR
# ----------------------------------
# *  RT @olivkoch: Happy to announce a great set of invited speakers at REVEAL #RecSys19: @mounialalmas (@SpotifyResearch), @TonyJebara (@Netfli…
# ----------------------------------
# *  Scientists think that the earliest protocells had three main components—a membrane, proteins, and molecules that en… https://t.co/3pF9y9ekOo
# ----------------------------------
# *  People willfully and actively forget details about their own moral transgressions but not about their own morally p… https://t.co/KsFTGSD4y6
# ----------------------------------
# *  In Super-Deep Diamonds, Glimmers of Earth’s Distant Past https://t.co/RlIfdz9qDt
# ----------------------------------
# *  RT @mzjacobson: This is quite spectacular
#
# The largest electric vehicle on Earth, a monster dump truck, never has to recharge because it mo…
# ----------------------------------
# *  Exit Scams Swindled $3.1 Billion From Crypto Investors in 2019: Report https://t.co/2623Kw8HE3 via @CoinDesk
# ----------------------------------
# *  NIST Lays Out Roadmap for Developing Artificial Intelligence Standards https://t.co/2ZvToyCgqb via @Nextgov
# ----------------------------------
# *  Statement on the Purpose of a Corporation https://t.co/D9BXFc0EYn (https://t.co/V4E8JRqChh)
# ----------------------------------
# *  Look no hands: self-driving vehicles' public trust problem https://t.co/PcFXA8gRSq via @wef
# ----------------------------------
# *  This was one of the better stories I read over the weekend https://t.co/f9x4OuWVDS
# ----------------------------------
# *  Fresh snow from Antarctica contained more iron-60 than could have been created by cosmic rays or human sources, sai… https://t.co/tiF9OZERFJ
# ----------------------------------
# *  RT @CompSciFact: Database normalization can help with data privacy by separating public and private data.
#
# For example, putting hospital a…
# ----------------------------------
# *  Facebook has been paying people to listen to your audio messages. https://t.co/ZyaWSpzWPh via @slate
# ----------------------------------
# *  Africa's rain forests are filled with large hardwoods that absorb carbon. For that, scientists say, we can thank th… https://t.co/mPAM6mWwUV
# ----------------------------------
# *  RT @ElliotMacgowan: Seeing @rigetti's lab yesterday reminded me how visitors of Apple must have felt in the 1980s. The energy and passion a…
# ----------------------------------
# *  Portugal trials use of goats to clear vegetation for reduction of wild f https://t.co/BHYCZBPZAf (https://t.co/Gw2Y3PNydE)
# ----------------------------------
# *  *at the same price point
# ----------------------------------
# *  From @nytopinion: Is the evening sky doomed? Light pollution is threatening our ability to see the cosmos. https://t.co/SNdmB6Dujy
# ----------------------------------

# %% [markdown]
# ### Example 2: Search tweets by key words
#
# **Twitter** employs a special query language.  For example, the query _"vacation?"_ will return tweets that contain the word "vacation" and are phrased as a question OR the query _"summer :)"_ will return the word "summer" with a positive attitude. [Check out more examples here](https://dev.twitter.com/rest/public/search).
#
# We can mine tweets using either **_search_** or **_stream_**.
#
# >The key difference between **_stream_** and **_search_** is that **_stream_** provides new data as it comes in, while **_search_** can be used to query old data. The **_search_** API is more powerful for queries, and provides faster access to a wide-range of data.
#
# Let's search for a single tweet about "vacation", phrased as a question. Note if request phrase contains URI characters you should [encode](https://en.wikipedia.org/wiki/Percent-encoding) these queries before making the request, because these characters can play role of keys in an URL. Particularly, the question mark "?" is encoded as "%3F".

# %%
import urllib

query = "stern,nyu"
encoded_query = urllib.parse.quote(query)

url_2 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + encoded_query
res = requests.get(url_2, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()
tweets
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=stern%2Cnyu
# {'statuses': [{'created_at': 'Mon Aug 19 16:39:02 +0000 2019',
#    'id': 1163490568455856128,
#    'id_str': '1163490568455856128',
#    'text': 'Breaking News: NYU Stern Will Now Accept The Shorter &amp; Easier Executive Assessment Test As A GMAT &amp; GRE Alternative… https://t.co/lVUCL7hFkf',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/lVUCL7hFkf',
#       'expanded_url': 'https://twitter.com/i/web/status/1163490568455856128',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [125, 148]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 128938832,
#     'id_str': '128938832',
#     'name': 'Poets&Quants',
#     'screen_name': 'PoetsAndQuants',
#     'location': 'San Francisco',
#     'description': 'Covering all that matters in the business school world, with in-depth analysis of B-schools rankings and full-time MBA programs',
#     'url': 'https://t.co/nedN324EbY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/nedN324EbY',
#         'expanded_url': 'http://poetsandquants.com',
#         'display_url': 'poetsandquants.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 26376,
#     'friends_count': 7518,
#     'listed_count': 498,
#     'created_at': 'Fri Apr 02 17:30:18 +0000 2010',
#     'favourites_count': 3695,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 21196,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/879779828433420290/Lsn7abGs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/879779828433420290/Lsn7abGs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128938832/1498591153',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFF312',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 19 16:38:38 +0000 2019',
#    'id': 1163490467066994689,
#    'id_str': '1163490467066994689',
#    'text': 'Breaking News: NYU Stern Will Now Accept The Shorter &amp; Easier Executive Assessment Test As A GMAT &amp; GRE Alternative… https://t.co/q6NqWjqPNY',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/q6NqWjqPNY',
#       'expanded_url': 'https://twitter.com/i/web/status/1163490467066994689',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [125, 148]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16574209,
#     'id_str': '16574209',
#     'name': 'JOHNABYRNE',
#     'screen_name': 'JohnAByrne',
#     'location': 'ÜT: 32.027902,118.797935',
#     'description': 'Founder of C-Change Media & former Executive Editor of BusinessWeek, Digital Journalism Advocate',
#     'url': 'http://t.co/QagoLxSp4J',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/QagoLxSp4J',
#         'expanded_url': 'http://www.c-changemedia.com',
#         'display_url': 'c-changemedia.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21928,
#     'friends_count': 7830,
#     'listed_count': 1335,
#     'created_at': 'Fri Oct 03 04:41:02 +0000 2008',
#     'favourites_count': 2176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 22231,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1304446701/Me_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1304446701/Me_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16574209/1394834969',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 19 12:47:58 +0000 2019',
#    'id': 1163432416599519234,
#    'id_str': '1163432416599519234',
#    'text': '@juanpablorud @romina_gaya @clarincom Cecilia Parlatore (NYU Stern), Julieta Caunedo (Cornell)',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'juanpablorud',
#       'name': 'Juan Pablo Rud',
#       'id': 1125788459724091393,
#       'id_str': '1125788459724091393',
#       'indices': [0, 13]},
#      {'screen_name': 'romina_gaya',
#       'name': 'Romina Gayá',
#       'id': 575590260,
#       'id_str': '575590260',
#       'indices': [14, 26]},
#      {'screen_name': 'clarincom',
#       'name': 'Clarín',
#       'id': 8105922,
#       'id_str': '8105922',
#       'indices': [27, 37]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ro', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1163349991466967040,
#    'in_reply_to_status_id_str': '1163349991466967040',
#    'in_reply_to_user_id': 1125788459724091393,
#    'in_reply_to_user_id_str': '1125788459724091393',
#    'in_reply_to_screen_name': 'juanpablorud',
#    'user': {'id': 4806247288,
#     'id_str': '4806247288',
#     'name': 'David Kohn',
#     'screen_name': 'DavidKohn_16',
#     'location': 'Santiago, Chile',
#     'description': 'Ph.D. in Economics, New York University. Profesor de Economía en Universidad Católica de Chile',
#     'url': 'https://t.co/w85NYDPWRp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/w85NYDPWRp',
#         'expanded_url': 'https://sites.google.com/site/davidkohn16/',
#         'display_url': 'sites.google.com/site/davidkohn…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1542,
#     'friends_count': 630,
#     'listed_count': 31,
#     'created_at': 'Thu Jan 14 17:36:59 +0000 2016',
#     'favourites_count': 6944,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1483,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1154776231965052930/pyWDGdAj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154776231965052930/pyWDGdAj_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ro'},
#   {'created_at': 'Mon Aug 19 08:27:48 +0000 2019',
#    'id': 1163366944638038017,
#    'id_str': '1163366944638038017',
#    'text': 'Improve your Leadership skills w/ Change Leadership: Strategies for Organizational Growth in a Dynamic World… https://t.co/ycPWPOQkf2',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ycPWPOQkf2',
#       'expanded_url': 'https://twitter.com/i/web/status/1163366944638038017',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [110, 133]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://execed.economist.com/" rel="nofollow">ExecEd Navigator</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 720700085462528000,
#     'id_str': '720700085462528000',
#     'name': 'Econ Courses',
#     'screen_name': 'ExecEdCourses',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 237,
#     'friends_count': 0,
#     'listed_count': 67,
#     'created_at': 'Thu Apr 14 19:47:45 +0000 2016',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24745,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/720701486418784257/ScrgFKdc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720701486418784257/ScrgFKdc_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 19 03:15:34 +0000 2019',
#    'id': 1163288366659657729,
#    'id_str': '1163288366659657729',
#    'text': 'Riesgo de caer en default financiero en 2018... Tenemos una posición envidiable en Sudamérica que está yéndose al h… https://t.co/LxezilmrlM',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/LxezilmrlM',
#       'expanded_url': 'https://twitter.com/i/web/status/1163288366659657729',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 222522828,
#     'id_str': '222522828',
#     'name': 'Pablo Carreño',
#     'screen_name': 'PaulusHC',
#     'location': 'Lima',
#     'description': 'Lingüista, escritor, traductor, reportero cultural... liberal libertario',
#     'url': 'https://t.co/aJ8L4BUhhe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/aJ8L4BUhhe',
#         'expanded_url': 'http://epeolatria.lamula.pe/',
#         'display_url': 'epeolatria.lamula.pe',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1700,
#     'friends_count': 1286,
#     'listed_count': 77,
#     'created_at': 'Fri Dec 03 17:27:13 +0000 2010',
#     'favourites_count': 20200,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 126267,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '352726',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1297249596/Sanskrit_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1297249596/Sanskrit_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/222522828/1527553646',
#     'profile_link_color': 'B97D35',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '99CC33',
#     'profile_text_color': '3E4415',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   {'created_at': 'Sun Aug 18 23:24:14 +0000 2019',
#    'id': 1163230152232493056,
#    'id_str': '1163230152232493056',
#    'text': '@scientificecon @tyillc Difference here is bank recapitalization, US was quick to do recaps. Europe has been more p… https://t.co/MozcU9n5b8',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'scientificecon',
#       'name': 'Richard Werner',
#       'id': 930743287648083968,
#       'id_str': '930743287648083968',
#       'indices': [0, 15]},
#      {'screen_name': 'tyillc',
#       'name': 'Richard Field',
#       'id': 255781485,
#       'id_str': '255781485',
#       'indices': [16, 23]}],
#     'urls': [{'url': 'https://t.co/MozcU9n5b8',
#       'expanded_url': 'https://twitter.com/i/web/status/1163230152232493056',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1163208692516425734,
#    'in_reply_to_status_id_str': '1163208692516425734',
#    'in_reply_to_user_id': 930743287648083968,
#    'in_reply_to_user_id_str': '930743287648083968',
#    'in_reply_to_screen_name': 'scientificecon',
#    'user': {'id': 404542998,
#     'id_str': '404542998',
#     'name': 'Macro Goose',
#     'screen_name': 'Macromob',
#     'location': 'New York',
#     'description': 'Macro',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 261,
#     'friends_count': 1909,
#     'listed_count': 28,
#     'created_at': 'Fri Nov 04 02:20:44 +0000 2011',
#     'favourites_count': 996,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1613,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFF04D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3534903580/eaf66a8be9921d58ea9df344a8a5ec8a_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3534903580/eaf66a8be9921d58ea9df344a8a5ec8a_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/404542998/1383941974',
#     'profile_link_color': '0099CC',
#     'profile_sidebar_border_color': 'FFF8AD',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 18 18:22:06 +0000 2019',
#    'id': 1163154116278923264,
#    'id_str': '1163154116278923264',
#    'text': 'This is my investing lecture playlist. These are some of the greatest people at calculating the value of companies.… https://t.co/tJdfpDDBE7',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/tJdfpDDBE7',
#       'expanded_url': 'https://twitter.com/i/web/status/1163154116278923264',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1148725418121469954,
#     'id_str': '1148725418121469954',
#     'name': 'Josh Felker',
#     'screen_name': 'felker_josh',
#     'location': 'Toronto, Ontario',
#     'description': 'CB1 Capital Analyst / Intrinsic Value / Cannabis / Munger / Damodaran.\n\nTesting the question of "How many Macho Man GIFS are too many Macho Man GIFS?"',
#     'url': 'https://t.co/agYzomBf8J',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/agYzomBf8J',
#         'expanded_url': 'http://cb1cap.com',
#         'display_url': 'cb1cap.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 462,
#     'friends_count': 354,
#     'listed_count': 7,
#     'created_at': 'Tue Jul 09 22:47:36 +0000 2019',
#     'favourites_count': 133,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 107,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1148728788802555915/qPDMVc5D_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148728788802555915/qPDMVc5D_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1148725418121469954/1565721333',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 18 18:08:17 +0000 2019',
#    'id': 1163150640446676992,
#    'id_str': '1163150640446676992',
#    'text': "Always a great reading, Bill Starbuck's autobiography, https://t.co/Qrpdhhz5jx https://t.co/FcK504olq6",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Qrpdhhz5jx',
#       'expanded_url': 'http://pages.stern.nyu.edu/~wstarbuc/autobio.html',
#       'display_url': 'pages.stern.nyu.edu/~wstarbuc/auto…',
#       'indices': [55, 78]}],
#     'media': [{'id': 1163150636545974278,
#       'id_str': '1163150636545974278',
#       'indices': [79, 102],
#       'media_url': 'http://pbs.twimg.com/media/ECRXV1-XoAYDSn3.png',
#       'media_url_https': 'https://pbs.twimg.com/media/ECRXV1-XoAYDSn3.png',
#       'url': 'https://t.co/FcK504olq6',
#       'display_url': 'pic.twitter.com/FcK504olq6',
#       'expanded_url': 'https://twitter.com/greenhiller42/status/1163150640446676992/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 54, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 96, 'resize': 'fit'},
#        'large': {'w': 1343, 'h': 107, 'resize': 'fit'},
#        'thumb': {'w': 107, 'h': 107, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1163150636545974278,
#       'id_str': '1163150636545974278',
#       'indices': [79, 102],
#       'media_url': 'http://pbs.twimg.com/media/ECRXV1-XoAYDSn3.png',
#       'media_url_https': 'https://pbs.twimg.com/media/ECRXV1-XoAYDSn3.png',
#       'url': 'https://t.co/FcK504olq6',
#       'display_url': 'pic.twitter.com/FcK504olq6',
#       'expanded_url': 'https://twitter.com/greenhiller42/status/1163150640446676992/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 54, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 96, 'resize': 'fit'},
#        'large': {'w': 1343, 'h': 107, 'resize': 'fit'},
#        'thumb': {'w': 107, 'h': 107, 'resize': 'crop'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 436584129,
#     'id_str': '436584129',
#     'name': 'greenhiller42',
#     'screen_name': 'greenhiller42',
#     'location': '',
#     'description': 'Assistant prof. in France. I study social (e)valuation, organizational identity, and nonmarket strategy.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 530,
#     'friends_count': 2083,
#     'listed_count': 18,
#     'created_at': 'Wed Dec 14 09:56:29 +0000 2011',
#     'favourites_count': 380,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2295,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/505673267282067457/r50hddQm_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/505673267282067457/r50hddQm_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/436584129/1475604008',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 18 16:54:46 +0000 2019',
#    'id': 1163132137765318656,
#    'id_str': '1163132137765318656',
#    'text': 'RT @aspide_l: Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che per cresc…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aspide_l',
#       'name': 'l’aspide',
#       'id': 992895004447334401,
#       'id_str': '992895004447334401',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 966978385342877697,
#     'id_str': '966978385342877697',
#     'name': 'Federico Gueli',
#     'screen_name': 'DentiRotti',
#     'location': 'Como, Lombardia',
#     'description': "Denti rotti sbattendo a terra.\n#Liberioltre\nE' conveniente governare con la menzogna, perché esalta i creduloni e sfianca i critici. \nEducatore cinofilo.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1248,
#     'friends_count': 5000,
#     'listed_count': 4,
#     'created_at': 'Fri Feb 23 10:09:47 +0000 2018',
#     'favourites_count': 28580,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 66460,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1103993395528257536/zKQjvls6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103993395528257536/zKQjvls6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/966978385342877697/1553639522',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 18 02:58:15 +0000 2019',
#     'id': 1162921620887003136,
#     'id_str': '1162921620887003136',
#     'text': 'Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che… https://t.co/lEiOmMxLsD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/lEiOmMxLsD',
#        'expanded_url': 'https://twitter.com/i/web/status/1162921620887003136',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 992895004447334401,
#      'id_str': '992895004447334401',
#      'name': 'l’aspide',
#      'screen_name': 'aspide_l',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 768,
#      'friends_count': 1917,
#      'listed_count': 6,
#      'created_at': 'Sat May 05 22:33:10 +0000 2018',
#      'favourites_count': 18212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 15372,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'},
#   {'created_at': 'Sun Aug 18 15:43:12 +0000 2019',
#    'id': 1163114127616700418,
#    'id_str': '1163114127616700418',
#    'text': 'RT @AswathDamodaran: I will not be teaching this fall at Stern, but my valuation &amp; corp fin classes are available online, for free. https:/…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AswathDamodaran',
#       'name': 'Aswath Damodaran',
#       'id': 33216611,
#       'id_str': '33216611',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 35439861,
#     'id_str': '35439861',
#     'name': 'Hariharan',
#     'screen_name': 'krishhariharan',
#     'location': 'Harrogate, England',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 755,
#     'listed_count': 1,
#     'created_at': 'Sun Apr 26 10:02:23 +0000 2009',
#     'favourites_count': 9516,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 444,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 12 20:21:43 +0000 2019',
#     'id': 1161009892531924992,
#     'id_str': '1161009892531924992',
#     'text': 'I will not be teaching this fall at Stern, but my valuation &amp; corp fin classes are available online, for free.… https://t.co/hjsEEi1WSx',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/hjsEEi1WSx',
#        'expanded_url': 'https://twitter.com/i/web/status/1161009892531924992',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 33216611,
#      'id_str': '33216611',
#      'name': 'Aswath Damodaran',
#      'screen_name': 'AswathDamodaran',
#      'location': 'New York',
#      'description': 'Fascinated by finance & markets, like writing about them and love teaching even more.',
#      'url': 'http://t.co/T8f6iV41hq',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/T8f6iV41hq',
#          'expanded_url': 'http://www.damodaran.com',
#          'display_url': 'damodaran.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 110733,
#      'friends_count': 3,
#      'listed_count': 2304,
#      'created_at': 'Sun Apr 19 14:54:22 +0000 2009',
#      'favourites_count': 47,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1298,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000557074315/275249c4889ec856ed268feef4abb00e_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000557074315/275249c4889ec856ed268feef4abb00e_normal.jpeg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 295,
#     'favorite_count': 1319,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 295,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 18 12:05:59 +0000 2019',
#    'id': 1163059462191669248,
#    'id_str': '1163059462191669248',
#    'text': 'The key to success is your ability to mourn and then to move on.\n\n– Scott Galloway, Founder, Professor of… https://t.co/M5fTPeWCnC',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/M5fTPeWCnC',
#       'expanded_url': 'https://twitter.com/i/web/status/1163059462191669248',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 798553261531918336,
#     'id_str': '798553261531918336',
#     'name': 'Cherry Advertising - Ecommerce Agency',
#     'screen_name': 'Cherry_Adv',
#     'location': 'Bulgaria',
#     'description': 'Our team brings together professionals from the fields of #design, #video #productions, #programming, #ecommerce, #ORM, #online #marketing and #advertising.',
#     'url': 'https://t.co/R7VYForoTj',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/R7VYForoTj',
#         'expanded_url': 'https://cherry-adv.net/en/',
#         'display_url': 'cherry-adv.net/en/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1238,
#     'friends_count': 3187,
#     'listed_count': 22,
#     'created_at': 'Tue Nov 15 15:48:28 +0000 2016',
#     'favourites_count': 57446,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4407,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/816035914958905344/-Y4KSVKY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816035914958905344/-Y4KSVKY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798553261531918336/1481393617',
#     'profile_link_color': 'EE1D25',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 48,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 18 10:45:08 +0000 2019',
#    'id': 1163039118546391046,
#    'id_str': '1163039118546391046',
#    'text': 'RT @aspide_l: Bill è in gamba e il 12 agosto 2017, un giorno prima della fine della internship, riceve da RBC un’offerta per diventare full…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aspide_l',
#       'name': 'l’aspide',
#       'id': 992895004447334401,
#       'id_str': '992895004447334401',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 961635731474173952,
#     'id_str': '961635731474173952',
#     'name': 'Alessio Argiolas',
#     'screen_name': 'ALESSIO_ARGIOLA',
#     'location': 'Cagliari, Sardegna',
#     'description': 'Piansi per la prima volta a Cagliari il 13 giugno 1970, appena mi accorsi che ero in ritardo di 62 giorni per assistere a Cagliari-Bari 2:0',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1117,
#     'friends_count': 9,
#     'listed_count': 7,
#     'created_at': 'Thu Feb 08 16:19:59 +0000 2018',
#     'favourites_count': 4821,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10134,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 18 03:03:37 +0000 2019',
#     'id': 1162922975131328519,
#     'id_str': '1162922975131328519',
#     'text': 'Bill è in gamba e il 12 agosto 2017, un giorno prima della fine della internship, riceve da RBC un’offerta per dive… https://t.co/CMng6NuEs9',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CMng6NuEs9',
#        'expanded_url': 'https://twitter.com/i/web/status/1162922975131328519',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1162922743198867458,
#     'in_reply_to_status_id_str': '1162922743198867458',
#     'in_reply_to_user_id': 992895004447334401,
#     'in_reply_to_user_id_str': '992895004447334401',
#     'in_reply_to_screen_name': 'aspide_l',
#     'user': {'id': 992895004447334401,
#      'id_str': '992895004447334401',
#      'name': 'l’aspide',
#      'screen_name': 'aspide_l',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 768,
#      'friends_count': 1917,
#      'listed_count': 6,
#      'created_at': 'Sat May 05 22:33:10 +0000 2018',
#      'favourites_count': 18212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 15372,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'},
#   {'created_at': 'Sun Aug 18 10:45:02 +0000 2019',
#    'id': 1163039093980323840,
#    'id_str': '1163039093980323840',
#    'text': 'RT @aspide_l: Bill è in gamba, è un ottimo studente, è presidente dello Stern Student Council. Sa che cessata la carica la responsabilità c…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aspide_l',
#       'name': 'l’aspide',
#       'id': 992895004447334401,
#       'id_str': '992895004447334401',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 961635731474173952,
#     'id_str': '961635731474173952',
#     'name': 'Alessio Argiolas',
#     'screen_name': 'ALESSIO_ARGIOLA',
#     'location': 'Cagliari, Sardegna',
#     'description': 'Piansi per la prima volta a Cagliari il 13 giugno 1970, appena mi accorsi che ero in ritardo di 62 giorni per assistere a Cagliari-Bari 2:0',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1117,
#     'friends_count': 9,
#     'listed_count': 7,
#     'created_at': 'Thu Feb 08 16:19:59 +0000 2018',
#     'favourites_count': 4821,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10134,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 18 03:00:29 +0000 2019',
#     'id': 1162922184924442624,
#     'id_str': '1162922184924442624',
#     'text': 'Bill è in gamba, è un ottimo studente, è presidente dello Stern Student Council. Sa che cessata la carica la respon… https://t.co/9Wm6TGNCPb',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9Wm6TGNCPb',
#        'expanded_url': 'https://twitter.com/i/web/status/1162922184924442624',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1162921620887003136,
#     'in_reply_to_status_id_str': '1162921620887003136',
#     'in_reply_to_user_id': 992895004447334401,
#     'in_reply_to_user_id_str': '992895004447334401',
#     'in_reply_to_screen_name': 'aspide_l',
#     'user': {'id': 992895004447334401,
#      'id_str': '992895004447334401',
#      'name': 'l’aspide',
#      'screen_name': 'aspide_l',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 768,
#      'friends_count': 1917,
#      'listed_count': 6,
#      'created_at': 'Sat May 05 22:33:10 +0000 2018',
#      'favourites_count': 18212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 15372,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'},
#   {'created_at': 'Sun Aug 18 10:45:00 +0000 2019',
#    'id': 1163039082366324736,
#    'id_str': '1163039082366324736',
#    'text': 'RT @aspide_l: Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che per cresc…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aspide_l',
#       'name': 'l’aspide',
#       'id': 992895004447334401,
#       'id_str': '992895004447334401',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 961635731474173952,
#     'id_str': '961635731474173952',
#     'name': 'Alessio Argiolas',
#     'screen_name': 'ALESSIO_ARGIOLA',
#     'location': 'Cagliari, Sardegna',
#     'description': 'Piansi per la prima volta a Cagliari il 13 giugno 1970, appena mi accorsi che ero in ritardo di 62 giorni per assistere a Cagliari-Bari 2:0',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1117,
#     'friends_count': 9,
#     'listed_count': 7,
#     'created_at': 'Thu Feb 08 16:19:59 +0000 2018',
#     'favourites_count': 4821,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10134,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961651941326704640/KnDycD8H_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 18 02:58:15 +0000 2019',
#     'id': 1162921620887003136,
#     'id_str': '1162921620887003136',
#     'text': 'Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che… https://t.co/lEiOmMxLsD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/lEiOmMxLsD',
#        'expanded_url': 'https://twitter.com/i/web/status/1162921620887003136',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 992895004447334401,
#      'id_str': '992895004447334401',
#      'name': 'l’aspide',
#      'screen_name': 'aspide_l',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 768,
#      'friends_count': 1917,
#      'listed_count': 6,
#      'created_at': 'Sat May 05 22:33:10 +0000 2018',
#      'favourites_count': 18212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 15372,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'},
#   {'created_at': 'Sun Aug 18 10:33:00 +0000 2019',
#    'id': 1163036064254222337,
#    'id_str': '1163036064254222337',
#    'text': 'RT @aspide_l: Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che per cresc…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aspide_l',
#       'name': 'l’aspide',
#       'id': 992895004447334401,
#       'id_str': '992895004447334401',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14724500,
#     'id_str': '14724500',
#     'name': 'C.A. Carnevale-Maffè',
#     'screen_name': 'carloalberto',
#     'location': 'Milan (Italy)',
#     'description': 'Bocconi University School of Management. The very moment I need to specify that Opinions Are My Own, unfollow me.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 34320,
#     'friends_count': 4529,
#     'listed_count': 521,
#     'created_at': 'Sat May 10 13:42:46 +0000 2008',
#     'favourites_count': 48291,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 89989,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '642D8B',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/476862290210590720/vv_6t7gi_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/476862290210590720/vv_6t7gi_normal.jpeg',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': '65B0DA',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 18 02:58:15 +0000 2019',
#     'id': 1162921620887003136,
#     'id_str': '1162921620887003136',
#     'text': 'Bill Tsai è nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. È ambizioso e capace. Sa che… https://t.co/lEiOmMxLsD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/lEiOmMxLsD',
#        'expanded_url': 'https://twitter.com/i/web/status/1162921620887003136',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 992895004447334401,
#      'id_str': '992895004447334401',
#      'name': 'l’aspide',
#      'screen_name': 'aspide_l',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 768,
#      'friends_count': 1917,
#      'listed_count': 6,
#      'created_at': 'Sat May 05 22:33:10 +0000 2018',
#      'favourites_count': 18212,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 15372,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992899280280211457/O7TQ-wPU_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'}],
#  'search_metadata': {'completed_in': 0.077,
#   'max_id': 1163490568455856128,
#   'max_id_str': '1163490568455856128',
#   'next_results': '?max_id=1163036064254222336&q=stern%2Cnyu&include_entities=1',
#   'query': 'stern%2Cnyu',
#   'refresh_url': '?since_id=1163490568455856128&q=stern%2Cnyu&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Please pay attention on how much information each tweet contains.

# %%
# And let's see tweets text directly
for num, tweet in enumerate(tweets['statuses']):
    print('Tweet #{0}\t{1}\t{2}\n{3}\n'.format(num+1, tweet['created_at'], 
                                               tweet['retweet_count'], 
                                               tweet['text'].encode("utf-8")))
# Out:
# Tweet #1	Mon Aug 19 16:39:02 +0000 2019	0
# b'Breaking News: NYU Stern Will Now Accept The Shorter &amp; Easier Executive Assessment Test As A GMAT &amp; GRE Alternative\xe2\x80\xa6 https://t.co/lVUCL7hFkf'
#
# Tweet #2	Mon Aug 19 16:38:38 +0000 2019	0
# b'Breaking News: NYU Stern Will Now Accept The Shorter &amp; Easier Executive Assessment Test As A GMAT &amp; GRE Alternative\xe2\x80\xa6 https://t.co/q6NqWjqPNY'
#
# Tweet #3	Mon Aug 19 12:47:58 +0000 2019	0
# b'@juanpablorud @romina_gaya @clarincom Cecilia Parlatore (NYU Stern), Julieta Caunedo (Cornell)'
#
# Tweet #4	Mon Aug 19 08:27:48 +0000 2019	0
# b'Improve your Leadership skills w/ Change Leadership: Strategies for Organizational Growth in a Dynamic World\xe2\x80\xa6 https://t.co/ycPWPOQkf2'
#
# Tweet #5	Mon Aug 19 03:15:34 +0000 2019	0
# b'Riesgo de caer en default financiero en 2018... Tenemos una posici\xc3\xb3n envidiable en Sudam\xc3\xa9rica que est\xc3\xa1 y\xc3\xa9ndose al h\xe2\x80\xa6 https://t.co/LxezilmrlM'
#
# Tweet #6	Sun Aug 18 23:24:14 +0000 2019	0
# b'@scientificecon @tyillc Difference here is bank recapitalization, US was quick to do recaps. Europe has been more p\xe2\x80\xa6 https://t.co/MozcU9n5b8'
#
# Tweet #7	Sun Aug 18 18:22:06 +0000 2019	0
# b'This is my investing lecture playlist. These are some of the greatest people at calculating the value of companies.\xe2\x80\xa6 https://t.co/tJdfpDDBE7'
#
# Tweet #8	Sun Aug 18 18:08:17 +0000 2019	0
# b"Always a great reading, Bill Starbuck's autobiography, https://t.co/Qrpdhhz5jx https://t.co/FcK504olq6"
#
# Tweet #9	Sun Aug 18 16:54:46 +0000 2019	4
# b'RT @aspide_l: Bill Tsai \xc3\xa8 nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. \xc3\x88 ambizioso e capace. Sa che per cresc\xe2\x80\xa6'
#
# Tweet #10	Sun Aug 18 15:43:12 +0000 2019	295
# b'RT @AswathDamodaran: I will not be teaching this fall at Stern, but my valuation &amp; corp fin classes are available online, for free. https:/\xe2\x80\xa6'
#
# Tweet #11	Sun Aug 18 12:05:59 +0000 2019	0
# b'The key to success is your ability to mourn and then to move on.\n\n\xe2\x80\x93 Scott Galloway, Founder, Professor of\xe2\x80\xa6 https://t.co/M5fTPeWCnC'
#
# Tweet #12	Sun Aug 18 10:45:08 +0000 2019	1
# b'RT @aspide_l: Bill \xc3\xa8 in gamba e il 12 agosto 2017, un giorno prima della fine della internship, riceve da RBC un\xe2\x80\x99offerta per diventare full\xe2\x80\xa6'
#
# Tweet #13	Sun Aug 18 10:45:02 +0000 2019	1
# b'RT @aspide_l: Bill \xc3\xa8 in gamba, \xc3\xa8 un ottimo studente, \xc3\xa8 presidente dello Stern Student Council. Sa che cessata la carica la responsabilit\xc3\xa0 c\xe2\x80\xa6'
#
# Tweet #14	Sun Aug 18 10:45:00 +0000 2019	4
# b'RT @aspide_l: Bill Tsai \xc3\xa8 nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. \xc3\x88 ambizioso e capace. Sa che per cresc\xe2\x80\xa6'
#
# Tweet #15	Sun Aug 18 10:33:00 +0000 2019	4
# b'RT @aspide_l: Bill Tsai \xc3\xa8 nato nel 1996, ha frequentato le scuole internazionali migliori di Taiwan. \xc3\x88 ambizioso e capace. Sa che per cresc\xe2\x80\xa6'

# %%
import pandas as pd
df = pd.DataFrame(tweets['statuses'])
df
# Out:
#                         created_at                   id               id_str  \
# 0   Mon Aug 19 16:39:02 +0000 2019  1163490568455856128  1163490568455856128
# 1   Mon Aug 19 16:38:38 +0000 2019  1163490467066994689  1163490467066994689
# 2   Mon Aug 19 12:47:58 +0000 2019  1163432416599519234  1163432416599519234
# 3   Mon Aug 19 08:27:48 +0000 2019  1163366944638038017  1163366944638038017
# 4   Mon Aug 19 03:15:34 +0000 2019  1163288366659657729  1163288366659657729
# 5   Sun Aug 18 23:24:14 +0000 2019  1163230152232493056  1163230152232493056
# 6   Sun Aug 18 18:22:06 +0000 2019  1163154116278923264  1163154116278923264
# 7   Sun Aug 18 18:08:17 +0000 2019  1163150640446676992  1163150640446676992
# 8   Sun Aug 18 16:54:46 +0000 2019  1163132137765318656  1163132137765318656
# 9   Sun Aug 18 15:43:12 +0000 2019  1163114127616700418  1163114127616700418
# 10  Sun Aug 18 12:05:59 +0000 2019  1163059462191669248  1163059462191669248
# 11  Sun Aug 18 10:45:08 +0000 2019  1163039118546391046  1163039118546391046
# 12  Sun Aug 18 10:45:02 +0000 2019  1163039093980323840  1163039093980323840
# 13  Sun Aug 18 10:45:00 +0000 2019  1163039082366324736  1163039082366324736
# 14  Sun Aug 18 10:33:00 +0000 2019  1163036064254222337  1163036064254222337
#
#                                                  text  truncated  \
# 0   Breaking News: NYU Stern Will Now Accept The S...       True
# 1   Breaking News: NYU Stern Will Now Accept The S...       True
# 2   @juanpablorud @romina_gaya @clarincom Cecilia ...      False
# 3   Improve your Leadership skills w/ Change Leade...       True
# 4   Riesgo de caer en default financiero en 2018.....       True
# 5   @scientificecon @tyillc Difference here is ban...       True
# 6   This is my investing lecture playlist. These a...       True
# 7   Always a great reading, Bill Starbuck's autobi...      False
# 8   RT @aspide_l: Bill Tsai è nato nel 1996, ha fr...      False
# 9   RT @AswathDamodaran: I will not be teaching th...      False
# 10  The key to success is your ability to mourn an...       True
# 11  RT @aspide_l: Bill è in gamba e il 12 agosto 2...      False
# 12  RT @aspide_l: Bill è in gamba, è un ottimo stu...      False
# 13  RT @aspide_l: Bill Tsai è nato nel 1996, ha fr...      False
# 14  RT @aspide_l: Bill Tsai è nato nel 1996, ha fr...      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...
# 5   {'hashtags': [], 'symbols': [], 'user_mentions...
# 6   {'hashtags': [], 'symbols': [], 'user_mentions...
# 7   {'hashtags': [], 'symbols': [], 'user_mentions...
# 8   {'hashtags': [], 'symbols': [], 'user_mentions...
# 9   {'hashtags': [], 'symbols': [], 'user_mentions...
# 10  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...
# 12  {'hashtags': [], 'symbols': [], 'user_mentions...
# 13  {'hashtags': [], 'symbols': [], 'user_mentions...
# 14  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'ro', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'es', 'result_type': 're...
# 5   {'iso_language_code': 'en', 'result_type': 're...
# 6   {'iso_language_code': 'en', 'result_type': 're...
# 7   {'iso_language_code': 'en', 'result_type': 're...
# 8   {'iso_language_code': 'it', 'result_type': 're...
# 9   {'iso_language_code': 'en', 'result_type': 're...
# 10  {'iso_language_code': 'en', 'result_type': 're...
# 11  {'iso_language_code': 'it', 'result_type': 're...
# 12  {'iso_language_code': 'it', 'result_type': 're...
# 13  {'iso_language_code': 'it', 'result_type': 're...
# 14  {'iso_language_code': 'it', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 2   <a href="http://twitter.com/download/iphone" r...           1.163350e+18
# 3   <a href="https://execed.economist.com/" rel="n...                    NaN
# 4   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 5   <a href="https://mobile.twitter.com" rel="nofo...           1.163209e+18
# 6   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 7   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 8   <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 9   <a href="http://twitter.com/download/iphone" r...                    NaN
# 10  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 11  <a href="http://twitter.com/download/iphone" r...                    NaN
# 12  <a href="http://twitter.com/download/iphone" r...                    NaN
# 13  <a href="http://twitter.com/download/iphone" r...                    NaN
# 14  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  ...  contributors is_quote_status retweet_count  \
# 0                       None  ...          None           False             0
# 1                       None  ...          None           False             0
# 2        1163349991466967040  ...          None           False             0
# 3                       None  ...          None           False             0
# 4                       None  ...          None           False             0
# 5        1163208692516425734  ...          None           False             0
# 6                       None  ...          None           False             0
# 7                       None  ...          None           False             0
# 8                       None  ...          None           False             4
# 9                       None  ...          None           False           295
# 10                      None  ...          None           False             0
# 11                      None  ...          None           False             1
# 12                      None  ...          None           False             1
# 13                      None  ...          None           False             4
# 14                      None  ...          None           False             4
#
#    favorite_count favorited retweeted possibly_sensitive lang  \
# 0               1     False     False              False   en
# 1               1     False     False              False   en
# 2               1     False     False                NaN   ro
# 3               0     False     False              False   en
# 4               0     False     False              False   es
# 5               0     False     False              False   en
# 6               4     False     False              False   en
# 7               0     False     False              False   en
# 8               0     False     False                NaN   it
# 9               0     False     False              False   en
# 10             48     False     False              False   en
# 11              0     False     False                NaN   it
# 12              0     False     False                NaN   it
# 13              0     False     False                NaN   it
# 14              0     False     False                NaN   it
#
#                                     extended_entities  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'media': [{'id': 1163150636545974278, 'id_str...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                      retweeted_status
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {'created_at': 'Sun Aug 18 02:58:15 +0000 2019...
# 9   {'created_at': 'Mon Aug 12 20:21:43 +0000 2019...
# 10                                                NaN
# 11  {'created_at': 'Sun Aug 18 03:03:37 +0000 2019...
# 12  {'created_at': 'Sun Aug 18 03:00:29 +0000 2019...
# 13  {'created_at': 'Sun Aug 18 02:58:15 +0000 2019...
# 14  {'created_at': 'Sun Aug 18 02:58:15 +0000 2019...
#
# [15 rows x 27 columns]

# %% [markdown]
# ##### A small diversion: The `json_normalize` function in Pandas

# %%
mylist = [
    {"FullName": {
            "Given": {
                "First": "Panos", 
                "Middle": "Gregory"
            }, 
            "Family": "Ipeirotis"
        }, 
     "Age": 40
    },
    {"FullName": {
            "Given": {
                "First": "John", 
                "Middle": "Reuben"
            }, 
            "Family": "Smith"
        }, 
     "Age": 25
    },
    {"FullName": {
            "Given": {
                "First": "Jane", 
                "Middle": "Janet"
            }, 
            "Family": "Smith"}, 
     "Age": 22
    }
]

df_test = pd.DataFrame(mylist)
df_test

# %%
from pandas.io.json import json_normalize
df_test_normalized = json_normalize(mylist)
df_test_normalized

# %% [markdown]
# ##### end of diversion... and using the function to make our JSON results more readable

# %%
# If we want to flatten the nested JSON entries
# we can use the json_normalize function
# http://pandas-docs.github.io/pandas-docs-travis/io.html#normalization
import pandas as pd
from pandas.io.json import json_normalize
df_flat = json_normalize(tweets['statuses'])

# %% [markdown]
# You may create very specialized and more concrete queries.
#
# Let's find 5 tweets that contains the word "python" or "IPython" near New York. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language). Additional parameters allows build very complicated search requests.

# %%
url_2_2 = 'https://api.twitter.com/1.1/search/tweets.json'

params = {
    "count": 10, 
    "geocode": '40.7127,-74.0059,15mi',
    "lang": 'en',
    "q": 'python'
}

res = requests.get(url_2_2, auth=auth, params=params)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()

for num, tweet in enumerate(tweets['statuses']):
    print("-----------------------------")
    print('Tweet )#{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8")))

# %% [markdown]
# ### Example 3: Get a list of all your followers
#
# **Twitter** GET request `followers/list` returns a cursored collection of user objects for users following the specified user. At this time, results are ordered with the most recent following first.

# %%
url_3 = 'https://api.twitter.com/1.1/followers/list.json'
res = requests.get(url_3, auth=auth)
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
followers

# %%
# And let's see only followers' name
for num, follower in enumerate(followers['users']):
    print('My follower #{0}\t{1}'.format(num+1, follower['name'].encode("utf-8")))

# %%
# And now an example of using a "cursor" to go through pages of results
cursor = res.json().get("next_cursor_str")
res = requests.get(url_3, auth=auth, params={"cursor": cursor})
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
for num, follower in enumerate(followers['users']):
    print('My follower #{0}\t{1}'.format(num+1, follower['name'].encode("utf-8")))

# %% [markdown]
# ### Example 4:  Finding what is trending
#
# According to the [tweepy API](http://tweepy.readthedocs.org/en/v3.5.0/api.html), we can return the top 50 trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, New York has a `WOEID` of 2459115. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in New York

# %%
url_4 = 'https://api.twitter.com/1.1/trends/place.json?id=2459115'
res = requests.get(url_4, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

top50_trends = res.json()
top50_trends

# %%
# And let's see only the first 10 trends names and the respective URL
for i, trend in enumerate(top50_trends[0]['trends'][:10]):
    print('{0} - {1} - URL: {2}'.format(i+1, trend['name'], trend['url']))

# %% [markdown]
# ### Example 5: Streaming
#
# **Twitter** offers a [Streaming API](https://dev.twitter.com/streaming/overview) to make it easier to query streams of tweets.  The Stream API encapsulates some pain points of REST access to ensure that Stream calls don't exceed the rate limit. These tool allows to get tweet data when it appears in real time. There are three stream types:
#
# - `Public Streams:` Streams of public data flowthing through **Twitter**. Suitable for followign specific users, topics or for data mining.
# - `User Streams:` Single-user streams. Containing roughly all of the data corresponding with a single user's view of **Twitter**.
# - `Site Streams:` The multi-user version of user streams.
#
# >Connecting to the streaming API requires keeping a persistent HTTP connection open. In many cases this involves thinking about your application differently than if you were interacting with the REST API. An app which connects to the Streaming APIs will not be able to establish a connection in response to a user request. Instead, the code for maintaining the Streaming connection is typically run in a process separate from the process which handles HTTP requests. The streaming process gets the input tweets and performs any parsing, filtering, and/or aggregation needed before storing the result to a data store. The HTTP handling process queries the data store for results in response to user requests. While this model is more complex than the first example, the benefits from having a realtime stream of tweet data make the integration worthwhile for many types of apps.
#
# With `requests.Response.iter_lines()` you can easily iterate over streaming APIs including the **Twitter Streaming API**. Simply set `stream` parameter to `True` and iterate over the response with `iter_lines()`.
#
# Depending on the search term/terms, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#iphone_ hashtag:

# %%
import time
import urllib

query = "#iphone"
encoded_query = urllib.parse.quote(query)
url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=' + encoded_query
res = requests.get(url_5, auth=auth, stream=True)

print(res, res.status_code, res.headers['content-type'])
print(res.url, "\n")

# Let's measure the time elapsed after the start of streaming 
start = time.time()
stop_after = 10
tweets_printed = 0
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line.decode(encoding='utf-8') )
        print("Elapsed:", time.time()-start, "sec",  
                parsed_line["created_at"], "\n", 
                parsed_line['text'].encode("utf-8"), "\n")
        tweets_printed = tweets_printed + 1
        if tweets_printed>stop_after:
            break

print("Time Elapsed for getting", stop_after, " tweets about ", query, " ==>" , time.time()-start)

# %% [markdown]
# ---
# ## Exercises
# ---

# %% [markdown]
# ## Exercise #1:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display, the list of all your friends and sort them by its followers amounts in descending order.
#
# #### HINT: `GET friends/list`  will be helpfull for you here.

# %% [markdown]
# ## Exercise #2:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library, display the list of 5 (or less if there is not so much) most recent tweets liked by you, which were also retweeted (`retweet_count` is not equal to zero). You shoud show the date of creation, author of the tweet and its text.
#
# #### HINT: `GET favorites/list` will be helpfull for you here

# %% [markdown]
# ## Exercise #3:
#
# > Using [Twitter Streaming API](https://dev.twitter.com/streaming/overview) and `requests` Python library count how many tweets with hashtags _#twitter_, _#tweet_ and _#world_ are appearing each minute over 5 minutes and display these 5 numbers. Please display also the shortest and the longest time period between to closest tweets for all 5 measures.
#
# #### HINT: `POST statuses/filter` will be helpfull for you here
