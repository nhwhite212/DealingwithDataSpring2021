# %% [markdown]
# <a href="https://colab.research.google.com/github/nhwhite212/DealingwithDataSpring2021/blob/master/4-UNIX_Basics/B-Fetching_Data_Using_CURL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting Data using CURL
# -----------------------
#
# We now move into a more interesting topic: How to get data from Internet sources. For that, we will use a command-line tool of Unix, called `curl`. (Later in class, we will learn how to achieve the same using Python, but for quick testing, curl is often the standard method used.) We will also use a tool called `jq` to interact with JSON output. (Do not worry, we will revisit both these later in class.)
#
# _Often, curl and jq do not come preinstalled, so the first time that we use them, we need to issue the appropriate command for installing it.  To install it, simply type:_

# %%
#!sudo apt-get -y install curl
#!sudo apt-get -y install jq

# %% [markdown]
# Let's start by retrieving a simple text file, which we will use later in the class, to illustrate how different shell commands work. The sample data file is hosted online. You can use terminal commands to copy this remote file. Simply type:

# %%
# !curl -L 'http://pages.stern.nyu.edu/~nwhite/DealingwithDataFall2018/sample.txt'

# %% [markdown]
# The columns in this tab-separated data correspond to [order id] [time of order] [user id] [ordered item], something similar to what might be encountered in practice. If you wish, you can copy-paste the data written above into a text editor, making sure there is a newline following each of the ordered item columns (the columns with alphabetic characters).

# %% [markdown]
# To store the output to a file, we also add the `-o [output file]` in the command. (We are also going to see in the next session how to use _output redirection_ to store the output to a file.)

# %%
# !curl -L 'http://pages.stern.nyu.edu/~nwhite/DealingwithDataFall2018/sample.txt' -o data/sample.txt

# %%
# !ls -al data/

# %% [markdown]
# This will pull the file to the directory 'data', creating a new file called `sample.txt`. If we do not want to see any statistics about the download, we can use the `-s` option:

# %%
# !curl  -s -L 'http://pages.stern.nyu.edu/~nwhite/DealingwithDataFall2018/sample.txt' -o data/sample.txt
# !ls -al  data/

# %% [markdown]
# Now, let's try to use curl to get access to some real data. A key component of today's data ecosystem is the existence of `Web APIs` which provide functionality for a variety of tasks.
#
# #### Where am I?
#
# For example, let's try to figure out programmatically the location of the computer where the jupyter server is running. We can access the API call by issuing the following command: (128.122.85.5 is an Stern server's IP)

# %%
# !curl -s "http://api.ipstack.com/128.122.85.5?access_key=c2192e9aa79a13153a328f383b810862"|jq

# %% [markdown]
# While this does not look nice to a human, for a computer is a perfectly legitimate answer. This format is called "JSON", and is an efficient and very commonly used way to trasfer data today on the Internet.
# | jq controls the presentation by taking the output and formatting it as json.

# %% [markdown]
# Now, let's examine a few more web APIs, just for fun:
#
# #### What's the weather?
#
# Now, let's use the OpenWeather API to get the weather details in our location. (The details of the API calls are available at http://openweathermap.org/api.)

# %%
# !curl -s "http://api.openweathermap.org/data/2.5/weather?\
&appid=ffb7b9808e07c9135bdcc7d1e867253d\
&q=New%20York,NY,USA\
&units=imperial\
&mode=json"|jq .

# %% [markdown]
# You will notice that we asked the service to return to us the data in JSON format. For that API, we can also ask the data to be returned in a different format, called XML, which is wordlier. (We will get back to these formats later in the semester.)

# %%
# !curl -s "http://api.openweathermap.org/data/2.5/weather?\
&q=New%20York,NY,USA\
&units=imperial\
&mode=xml\
&appid=ffb7b9808e07c9135bdcc7d1e867253d"

# %% [markdown]
# #### What's the sentiment?
#
# Now let's try to use a web service to automatically analyze the sentiment for a piece of text. (The service comes from the [IBM's Alchemy API](http://www.alchemyapi.com/api/sentiment/textc.html#textsentiment))
#
# Note that you can register for a free account at IBM Cloud Services, and try out many of their
# machine learning/data science api's.
# https://www.ibm.com/cloud/

# %%
#  Create the parameter file for the call to watsons natural language service
# !echo "{" >parameters.json
# !echo  "   \"text\":\"I think that IBM watson is a wonderful service.\"," >>parameters.json
# !echo "    \"features\":{" >>parameters.json
# !echo "      \"entities\": {" >>parameters.json
# !echo "        \"emotion\": true," >>parameters.json
# !echo "        \"sentiment\": true," >> parameters.json
# !echo "        \"limit\":2" >>parameters.json
# !echo "      }," >>parameters.json
# !echo "     \"keywords\": {" >>parameters.json
# !echo "         \"emotion\":true," >>parameters.json
# !echo "         \"sentiment\":true," >>parameters.json
# !echo "         \"limit\": 2" >> parameters.json
# !echo "    }" >> parameters.json
# !echo "   }"  >> parameters.json
# !echo "}" >> parameters.json
# !cat parameters.json
# Out:
# {
#    "text":"I think that IBM watson is a wonderful service.",
#     "features":{
#       "entities": {
#         "emotion": true,
#         "sentiment": true,
#         "limit":2
#       },
#      "keywords": {
#          "emotion":true,
#          "sentiment":true,
#          "limit": 2
#     }
#    }
# }

# %%
#!curl -s "https://gateway-a.watsonplatform.net/calls/text/TextGetTextSentiment" \
#-d "outputMode=json" \
#-d "apikey=4b46c7859a7be311b6f9389b12504e302cac0a55" \
#-d "text=I did not dislike it. " 
# !curl -X POST -H "content-Type: application/json"   \
-u "apikey":"JjBk20E2nz3jxv9tUkasj1CIcyPOwhcb1uhMhkXdTWEn" \
    -d @parameters.json  \
    "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze?version=2018-11-16"


# !curl -G -u  "apikey":"JjBk20E2nz3jxv9tUkasj1CIcyPOwhcb1uhMhkXdTWEn" -d "version=2018-11-16" -d "url=pages.stern.nyu.edu/~nwhite" -d "features=keywords,entities" -d "entities.emotion=true" -d "entities.sentiment=true" -d "keywords.emotion=true" -d "keywords.sentiment=true" "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze"
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 47,
#     "features": 2
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "IBM watson",
#       "sentiment": {
#         "score": 0.983705,
#         "label": "positive"
#       },
#       "relevance": 0.844343,
#       "emotion": {
#         "sadness": 0.006155,
#         "joy": 0.113473,
#         "fear": 0.002814,
#         "disgust": 0.008891,
#         "anger": 0.022145
#       },
#       "count": 1
#     },
#     {
#       "text": "wonderful service",
#       "sentiment": {
#         "score": 0.983705,
#         "label": "positive"
#       },
#       "relevance": 0.155657,
#       "emotion": {
#         "sadness": 0.006155,
#         "joy": 0.113473,
#         "fear": 0.002814,
#         "disgust": 0.008891,
#         "anger": 0.022145
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "Company",
#       "text": "IBM",
#       "sentiment": {
#         "score": 0.728278,
#         "label": "positive"
#       },
#       "relevance": 0.33,
#       "emotion": {
#         "sadness": 0.006155,
#         "joy": 0.113473,
#         "fear": 0.002814,
#         "disgust": 0.008891,
#         "anger": 0.022145
#       },
#       "disambiguation": {
#         "subtype": [
#           "SoftwareLicense",
#           "OperatingSystemDeveloper",
#           "ProcessorManufacturer",
#           "SoftwareDeveloper",
#           "CompanyFounder",
#           "ProgrammingLanguageDesigner",
#           "ProgrammingLanguageDeveloper"
#         ],
#         "name": "IBM",
#         "dbpedia_resource": "http://dbpedia.org/resource/IBM"
#       },
#       "count": 1
#     }
#   ]
# }{
#   "usage": {
#     "text_units": 1,
#     "text_characters": 2069,
#     "features": 2
#   },
#   "retrieved_url": "http://pages.stern.nyu.edu/~nwhite/",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Director of the Academic Computing Center",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.817482,
#       "emotion": {
#         "sadness": 0.072164,
#         "joy": 0.437076,
#         "fear": 0.069357,
#         "disgust": 0.045703,
#         "anger": 0.152573
#       },
#       "count": 1
#     },
#     {
#       "text": "Stern faculty",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.792338,
#       "emotion": {
#         "sadness": 0.072164,
#         "joy": 0.437076,
#         "fear": 0.069357,
#         "disgust": 0.045703,
#         "anger": 0.152573
#       },
#       "count": 1
#     },
#     {
#       "text": "Professor White's research interests",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.74056,
#       "emotion": {
#         "sadness": 0.100329,
#         "joy": 0.1589,
#         "fear": 0.110623,
#         "disgust": 0.045543,
#         "anger": 0.065043
#       },
#       "count": 1
#     },
#     {
#       "text": "Faculty Director of the Stern Center",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.703493,
#       "emotion": {
#         "sadness": 0.06458,
#         "joy": 0.30885,
#         "fear": 0.078258,
#         "disgust": 0.030691,
#         "anger": 0.167043
#       },
#       "count": 2
#     },
#     {
#       "text": "university level",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.670579,
#       "emotion": {
#         "sadness": 0.049607,
#         "joy": 0.170732,
#         "fear": 0.057061,
#         "disgust": 0.030707,
#         "anger": 0.050694
#       },
#       "count": 1
#     },
#     {
#       "text": "World Wide Web",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.631358,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "General Foods",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.606561,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "big data",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.594697,
#       "emotion": {
#         "sadness": 0.102676,
#         "joy": 0.143691,
#         "fear": 0.076888,
#         "disgust": 0.042443,
#         "anger": 0.044638
#       },
#       "count": 1
#     },
#     {
#       "text": "Recent teaching activities",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.57885,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "Stern School",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.576934,
#       "emotion": {
#         "sadness": 0.086958,
#         "joy": 0.284552,
#         "fear": 0.115849,
#         "disgust": 0.045061,
#         "anger": 0.191695
#       },
#       "count": 1
#     },
#     {
#       "text": "Professor White",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.57168,
#       "emotion": {
#         "sadness": 0.035365,
#         "joy": 0.183233,
#         "fear": 0.024114,
#         "disgust": 0.017,
#         "anger": 0.099954
#       },
#       "count": 3
#     },
#     {
#       "text": "decision support systems",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.567692,
#       "emotion": {
#         "sadness": 0.100329,
#         "joy": 0.1589,
#         "fear": 0.110623,
#         "disgust": 0.045543,
#         "anger": 0.065043
#       },
#       "count": 1
#     },
#     {
#       "text": "wide variety",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.562603,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "Mobile Apps",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.561383,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "Research Computing",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.559379,
#       "emotion": {
#         "sadness": 0.06458,
#         "joy": 0.30885,
#         "fear": 0.078258,
#         "disgust": 0.030691,
#         "anger": 0.167043
#       },
#       "count": 2
#     },
#     {
#       "text": "electronic commerce",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.546495,
#       "emotion": {
#         "sadness": 0.100329,
#         "joy": 0.1589,
#         "fear": 0.110623,
#         "disgust": 0.045543,
#         "anger": 0.065043
#       },
#       "count": 1
#     },
#     {
#       "text": "G. Heileman Brewing",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.542332,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "number of committees",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.541238,
#       "emotion": {
#         "sadness": 0.049607,
#         "joy": 0.170732,
#         "fear": 0.057061,
#         "disgust": 0.030707,
#         "anger": 0.050694
#       },
#       "count": 1
#     },
#     {
#       "text": "former clients",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.539273,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "delivery          of multimedia material",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.531692,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "Centers services",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.531406,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "Annheuser Busch",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.525346,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "Computational Approaches",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.519068,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "number of consumer product          companies",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.516024,
#       "emotion": {
#         "sadness": 0.072843,
#         "joy": 0.17019,
#         "fear": 0.018713,
#         "disgust": 0.012602,
#         "anger": 0.071857
#       },
#       "count": 1
#     },
#     {
#       "text": "university",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.51441,
#       "emotion": {
#         "sadness": 0.049607,
#         "joy": 0.170732,
#         "fear": 0.057061,
#         "disgust": 0.030707,
#         "anger": 0.050694
#       },
#       "count": 1
#     },
#     {
#       "text": "Kraft",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.512614,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "advanced computational research",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.512425,
#       "emotion": {
#         "sadness": 0.086958,
#         "joy": 0.284552,
#         "fear": 0.115849,
#         "disgust": 0.045061,
#         "anger": 0.191695
#       },
#       "count": 1
#     },
#     {
#       "text": "Engineering",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.512194,
#       "emotion": {
#         "sadness": 0.098257,
#         "joy": 0.488942,
#         "fear": 0.081858,
#         "disgust": 0.009828,
#         "anger": 0.047989
#       },
#       "count": 1
#     },
#     {
#       "text": "Labatt",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.511464,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "small high performance",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.511128,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "cloud",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.511124,
#       "emotion": {
#         "sadness": 0.102676,
#         "joy": 0.143691,
#         "fear": 0.076888,
#         "disgust": 0.042443,
#         "anger": 0.044638
#       },
#       "count": 1
#     },
#     {
#       "text": "Toyota",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.511054,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "Ford",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.510706,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "Design",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.510307,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "marketing",
#       "sentiment": {
#         "score": 0.633199,
#         "label": "positive"
#       },
#       "relevance": 0.51022,
#       "emotion": {
#         "sadness": 0.064653,
#         "joy": 0.168692,
#         "fear": 0.039482,
#         "disgust": 0.017739,
#         "anger": 0.062692
#       },
#       "count": 1
#     },
#     {
#       "text": "group",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.509966,
#       "emotion": {
#         "sadness": 0.086958,
#         "joy": 0.284552,
#         "fear": 0.115849,
#         "disgust": 0.045061,
#         "anger": 0.191695
#       },
#       "count": 1
#     },
#     {
#       "text": "consultant",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.509672,
#       "emotion": {
#         "sadness": 0.072843,
#         "joy": 0.17019,
#         "fear": 0.018713,
#         "disgust": 0.012602,
#         "anger": 0.071857
#       },
#       "count": 1
#     },
#     {
#       "text": "grid",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.508414,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "Data",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.507863,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 2
#     },
#     {
#       "text": "E-mail",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.507008,
#       "emotion": {
#         "sadness": 0.098282,
#         "joy": 0.07359,
#         "fear": 0.031413,
#         "disgust": 0.02336,
#         "anger": 0.057449
#       },
#       "count": 1
#     },
#     {
#       "text": "Mckinsey",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.506402,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "RJ Reynolds",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.505971,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     },
#     {
#       "text": "servers",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.505863,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "Harvard",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.505231,
#       "emotion": {
#         "sadness": 0.070554,
#         "joy": 0.0901,
#         "fear": 0.053037,
#         "disgust": 0.036074,
#         "anger": 0.058664
#       },
#       "count": 2
#     },
#     {
#       "text": "course",
#       "sentiment": {
#         "score": 0.813694,
#         "label": "positive"
#       },
#       "relevance": 0.504979,
#       "emotion": {
#         "sadness": 0.116626,
#         "joy": 0.551412,
#         "fear": 0.075298,
#         "disgust": 0.011587,
#         "anger": 0.039587
#       },
#       "count": 1
#     },
#     {
#       "text": "Physics",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.504879,
#       "emotion": {
#         "sadness": 0.127156,
#         "joy": 0.131455,
#         "fear": 0.132962,
#         "disgust": 0.028603,
#         "anger": 0.079081
#       },
#       "count": 1
#     },
#     {
#       "text": "blog",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.504862,
#       "emotion": {
#         "sadness": 0.126649,
#         "joy": 0.688001,
#         "fear": 0.08816,
#         "disgust": 0.01062,
#         "anger": 0.017479
#       },
#       "count": 1
#     },
#     {
#       "text": "hadoop",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.504835,
#       "emotion": {
#         "sadness": 0.117578,
#         "joy": 0.129424,
#         "fear": 0.063308,
#         "disgust": 0.039396,
#         "anger": 0.03093
#       },
#       "count": 1
#     },
#     {
#       "text": "Economics",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.503566,
#       "emotion": {
#         "sadness": 0.127156,
#         "joy": 0.131455,
#         "fear": 0.132962,
#         "disgust": 0.028603,
#         "anger": 0.079081
#       },
#       "count": 1
#     },
#     {
#       "text": "Payback Training Systems",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.502981,
#       "emotion": {
#         "sadness": 0.033781,
#         "joy": 0.288869,
#         "fear": 0.010166,
#         "disgust": 0.032385,
#         "anger": 0.09542
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "JobTitle",
#       "text": "Faculty Director",
#       "sentiment": {
#         "score": -0.480628,
#         "label": "negative"
#       },
#       "relevance": 0.828524,
#       "emotion": {
#         "sadness": 0.087108,
#         "joy": 0.190399,
#         "fear": 0.092671,
#         "disgust": 0.028876,
#         "anger": 0.102146
#       },
#       "count": 7
#     },
#     {
#       "type": "Organization",
#       "text": "Stern Center for Research Computing",
#       "sentiment": {
#         "score": -0.480628,
#         "label": "negative"
#       },
#       "relevance": 0.712556,
#       "emotion": {
#         "sadness": 0.075174,
#         "joy": 0.234297,
#         "fear": 0.088553,
#         "disgust": 0.01678,
#         "anger": 0.150155
#       },
#       "count": 2
#     },
#     {
#       "type": "Person",
#       "text": "Professor White",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.705907,
#       "emotion": {
#         "sadness": 0.034976,
#         "joy": 0.155347,
#         "fear": 0.011337,
#         "disgust": 0.013492,
#         "anger": 0.047423
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "NYU",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.406787,
#       "emotion": {
#         "sadness": 0.070554,
#         "joy": 0.0901,
#         "fear": 0.053037,
#         "disgust": 0.036074,
#         "anger": 0.058664
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "Facility",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "New York University",
#         "dbpedia_resource": "http://dbpedia.org/resource/New_York_University"
#       },
#       "count": 2
#     },
#     {
#       "type": "Location",
#       "text": "Stern",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.396726,
#       "emotion": {
#         "sadness": 0.072164,
#         "joy": 0.437076,
#         "fear": 0.069357,
#         "disgust": 0.045703,
#         "anger": 0.152573
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Academic Computing Center",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.395954,
#       "emotion": {
#         "sadness": 0.072164,
#         "joy": 0.437076,
#         "fear": 0.069357,
#         "disgust": 0.045703,
#         "anger": 0.152573
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Stern School",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.387119,
#       "emotion": {
#         "sadness": 0.091605,
#         "joy": 0.281979,
#         "fear": 0.135929,
#         "disgust": 0.102825,
#         "anger": 0.110253
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "New York University Stern School of Business",
#         "dbpedia_resource": "http://dbpedia.org/resource/New_York_University_Stern_School_of_Business"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Harvard",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.381492,
#       "emotion": {
#         "sadness": 0.070554,
#         "joy": 0.0901,
#         "fear": 0.053037,
#         "disgust": 0.036074,
#         "anger": 0.058664
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Harvard University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Harvard_University"
#       },
#       "count": 2
#     },
#     {
#       "type": "Company",
#       "text": "Dairyland Foods",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.265415,
#       "emotion": {
#         "sadness": 0.218364,
#         "joy": 0.252756,
#         "fear": 0.152848,
#         "disgust": 0.41869,
#         "anger": 0.09986
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Goldman Sachs",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.262847,
#       "emotion": {
#         "sadness": 0.26506,
#         "joy": 0.125627,
#         "fear": 0.077127,
#         "disgust": 0.136296,
#         "anger": 0.085966
#       },
#       "disambiguation": {
#         "subtype": [
#           "CompanyShareholder"
#         ],
#         "name": "Goldman Sachs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Goldman_Sachs"
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "RJ Reynolds",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.260145,
#       "emotion": {
#         "sadness": 0.158132,
#         "joy": 0.163354,
#         "fear": 0.097915,
#         "disgust": 0.074539,
#         "anger": 0.094071
#       },
#       "disambiguation": {
#         "subtype": [
#           "CompanyFounder"
#         ],
#         "name": "R. J. Reynolds",
#         "dbpedia_resource": "http://dbpedia.org/resource/R._J._Reynolds"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Labatt",
#       "sentiment": {
#         "score": 0.45456,
#         "label": "positive"
#       },
#       "relevance": 0.258495,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "Labatt Brewing Company",
#         "dbpedia_resource": "http://dbpedia.org/resource/Labatt_Brewing_Company"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "US State Department",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.257567,
#       "emotion": {
#         "sadness": 0.26506,
#         "joy": 0.125627,
#         "fear": 0.077127,
#         "disgust": 0.136296,
#         "anger": 0.085966
#       },
#       "disambiguation": {
#         "subtype": [
#           "GovernmentAgency",
#           "GovernmentalBody",
#           "AppointedRole"
#         ],
#         "name": "United States Department of State",
#         "dbpedia_resource": "http://dbpedia.org/resource/United_States_Department_of_State"
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Annheuser Busch",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.254379,
#       "emotion": {
#         "sadness": 0.064441,
#         "joy": 0.165117,
#         "fear": 0.011244,
#         "disgust": 0.008547,
#         "anger": 0.043826
#       },
#       "count": 1
#     },
#     {
#       "type": "JobTitle",
#       "text": "Director",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.253371,
#       "emotion": {
#         "sadness": 0.072164,
#         "joy": 0.437076,
#         "fear": 0.069357,
#         "disgust": 0.045703,
#         "anger": 0.152573
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "General Foods",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.252653,
#       "emotion": {
#         "sadness": 0.225712,
#         "joy": 0.250945,
#         "fear": 0.130829,
#         "disgust": 0.283699,
#         "anger": 0.138565
#       },
#       "disambiguation": {
#         "subtype": [
#           "Brand"
#         ],
#         "name": "General Foods",
#         "dbpedia_resource": "http://dbpedia.org/resource/General_Foods"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Kraft",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.247216,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "CandyBarManufacturer"
#         ],
#         "name": "Kraft Foods",
#         "dbpedia_resource": "http://dbpedia.org/resource/Kraft_Foods"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Mckinsey",
#       "sentiment": {
#         "score": 0.258364,
#         "label": "positive"
#       },
#       "relevance": 0.232805,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "McKinsey & Company",
#         "dbpedia_resource": "http://dbpedia.org/resource/McKinsey_&_Company"
#       },
#       "count": 1
#     },
#     {
#       "type": "JobTitle",
#       "text": "consultant",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.226806,
#       "emotion": {
#         "sadness": 0.064441,
#         "joy": 0.165117,
#         "fear": 0.011244,
#         "disgust": 0.008547,
#         "anger": 0.043826
#       },
#       "count": 1
#     },
#     {
#       "type": "JobTitle",
#       "text": "marketing and sales",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.226363,
#       "emotion": {
#         "sadness": 0.064441,
#         "joy": 0.165117,
#         "fear": 0.011244,
#         "disgust": 0.008547,
#         "anger": 0.043826
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Toyota",
#       "sentiment": {
#         "score": 0.559021,
#         "label": "positive"
#       },
#       "relevance": 0.220538,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "AutomobileCompany",
#           "ManufacturingPlant",
#           "AwardWinner"
#         ],
#         "name": "Toyota",
#         "dbpedia_resource": "http://dbpedia.org/resource/Toyota"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Ford",
#       "sentiment": {
#         "score": 0.400173,
#         "label": "positive"
#       },
#       "relevance": 0.204028,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "count": 1
#     },
#     {
#       "type": "TwitterHandle",
#       "text": "@normwhite",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.204028,
#       "count": 1
#     }
#   ]
# }

# %% [markdown]
# ## Exercise
#
# The following websites contain listing of many useful APIs
#
# * https://market.mashape.com/explore
# * https://www.programmableweb.com/category/all/apis
# * http://www.mashery.com/
# * http://apigee.com/
#
# Mashape is my own personal favorite in terms of user-friendliness and also has examples directly expressed using CURL. but the others are pretty nice as well.
# #### Your task: search through mashup  and find a web API that does something that you like. Use CURL to issue a web API call to this service. Note, You will need to create a mashup account to get a key to use with your application.

# %%
# !curl -X POST --include 'https://andruxnet-random-famous-quotes.p.mashape.com/?cat=movies' \
-H 'X-Mashape-Key: OzEG3Zp1kqmshUxcOFT9hhn1LFbmp19ubr2jsnLlnpE40EIlCp' \
-H 'Content-Type: application/x-www-form-urlencoded' \
-H 'Accept: application/json'
